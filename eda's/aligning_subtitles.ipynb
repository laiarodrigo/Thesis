# %% [markdown]
# **//IMPORTS**

# %%
import sys, pathlib
import pandas as pd
import numpy as np
import pysrt

from typing import List, Dict, Sequence, Tuple
from datetime import timedelta

project_root = pathlib.Path().resolve().parents[0] 
print(f"Project root: {project_root}")
sys.path.insert(0, str(project_root / "src"))
from transform.align_subtitles import time_diff_score, align_subtitles_greedy, align_subtitles_optimal_hungarian, shift_srt
# Out:
# Project root: /home/rofarate/Thesis
# /home/rofarate/Thesis/thesis/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# **//FUNCTION** Functions to be put in the transform folder

# %%
def find_offset_between_subtitles(aligned_pairs, min_score=0.6):
    time_differences = []
    scores = []
    matched = 0
    
    for a, b, score in aligned_pairs:
        if b is not None and score > min_score:
            matched += 1
            time_differences.append((a['start'] - b['start']).total_seconds())
            scores.append(score)

    if len(time_differences) == 0:
        return 0.0, 0.0
    
    total = len(aligned_pairs)
    coverage = matched / total if total > 0 else 0.0
    avg_offset = np.mean(time_differences) if time_differences else 0.0
    max_offset = np.max(np.abs(time_differences)) if time_differences else 0.0
    mean_score = np.mean(scores) if scores else 0.0

    return avg_offset, max_offset, coverage, mean_score

def find_offset_between_subtitles_percentile(
    aligned_pairs: Sequence[Tuple[Dict[str, object], Dict[str, object], float]],
    top_percent: float = 10.0,          # keep the top-10 % most similar
    min_pairs: int = 3                  # need at least this many to compute stats
) -> Tuple[float, float, float, float]:

    diffs, scores = [], []
    for a, b, s in aligned_pairs:
        if b is not None:
            diffs.append((a["start"] - b["start"]).total_seconds())
            scores.append(float(s))

    total = len(scores)
    if total == 0:
        return 0.0, 0.0, 0.0, 0.0

    # percentile threshold
    q = 100.0 - top_percent            # e.g. 90-th percentile for top 10 %
    score_cutoff = np.percentile(scores, q)

    # keep only pairs at / above the cutoff
    kept_diffs  = [d for d, s in zip(diffs, scores) if s >= score_cutoff]
    kept_scores = [s for s       in scores            if s >= score_cutoff]
    kept_diffs = np.array(kept_diffs)

    if len(kept_diffs) < min_pairs:    
        print(f"Warning: not enough pairs ({len(kept_diffs)})")
        return 0.0, 0.0, len(kept_diffs) / total, (np.mean(kept_scores) if kept_scores else 0.0)

    avg_offset = float(np.median(kept_diffs))        # median, not mean
    max_offset = float(np.max(np.abs(kept_diffs)))
    coverage   = len(kept_diffs) / total
    mean_score = float(np.mean(kept_scores))

    return avg_offset, max_offset, coverage, mean_score

def shift_srt(subs, offset_seconds):
    delta = pd.to_timedelta(offset_seconds, unit='s')
    shifted = []
    for record in subs:
        shifted.append(
            {
                "start": record["start"] - delta,   # subtract the signed Δ
                "end":   record["end"]   - delta,
                "text":  record["text"],
            }
        )
    return shifted

# %% [markdown]
# **//FUNCTIONS** Preprocessing

# %%
def eliminate_new_lines(subtitles):
    for sub in subtitles:
        if '\n' in sub['text']:
            sub['text'] = sub['text'].replace('\n', ' ')

def merge_subtitle_fragments(
    blocks: Sequence[Dict[str, object]],
    gap_threshold: timedelta | pd.Timedelta = pd.Timedelta(milliseconds=120),
    join_punct: str = " ",                     # what to insert between merged parts
    terminal_stop: str = ".?!",                # punctuation that *prevents* merging
) -> List[Dict[str, object]]:

    gap_threshold = pd.Timedelta(gap_threshold)

    merged: List[Dict[str, object]] = []
    i = 0
    n = len(blocks)

    while i < n:
        current = blocks[i].copy()           # shallow copy is enough
        i += 1                           # provisional advance

        # attempt to merge with followers as long as the rule allows
        while i < n:
            nxt = blocks[i]
            gap = nxt["start"] - current["end"]

            # last char of current text, first char of next
            tail = current["text"].rstrip()[-1:]          # could be '', ',' …
            head = nxt["text"].lstrip()[:1]

            mergeable = (
                gap <= gap_threshold and
                (tail == "," or tail not in terminal_stop) and
                head.islower()
            )
            if not mergeable:
                break

            # --- perform merge --------------------------------------------
            if tail == ",":
                current["text"] = current["text"].rstrip(",") + " " + nxt["text"].lstrip()
            else:
                current["text"] = current["text"].rstrip() + join_punct + nxt["text"].lstrip()

            current["end"] = nxt["end"]      # extend duration
            i += 1                       # consume the merged‐in block

        merged.append(current)

    return merged

def load_subtitles(path):
    subs = pysrt.open(path)
    return [
        {
            "start": pd.to_timedelta(s.start.ordinal, unit="ms"),  # milliseconds → Timedelta
            "end":   pd.to_timedelta(s.end.ordinal,   unit="ms"),
            "text":  s.text.replace("\n", " ").strip(),
        }
        for s in subs
    ]

# %% [markdown]
# **//MAIN CODE**

# %%
file_a = '../data/raw/test_br_subs/tt14513804.srt'
file_b = '../data/raw/test_pt_subs/tt14513804.srt'

# %%
subs_a = load_subtitles(file_a)
subs_b = load_subtitles(file_b)

eliminate_new_lines(subs_a)
eliminate_new_lines(subs_b)

merged_subs_a = merge_subtitle_fragments(subs_a, gap_threshold=pd.Timedelta(seconds=0.2))
merged_subs_b = merge_subtitle_fragments(subs_b, gap_threshold=pd.Timedelta(seconds=0.2))

# %%
aligned_pairs = align_subtitles_optimal_hungarian(subs_a, subs_b)
aligned_pairs_preprocessed = align_subtitles_optimal_hungarian(merged_subs_a, merged_subs_b)

# %%
# aligned_pairs_greedy = align_subtitles_greedy(subs_a, subs_b, time_window=time_window)

# %%
count = 0
for _ in aligned_pairs:
    a, b, score = _
    if score == 0:
        count += 1
        print(_)
print(f"Total unmatched pairs: {count}")
print(f"Total pairs: {len(aligned_pairs)}")
# Out:
# ({'start': Timedelta('0 days 00:01:07.420000'), 'end': Timedelta('0 days 00:01:09.430000'), 'text': 'estamos a instantes de começar.'}, None, 0)
# ({'start': Timedelta('0 days 00:01:09.450000'), 'end': Timedelta('0 days 00:01:11.560000'), 'text': 'Vocês estão prontos?'}, None, 0)
# ({'start': Timedelta('0 days 00:01:21.350000'), 'end': Timedelta('0 days 00:01:22.530000'), 'text': 'Senhoras e senhores,'}, None, 0)
# ({'start': Timedelta('0 days 00:02:27.390000'), 'end': Timedelta('0 days 00:02:28.560000'), 'text': 'abraçou o tema da união'}, None, 0)
# ({'start': Timedelta('0 days 00:02:38.470000'), 'end': Timedelta('0 days 00:02:40.460000'), 'text': 'alguns questionam se eles podem superar'}, None, 0)
# ({'start': Timedelta('0 days 00:02:44.550000'), 'end': Timedelta('0 days 00:02:45.530000'), 'text': 'Aqui está, Cap.'}, None, 0)
# ({'start': Timedelta('0 days 00:02:45.550000'), 'end': Timedelta('0 days 00:02:47.540000'), 'text': 'Durante seu tempo como um...'}, None, 0)
# ({'start': Timedelta('0 days 00:02:52.470000'), 'end': Timedelta('0 days 00:02:54.390000'), 'text': '...levando Ross'}, None, 0)
# ({'start': Timedelta('0 days 00:03:11.400000'), 'end': Timedelta('0 days 00:03:13.570000'), 'text': 'ao Hulk de Banner foi o que levou à destruição.'}, None, 0)
# ({'start': Timedelta('0 days 00:04:19.470000'), 'end': Timedelta('0 days 00:04:21.460000'), 'text': 'Carregue os pontos de entrada encobertos do complexo.'}, None, 0)
# ({'start': Timedelta('0 days 00:05:17.540000'), 'end': Timedelta('0 days 00:05:18.520000'), 'text': 'por ajudá-los.'}, None, 0)
# ({'start': Timedelta('0 days 00:06:40.570000'), 'end': Timedelta('0 days 00:06:42.510000'), 'text': 'Movam-se, movam-se, movam-se!'}, None, 0)
# ({'start': Timedelta('0 days 00:06:42.530000'), 'end': Timedelta('0 days 00:06:45.360000'), 'text': 'Vámonos, vámonos.'}, None, 0)
# ({'start': Timedelta('0 days 00:10:01.540000'), 'end': Timedelta('0 days 00:10:03.520000'), 'text': 'Uhul!'}, None, 0)
# ({'start': Timedelta('0 days 00:11:06.470000'), 'end': Timedelta('0 days 00:11:08.340000'), 'text': 'sempre voltado para o sol,'}, None, 0)
# ({'start': Timedelta('0 days 00:11:40.390000'), 'end': Timedelta('0 days 00:11:41.350000'), 'text': 'Alô.'}, None, 0)
# ({'start': Timedelta('0 days 00:12:49.490000'), 'end': Timedelta('0 days 00:12:50.480000'), 'text': 'Isso significa que você finalmente vai'}, None, 0)
# ({'start': Timedelta('0 days 00:13:07.400000'), 'end': Timedelta('0 days 00:13:09.350000'), 'text': 'Então você vai precisar aprender a ficar de boca fechada.'}, None, 0)
# ({'start': Timedelta('0 days 00:13:23.540000'), 'end': Timedelta('0 days 00:13:24.540000'), 'text': 'E aí, veterano?'}, None, 0)
# ({'start': Timedelta('0 days 00:13:34.470000'), 'end': Timedelta('0 days 00:13:36.420000'), 'text': 'Ainda não descobri como fazer ele calar a boca.'}, None, 0)
# ({'start': Timedelta('0 days 00:13:44.580000'), 'end': Timedelta('0 days 00:13:46.370000'), 'text': 'Ah, m*rda...'}, None, 0)
# ({'start': Timedelta('0 days 00:13:47.530000'), 'end': Timedelta('0 days 00:13:49.370000'), 'text': 'Ah, droga.'}, None, 0)
# ({'start': Timedelta('0 days 00:15:48.370000'), 'end': Timedelta('0 days 00:15:51.500000'), 'text': 'Isso simplesmente não me parece certo.'}, None, 0)
# ({'start': Timedelta('0 days 00:20:06.540000'), 'end': Timedelta('0 days 00:20:07.540000'), 'text': 'Hmm.'}, None, 0)
# ({'start': Timedelta('0 days 00:20:38.580000'), 'end': Timedelta('0 days 00:20:41.350000'), 'text': 'me deu motivos para reconsiderar.'}, None, 0)
# ({'start': Timedelta('0 days 00:21:01.540000'), 'end': Timedelta('0 days 00:21:03.360000'), 'text': 'destruiu os Vingadores.'}, None, 0)
# ({'start': Timedelta('0 days 00:21:21.440000'), 'end': Timedelta('0 days 00:21:22.510000'), 'text': 'o que acontece então?'}, None, 0)
# ({'start': Timedelta('0 days 00:21:53.430000'), 'end': Timedelta('0 days 00:21:54.460000'), 'text': 'Gostaria de uma foto?'}, None, 0)
# ({'start': Timedelta('0 days 00:22:07.520000'), 'end': Timedelta('0 days 00:22:08.520000'), 'text': 'Trabalhe comigo, Sam.'}, None, 0)
# ({'start': Timedelta('0 days 00:22:32.540000'), 'end': Timedelta('0 days 00:22:34.370000'), 'text': 'Espera, o quê?'}, None, 0)
# ({'start': Timedelta('0 days 00:22:58.550000'), 'end': Timedelta('0 days 00:23:01.470000'), 'text': 'fizemos o que sempre fazemos.'}, None, 0)
# ({'start': Timedelta('0 days 00:23:01.490000'), 'end': Timedelta('0 days 00:23:03.490000'), 'text': 'Discutimos sobre isso.'}, None, 0)
# ({'start': Timedelta('0 days 00:38:00.360000'), 'end': Timedelta('0 days 00:38:01.400000'), 'text': 'Veja só.'}, None, 0)
# ({'start': Timedelta('0 days 00:39:21.440000'), 'end': Timedelta('0 days 00:39:22.400000'), 'text': 'Alô.'}, None, 0)
# ({'start': Timedelta('0 days 00:49:15.580000'), 'end': Timedelta('0 days 00:49:18.400000'), 'text': 'Redwing, corte a cerca e faça um loop no sistema.'}, None, 0)
# ({'start': Timedelta('0 days 00:49:51.470000'), 'end': Timedelta('0 days 00:49:52.480000'), 'text': 'Droga!'}, None, 0)
# ({'start': Timedelta('0 days 00:53:04.500000'), 'end': Timedelta('0 days 00:53:06.360000'), 'text': 'quero lhe assegurar'}, None, 0)
# ({'start': Timedelta('0 days 00:53:23.390000'), 'end': Timedelta('0 days 00:53:24.540000'), 'text': 'Um homem em um país'}, None, 0)
# ({'start': Timedelta('0 days 01:02:01.530000'), 'end': Timedelta('0 days 01:02:02.550000'), 'text': 'O Presidente me informou'}, None, 0)
# ({'start': Timedelta('0 days 01:05:59.420000'), 'end': Timedelta('0 days 01:06:00.480000'), 'text': 'Ok. Precisamos ir a DC'}, None, 0)
# ({'start': Timedelta('0 days 01:16:50.340000'), 'end': Timedelta('0 days 01:16:52.390000'), 'text': 'Mas nós dois sabemos que você não vai.'}, None, 0)
# ({'start': Timedelta('0 days 01:17:58.480000'), 'end': Timedelta('0 days 01:17:59.500000'), 'text': 'Droga!'}, None, 0)
# ({'start': Timedelta('0 days 01:40:29.350000'), 'end': Timedelta('0 days 01:40:31.350000'), 'text': 'Tem um lugar onde precisamos ir antes.'}, None, 0)
# ({'start': Timedelta('0 days 01:41:30.520000'), 'end': Timedelta('0 days 01:41:31.490000'), 'text': 'para o país.'}, None, 0)
# ({'start': Timedelta('0 days 01:42:21.530000'), 'end': Timedelta('0 days 01:42:22.560000'), 'text': 'Isso é bom.'}, None, 0)
# ({'start': Timedelta('0 days 01:50:56.960000'), 'end': Timedelta('0 days 01:50:58.890000'), 'text': 'Te disse que você ia perder essa aposta.'}, None, 0)
# ({'start': Timedelta('0 days 00:30:58.380000'), 'end': Timedelta('0 days 00:30:59.340000'), 'text': 'Ei.'}, None, 0)
# ({'start': Timedelta('0 days 00:31:01.400000'), 'end': Timedelta('0 days 00:31:02.570000'), 'text': 'E que cara seria esse?'}, None, 0)
# ({'start': Timedelta('0 days 01:04:27.550000'), 'end': Timedelta('0 days 01:04:28.560000'), 'text': 'nos destroços do Harlem.'}, None, 0)
# ({'start': Timedelta('0 days 01:42:42.340000'), 'end': Timedelta('0 days 01:42:43.360000'), 'text': 'É.'}, None, 0)
# ({'start': Timedelta('0 days 01:42:45.450000'), 'end': Timedelta('0 days 01:42:46.490000'), 'text': 'não foi pouca coisa ver você'}, None, 0)
# ({'start': Timedelta('0 days 00:32:27.450000'), 'end': Timedelta('0 days 00:32:28.450000'), 'text': 'Olhe nos meus olhos.'}, None, 0)
# ({'start': Timedelta('0 days 01:42:59.510000'), 'end': Timedelta('0 days 01:43:00.470000'), 'text': 'Nós também.'}, None, 0)
# ({'start': Timedelta('0 days 00:32:38.480000'), 'end': Timedelta('0 days 00:32:40.440000'), 'text': 'Tem algo que você se lembra?'}, None, 0)
# ({'start': Timedelta('0 days 01:43:13.490000'), 'end': Timedelta('0 days 01:43:14.560000'), 'text': 'a cada passo do caminho.'}, None, 0)
# ({'start': Timedelta('0 days 01:43:20.340000'), 'end': Timedelta('0 days 01:43:21.450000'), 'text': 'já perdemos a luta.'}, None, 0)
# ({'start': Timedelta('0 days 00:33:00.390000'), 'end': Timedelta('0 days 00:33:01.530000'), 'text': 'Num momento eu estava sentado,'}, None, 0)
# ({'start': Timedelta('0 days 00:33:37.530000'), 'end': Timedelta('0 days 00:33:39.460000'), 'text': 'Não, você não vai.'}, None, 0)
# ({'start': Timedelta('0 days 01:44:34.420000'), 'end': Timedelta('0 days 01:44:35.550000'), 'text': 'Sabe, fico feliz que você tenha encontrado uma amiga'}, None, 0)
# ({'start': Timedelta('0 days 01:45:12.550000'), 'end': Timedelta('0 days 01:45:14.500000'), 'text': 'Nunca foi abatido no ar'}, None, 0)
# ({'start': Timedelta('0 days 01:45:42.370000'), 'end': Timedelta('0 days 01:45:43.480000'), 'text': 'Ela te consome.'}, None, 0)
# ({'start': Timedelta('0 days 01:46:01.580000'), 'end': Timedelta('0 days 01:46:03.340000'), 'text': 'No lugar onde cresci,'}, None, 0)
# ({'start': Timedelta('0 days 01:07:33.390000'), 'end': Timedelta('0 days 01:07:35.500000'), 'text': 'descobrimos informações no Campo Echo One'}, None, 0)
# ({'start': Timedelta('0 days 00:35:03.500000'), 'end': Timedelta('0 days 00:35:05.370000'), 'text': 'Ah, droga, estou vendo o mesmo acontecendo'}, None, 0)
# ({'start': Timedelta('0 days 01:46:43.370000'), 'end': Timedelta('0 days 01:46:44.380000'), 'text': 'de que você fala?'}, None, 0)
# ({'start': Timedelta('0 days 01:08:22.400000'), 'end': Timedelta('0 days 01:08:24.430000'), 'text': 'Ele colocou você e o Japão um contra o outro'}, None, 0)
# ({'start': Timedelta('0 days 00:36:12.350000'), 'end': Timedelta('0 days 00:36:13.520000'), 'text': 'E se eles quisessem que estivéssemos na Casa Branca?'}, None, 0)
# ({'start': Timedelta('0 days 01:08:33.440000'), 'end': Timedelta('0 days 01:08:34.550000'), 'text': 'de qualquer um que ele quisesse.'}, None, 0)
# ({'start': Timedelta('0 days 00:37:10.400000'), 'end': Timedelta('0 days 00:37:11.400000'), 'text': 'Hmm.'}, None, 0)
# ({'start': Timedelta('0 days 00:37:31.540000'), 'end': Timedelta('0 days 00:37:33.530000'), 'text': 'Não tem como você ter vindo do México'}, None, 0)
# ({'start': Timedelta('0 days 01:47:43.580000'), 'end': Timedelta('0 days 01:47:44.540000'), 'text': 'Ai, não.'}, None, 0)
# ({'start': Timedelta('0 days 01:47:52.360000'), 'end': Timedelta('0 days 01:47:54.420000'), 'text': 'Só estou dizendo, talvez você tenha,'}, None, 0)
# ({'start': Timedelta('0 days 01:09:24.480000'), 'end': Timedelta('0 days 01:09:25.520000'), 'text': 'maldição!'}, None, 0)
# ({'start': Timedelta('0 days 01:09:49.390000'), 'end': Timedelta('0 days 01:09:51.360000'), 'text': 'para que ele pudesse ter sua vida de volta.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:00.140000'), 'end': Timedelta('0 days 01:51:01.530000'), 'text': 'Quer saber o que é engraçado?'}, None, 0)
# ({'start': Timedelta('0 days 01:51:02.080000'), 'end': Timedelta('0 days 01:51:04.450000'), 'text': 'Não tô com humor pra suas piadas.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:04.580000'), 'end': Timedelta('0 days 01:51:07.480000'), 'text': 'Você matou muitos homens bons tentando se vingar.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:07.500000'), 'end': Timedelta('0 days 01:51:10.440000'), 'text': 'Acredite, nós não temos o mesmo senso de humor.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:10.730000'), 'end': Timedelta('0 days 01:51:13.560000'), 'text': 'Mas dividimos o mesmo mundo, não é?'}, None, 0)
# ({'start': Timedelta('0 days 01:51:14.190000'), 'end': Timedelta('0 days 01:51:16.290000'), 'text': 'Esse mundo que você daria sua vida para salvar?'}, None, 0)
# ({'start': Timedelta('0 days 01:51:18.450000'), 'end': Timedelta('0 days 01:51:19.500000'), 'text': 'Ele está vindo.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:20.430000'), 'end': Timedelta('0 days 01:51:22.400000'), 'text': 'Eu vi isso nas probabilidades,'}, None, 0)
# ({'start': Timedelta('0 days 01:51:22.420000'), 'end': Timedelta('0 days 01:51:24.400000'), 'text': 'vi tão claro quanto o dia.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:25.440000'), 'end': Timedelta('0 days 01:51:28.390000'), 'text': 'Todos vocês, heróis, protegendo este mundo...'}, None, 0)
# ({'start': Timedelta('0 days 01:51:29.340000'), 'end': Timedelta('0 days 01:51:30.940000'), 'text': 'acham que são os únicos?'}, None, 0)
# ({'start': Timedelta('0 days 01:51:32.250000'), 'end': Timedelta('0 days 01:51:34.360000'), 'text': 'Acham que este é o único mundo?'}, None, 0)
# ({'start': Timedelta('0 days 01:51:36.230000'), 'end': Timedelta('0 days 01:51:37.430000'), 'text': 'Vamos ver o que acontece'}, None, 0)
# ({'start': Timedelta('0 days 01:51:37.450000'), 'end': Timedelta('0 days 01:51:41.960000'), 'text': 'quando vocês tiverem que proteger este lugar dos outros.'}, None, 0)
# ({'start': Timedelta('0 days 01:10:55.470000'), 'end': Timedelta('0 days 01:10:57.560000'), 'text': 'que havia mais em seu pai.'}, None, 0)
# ({'start': Timedelta('0 days 00:40:32.430000'), 'end': Timedelta('0 days 00:40:33.510000'), 'text': 'diz muito.'}, None, 0)
# ({'start': Timedelta('0 days 00:40:53.390000'), 'end': Timedelta('0 days 00:40:56.490000'), 'text': 'teremos que tomar medidas por conta própria.'}, None, 0)
# ({'start': Timedelta('0 days 00:42:17.340000'), 'end': Timedelta('0 days 00:42:18.360000'), 'text': 'Ah, droga.'}, None, 0)
# ({'start': Timedelta('0 days 00:13:55.360000'), 'end': Timedelta('0 days 00:13:56.360000'), 'text': 'Por que não disse nada?'}, None, 0)
# ({'start': Timedelta('0 days 00:14:05.430000'), 'end': Timedelta('0 days 00:14:06.480000'), 'text': 'O governo dos Estados Unidos'}, None, 0)
# ({'start': Timedelta('0 days 00:44:10.360000'), 'end': Timedelta('0 days 00:44:11.430000'), 'text': 'Solte isso.'}, None, 0)
# ({'start': Timedelta('0 days 00:44:33.510000'), 'end': Timedelta('0 days 00:44:34.540000'), 'text': 'e a resistência.'}, None, 0)
# ({'start': Timedelta('0 days 00:44:36.420000'), 'end': Timedelta('0 days 00:44:37.420000'), 'text': 'certo?'}, None, 0)
# ({'start': Timedelta('0 days 00:45:41.360000'), 'end': Timedelta('0 days 00:45:42.460000'), 'text': 'Estão fora da rede.'}, None, 0)
# ({'start': Timedelta('0 days 00:45:44.380000'), 'end': Timedelta('0 days 00:45:45.520000'), 'text': 'que eu não possa controlar.'}, None, 0)
# ({'start': Timedelta('0 days 00:45:45.540000'), 'end': Timedelta('0 days 00:45:48.380000'), 'text': 'Reúna uma equipe, encontre-o e traga-o para cá.'}, None, 0)
# ({'start': Timedelta('0 days 01:20:12.490000'), 'end': Timedelta('0 days 01:20:14.470000'), 'text': 'foi abatido durante o combate'}, None, 0)
# ({'start': Timedelta('0 days 00:45:50.370000'), 'end': Timedelta('0 days 00:45:51.560000'), 'text': 'Notícia urgente de Washington,'}, None, 0)
# ({'start': Timedelta('0 days 01:20:14.490000'), 'end': Timedelta('0 days 01:20:15.540000'), 'text': 'e está agora em cirurgia'}, None, 0)
# ({'start': Timedelta('0 days 00:16:14.430000'), 'end': Timedelta('0 days 00:16:15.520000'), 'text': 'Enquanto você faz isso,'}, None, 0)
# ({'start': Timedelta('0 days 00:45:59.450000'), 'end': Timedelta('0 days 00:46:00.430000'), 'text': 'Pois é.'}, None, 0)
# ({'start': Timedelta('0 days 01:21:31.420000'), 'end': Timedelta('0 days 01:21:32.400000'), 'text': 'Duas.'}, None, 0)
# ({'start': Timedelta('0 days 01:21:34.370000'), 'end': Timedelta('0 days 01:21:35.380000'), 'text': 'Uau.'}, None, 0)
# ({'start': Timedelta('0 days 00:47:00.570000'), 'end': Timedelta('0 days 00:47:03.400000'), 'text': 'Você já parou para se perguntar'}, None, 0)
# ({'start': Timedelta('0 days 01:22:03.400000'), 'end': Timedelta('0 days 01:22:05.340000'), 'text': 'Mas Joaquin está aqui,'}, None, 0)
# ({'start': Timedelta('0 days 01:22:18.500000'), 'end': Timedelta('0 days 01:22:20.340000'), 'text': 'porque eu não era...'}, None, 0)
# ({'start': Timedelta('0 days 01:22:34.420000'), 'end': Timedelta('0 days 01:22:36.370000'), 'text': 'Ele te deu aquele escudo'}, None, 0)
# ({'start': Timedelta('0 days 01:22:39.360000'), 'end': Timedelta('0 days 01:22:40.440000'), 'text': 'mas porque você é você.'}, None, 0)
# ({'start': Timedelta('0 days 01:22:44.500000'), 'end': Timedelta('0 days 01:22:46.480000'), 'text': 'Você acha que, se tivesse o soro,'}, None, 0)
# ({'start': Timedelta('0 days 00:47:32.550000'), 'end': Timedelta('0 days 00:47:34.500000'), 'text': 'escrita em probabilidades.'}, None, 0)
# ({'start': Timedelta('0 days 01:22:58.520000'), 'end': Timedelta('0 days 01:22:59.520000'), 'text': 'Mas você...'}, None, 0)
# ({'start': Timedelta('0 days 01:23:10.470000'), 'end': Timedelta('0 days 01:23:11.450000'), 'text': 'E aí, gostou?'}, None, 0)
# ({'start': Timedelta('0 days 00:18:24.500000'), 'end': Timedelta('0 days 00:18:26.430000'), 'text': 'E ainda veio com esse xadrez estiloso.'}, None, 0)
# ({'start': Timedelta('0 days 01:23:50.500000'), 'end': Timedelta('0 days 01:23:52.400000'), 'text': '-Isso foi... -Foi.'}, None, 0)
# ({'start': Timedelta('0 days 01:24:08.450000'), 'end': Timedelta('0 days 01:24:09.420000'), 'text': 'Posso trabalhar com isso.'}, None, 0)
# ({'start': Timedelta('0 days 01:24:12.560000'), 'end': Timedelta('0 days 01:24:14.400000'), 'text': 'e o chocante ataque a tiros na'}, None, 0)
# ({'start': Timedelta('0 days 01:24:17.430000'), 'end': Timedelta('0 days 01:24:19.460000'), 'text': 'Isaiah Bradley deve comparecer'}, None, 0)
# ({'start': Timedelta('0 days 01:25:20.510000'), 'end': Timedelta('0 days 01:25:22.540000'), 'text': 'ele irá perturbar seus batimentos cardíacos.'}, None, 0)
# ({'start': Timedelta('0 days 01:25:23.500000'), 'end': Timedelta('0 days 01:25:26.360000'), 'text': 'Não sinto prazer em sua morte,'}, None, 0)
# ({'start': Timedelta('0 days 00:53:28.340000'), 'end': Timedelta('0 days 00:53:29.450000'), 'text': 'Como é?'}, None, 0)
# ({'start': Timedelta('0 days 00:19:56.520000'), 'end': Timedelta('0 days 00:19:57.520000'), 'text': 'Ah...'}, None, 0)
# ({'start': Timedelta('0 days 00:53:52.560000'), 'end': Timedelta('0 days 00:53:54.360000'), 'text': 'O quê...'}, None, 0)
# ({'start': Timedelta('0 days 00:54:06.570000'), 'end': Timedelta('0 days 00:54:09.430000'), 'text': 'que nem percebe que está sendo manipulado.'}, None, 0)
# ({'start': Timedelta('0 days 01:26:32.520000'), 'end': Timedelta('0 days 01:26:34.400000'), 'text': 'Alô?'}, None, 0)
# ({'start': Timedelta('0 days 01:26:42.510000'), 'end': Timedelta('0 days 01:26:44.390000'), 'text': 'Desculpe, eu deveria ter ligado'}, None, 0)
# ({'start': Timedelta('0 days 01:26:47.560000'), 'end': Timedelta('0 days 01:26:48.560000'), 'text': 'Ah...'}, None, 0)
# ({'start': Timedelta('0 days 01:27:32.580000'), 'end': Timedelta('0 days 01:27:36.360000'), 'text': 'Ok. Eu te amo.'}, None, 0)
# ({'start': Timedelta('0 days 00:55:06.430000'), 'end': Timedelta('0 days 00:55:07.430000'), 'text': 'Arrisque-se.'}, None, 0)
# ({'start': Timedelta('0 days 00:55:28.430000'), 'end': Timedelta('0 days 00:55:31.490000'), 'text': 'Havia 89% de chance de você recuar'}, None, 0)
# ({'start': Timedelta('0 days 01:28:23.510000'), 'end': Timedelta('0 days 01:28:24.580000'), 'text': 'você me faria a gentileza'}, None, 0)
# ({'start': Timedelta('0 days 01:28:33.500000'), 'end': Timedelta('0 days 01:28:35.510000'), 'text': 'até os MPs arrastarem sua bunda daqui.'}, None, 0)
# ({'start': Timedelta('0 days 01:28:39.400000'), 'end': Timedelta('0 days 01:28:41.400000'), 'text': 'Agora sou forçado a me entregar'}, None, 0)
# ({'start': Timedelta('0 days 01:28:44.530000'), 'end': Timedelta('0 days 01:28:46.340000'), 'text': 'vamos ficar aqui por um tempo.'}, None, 0)
# ({'start': Timedelta('0 days 01:28:46.360000'), 'end': Timedelta('0 days 01:28:47.560000'), 'text': 'Estou esperando você perceber'}, None, 0)
# ({'start': Timedelta('0 days 00:56:16.450000'), 'end': Timedelta('0 days 00:56:17.450000'), 'text': 'do meu cérebro?'}, None, 0)
# ({'start': Timedelta('0 days 01:29:00.530000'), 'end': Timedelta('0 days 01:29:02.380000'), 'text': 'Senhor, o que tem a dizer sobre os relatos'}, None, 0)
# ({'start': Timedelta('0 days 01:29:04.350000'), 'end': Timedelta('0 days 01:29:05.340000'), 'text': 'devido à sua condução'}, None, 0)
# ({'start': Timedelta('0 days 01:29:06.550000'), 'end': Timedelta('0 days 01:29:09.500000'), 'text': 'Apesar das falsificações que alguns usaram'}, None, 0)
# ({'start': Timedelta('0 days 01:29:42.480000'), 'end': Timedelta('0 days 01:29:44.490000'), 'text': 'É verdade que as hostilidades no Oceano Índico'}, None, 0)
# ({'start': Timedelta('0 days 01:29:46.510000'), 'end': Timedelta('0 days 01:29:48.390000'), 'text': 'que foi, na verdade, seu governo'}, None, 0)
# ({'start': Timedelta('0 days 00:57:26.340000'), 'end': Timedelta('0 days 00:57:27.580000'), 'text': 'para que não me surpreenda de novo.'}, None, 0)
# ({'start': Timedelta('0 days 01:30:15.580000'), 'end': Timedelta('0 days 01:30:16.550000'), 'text': 'Sim.'}, None, 0)
# ({'start': Timedelta('0 days 01:30:25.540000'), 'end': Timedelta('0 days 01:30:26.580000'), 'text': 'Capitão América!'}, None, 0)
# ({'start': Timedelta('0 days 00:59:55.580000'), 'end': Timedelta('0 days 00:59:57.370000'), 'text': 'Querem outro?'}, None, 0)
# ({'start': Timedelta('0 days 00:59:58.520000'), 'end': Timedelta('0 days 01:00:00.450000'), 'text': 'em propriedade governamental restrita.'}, None, 0)
# ({'start': Timedelta('0 days 01:00:40.500000'), 'end': Timedelta('0 days 01:00:41.500000'), 'text': 'Sr. Presidente,'}, None, 0)
# ({'start': Timedelta('0 days 01:31:28.520000'), 'end': Timedelta('0 days 01:31:29.530000'), 'text': 'Senhor.'}, None, 0)
# ({'start': Timedelta('0 days 01:00:59.530000'), 'end': Timedelta('0 days 01:01:00.530000'), 'text': 'Jesus.'}, None, 0)
# ({'start': Timedelta('0 days 01:01:12.490000'), 'end': Timedelta('0 days 01:01:13.460000'), 'text': 'Se chamarmos Ozaki agora,'}, None, 0)
# ({'start': Timedelta('0 days 00:28:35.370000'), 'end': Timedelta('0 days 00:28:36.430000'), 'text': 'Você realmente está defendendo um homem'}, None, 0)
# ({'start': Timedelta('0 days 01:01:39.360000'), 'end': Timedelta('0 days 01:01:41.520000'), 'text': 'Senhor, estamos realmente falando sobre tomar controle'}, None, 0)
# ({'start': Timedelta('0 days 01:01:41.540000'), 'end': Timedelta('0 days 01:01:42.550000'), 'text': 'do adamantium do Japão?'}, None, 0)
# ({'start': Timedelta('0 days 01:01:49.400000'), 'end': Timedelta('0 days 01:01:50.570000'), 'text': 'será o nosso.'}, None, 0)
# ({'start': Timedelta('0 days 00:29:10.580000'), 'end': Timedelta('0 days 00:29:13.390000'), 'text': 'Você não acha que está envolvido demais nisso?'}, None, 0)
# ({'start': Timedelta('0 days 00:29:56.510000'), 'end': Timedelta('0 days 00:29:59.460000'), 'text': '- Então vamos trabalhar juntos. - Receio que essa oferta expirou'}, None, 0)
# ({'start': Timedelta('0 days 01:03:37.370000'), 'end': Timedelta('0 days 01:03:38.370000'), 'text': 'Ouça a conversa.'}, None, 0)
# Total unmatched pairs: 160
# Total pairs: 1667

# %%
count = 0
for _ in aligned_pairs_preprocessed:
    a, b, score = _
    if score == 0:
        count += 1
        print(_)
print(f"Total unmatched pairs: {count}")
print(f"Total pairs: {len(aligned_pairs)}")
# Out:
# ({'start': Timedelta('0 days 00:01:17.560000'), 'end': Timedelta('0 days 00:01:20.580000'), 'text': 'Prontos para Ross! Prontos para Ross!'}, None, 0)
# ({'start': Timedelta('0 days 00:05:56.390000'), 'end': Timedelta('0 days 00:05:57.520000'), 'text': 'Ah.'}, None, 0)
# ({'start': Timedelta('0 days 00:06:37.570000'), 'end': Timedelta('0 days 00:06:38.550000'), 'text': 'Silêncio!'}, None, 0)
# ({'start': Timedelta('0 days 00:06:42.530000'), 'end': Timedelta('0 days 00:06:45.360000'), 'text': 'Vámonos, vámonos.'}, None, 0)
# ({'start': Timedelta('0 days 00:08:42.480000'), 'end': Timedelta('0 days 00:08:44.400000'), 'text': 'Isso não é um problema.'}, None, 0)
# ({'start': Timedelta('0 days 00:09:24.450000'), 'end': Timedelta('0 days 00:09:25.480000'), 'text': 'Nem tanto.'}, None, 0)
# ({'start': Timedelta('0 days 00:10:01.540000'), 'end': Timedelta('0 days 00:10:03.520000'), 'text': 'Uhul!'}, None, 0)
# ({'start': Timedelta('0 days 00:11:40.390000'), 'end': Timedelta('0 days 00:11:41.350000'), 'text': 'Alô.'}, None, 0)
# ({'start': Timedelta('0 days 00:12:08.450000'), 'end': Timedelta('0 days 00:12:09.450000'), 'text': 'O que eles estão dizendo?'}, None, 0)
# ({'start': Timedelta('0 days 00:13:34.470000'), 'end': Timedelta('0 days 00:13:36.420000'), 'text': 'Ainda não descobri como fazer ele calar a boca.'}, None, 0)
# ({'start': Timedelta('0 days 00:14:46.530000'), 'end': Timedelta('0 days 00:14:47.580000'), 'text': 'Esse é dois.'}, None, 0)
# ({'start': Timedelta('0 days 00:19:45.360000'), 'end': Timedelta('0 days 00:19:46.360000'), 'text': 'Ah, meu Deus.'}, None, 0)
# ({'start': Timedelta('0 days 00:20:06.540000'), 'end': Timedelta('0 days 00:20:07.540000'), 'text': 'Hmm.'}, None, 0)
# ({'start': Timedelta('0 days 00:20:29.480000'), 'end': Timedelta('0 days 00:20:31.450000'), 'text': 'Eu só estava fazendo meu trabalho, senhor.'}, None, 0)
# ({'start': Timedelta('0 days 00:21:21.440000'), 'end': Timedelta('0 days 00:21:22.510000'), 'text': 'o que acontece então?'}, None, 0)
# ({'start': Timedelta('0 days 00:21:53.430000'), 'end': Timedelta('0 days 00:21:54.460000'), 'text': 'Gostaria de uma foto?'}, None, 0)
# ({'start': Timedelta('0 days 00:22:07.520000'), 'end': Timedelta('0 days 00:22:08.520000'), 'text': 'Trabalhe comigo, Sam.'}, None, 0)
# ({'start': Timedelta('0 days 00:22:32.540000'), 'end': Timedelta('0 days 00:22:34.370000'), 'text': 'Espera, o quê?'}, None, 0)
# ({'start': Timedelta('0 days 00:30:58.380000'), 'end': Timedelta('0 days 00:30:59.340000'), 'text': 'Ei.'}, None, 0)
# ({'start': Timedelta('0 days 00:33:00.390000'), 'end': Timedelta('0 days 00:33:03.550000'), 'text': 'Num momento eu estava sentado no outro estava em pé naquele parque.'}, None, 0)
# ({'start': Timedelta('0 days 00:37:59.360000'), 'end': Timedelta('0 days 00:38:00.340000'), 'text': 'Hmm.'}, None, 0)
# ({'start': Timedelta('0 days 00:38:00.360000'), 'end': Timedelta('0 days 00:38:01.400000'), 'text': 'Veja só.'}, None, 0)
# ({'start': Timedelta('0 days 00:38:45.520000'), 'end': Timedelta('0 days 00:38:50.450000'), 'text': 'Com que frequência se tem a chance de matar o Capitão América?'}, None, 0)
# ({'start': Timedelta('0 days 00:53:28.340000'), 'end': Timedelta('0 days 00:53:29.450000'), 'text': 'Como é?'}, None, 0)
# ({'start': Timedelta('0 days 00:53:32.340000'), 'end': Timedelta('0 days 00:53:35.360000'), 'text': 'apenas para devolvê-lo a nós em Washington?'}, None, 0)
# ({'start': Timedelta('0 days 00:57:23.480000'), 'end': Timedelta('0 days 00:57:25.570000'), 'text': 'Mas logo você estará fora do tabuleiro,'}, None, 0)
# ({'start': Timedelta('0 days 01:00:59.530000'), 'end': Timedelta('0 days 01:01:00.530000'), 'text': 'Jesus.'}, None, 0)
# ({'start': Timedelta('0 days 01:01:39.360000'), 'end': Timedelta('0 days 01:01:42.550000'), 'text': 'Senhor, estamos realmente falando sobre tomar controle do adamantium do Japão?'}, None, 0)
# ({'start': Timedelta('0 days 01:02:01.530000'), 'end': Timedelta('0 days 01:02:04.380000'), 'text': 'O Presidente me informou que precisamos mobilizar o Grupo de Ataque Cinco.'}, None, 0)
# ({'start': Timedelta('0 days 01:03:57.450000'), 'end': Timedelta('0 days 01:03:59.440000'), 'text': 'Cara macabro, não acha?'}, None, 0)
# ({'start': Timedelta('0 days 01:07:05.470000'), 'end': Timedelta('0 days 01:07:06.490000'), 'text': 'Ele precisa sair disso rápido.'}, None, 0)
# ({'start': Timedelta('0 days 01:09:56.440000'), 'end': Timedelta('0 days 01:09:58.450000'), 'text': 'Eu até tentei transferi-lo, mas...'}, None, 0)
# ({'start': Timedelta('0 days 01:16:50.340000'), 'end': Timedelta('0 days 01:16:52.390000'), 'text': 'Mas nós dois sabemos que você não vai.'}, None, 0)
# ({'start': Timedelta('0 days 01:17:58.480000'), 'end': Timedelta('0 days 01:17:59.500000'), 'text': 'Droga!'}, None, 0)
# ({'start': Timedelta('0 days 01:18:57.580000'), 'end': Timedelta('0 days 01:19:00.420000'), 'text': 'Nada pode te parar, Ross.'}, None, 0)
# ({'start': Timedelta('0 days 01:19:28.540000'), 'end': Timedelta('0 days 01:19:30.480000'), 'text': 'Coloque Ozaki de volta na linha.'}, None, 0)
# ({'start': Timedelta('0 days 01:19:51.440000'), 'end': Timedelta('0 days 01:19:53.340000'), 'text': 'A equipe de evacuação médica acabou de chegar.'}, None, 0)
# ({'start': Timedelta('0 days 01:20:20.500000'), 'end': Timedelta('0 days 01:20:21.550000'), 'text': 'Aqui, me dê essa pinça.'}, None, 0)
# ({'start': Timedelta('0 days 01:20:24.520000'), 'end': Timedelta('0 days 01:20:26.340000'), 'text': 'Sucção!'}, None, 0)
# ({'start': Timedelta('0 days 01:20:27.450000'), 'end': Timedelta('0 days 01:20:29.420000'), 'text': 'Não consigo ver nada. Mais sucção.'}, None, 0)
# ({'start': Timedelta('0 days 01:20:55.340000'), 'end': Timedelta('0 days 01:20:59.500000'), 'text': 'Odeio admitir, mas estou feliz que você esteja aqui.'}, None, 0)
# ({'start': Timedelta('0 days 01:21:06.530000'), 'end': Timedelta('0 days 01:21:09.340000'), 'text': 'Você estava incrível lá fora, cobrindo meu seis.'}, None, 0)
# ({'start': Timedelta('0 days 01:21:09.550000'), 'end': Timedelta('0 days 01:21:11.420000'), 'text': 'Mas então eu vi isso.'}, None, 0)
# ({'start': Timedelta('0 days 01:21:30.340000'), 'end': Timedelta('0 days 01:21:31.390000'), 'text': 'Duas.'}, None, 0)
# ({'start': Timedelta('0 days 01:21:34.370000'), 'end': Timedelta('0 days 01:21:35.380000'), 'text': 'Uau.'}, None, 0)
# ({'start': Timedelta('0 days 01:21:37.470000'), 'end': Timedelta('0 days 01:21:39.560000'), 'text': 'O que me fez pensar que eu poderia seguir isso?'}, None, 0)
# ({'start': Timedelta('0 days 01:22:05.360000'), 'end': Timedelta('0 days 01:22:08.360000'), 'text': 'Isaiah está na prisão, e Sterns...'}, None, 0)
# ({'start': Timedelta('0 days 01:22:16.380000'), 'end': Timedelta('0 days 01:22:20.340000'), 'text': 'Ele quase nos empurrou para a beira da guerra porque eu não era...'}, None, 0)
# ({'start': Timedelta('0 days 01:22:58.520000'), 'end': Timedelta('0 days 01:22:59.520000'), 'text': 'Mas você...'}, None, 0)
# ({'start': Timedelta('0 days 01:23:19.510000'), 'end': Timedelta('0 days 01:23:21.540000'), 'text': 'Olha, preciso pegar um voo.'}, None, 0)
# ({'start': Timedelta('0 days 01:25:18.460000'), 'end': Timedelta('0 days 01:25:22.540000'), 'text': 'Quando eu girar este dial ele irá perturbar seus batimentos cardíacos.'}, None, 0)
# ({'start': Timedelta('0 days 01:25:35.400000'), 'end': Timedelta('0 days 01:25:36.550000'), 'text': 'Eu sou o herói.'}, None, 0)
# ({'start': Timedelta('0 days 01:25:59.370000'), 'end': Timedelta('0 days 01:26:00.430000'), 'text': 'Senhor.'}, None, 0)
# ({'start': Timedelta('0 days 01:26:02.460000'), 'end': Timedelta('0 days 01:26:03.530000'), 'text': 'Agente Taylor.'}, None, 0)
# ({'start': Timedelta('0 days 01:26:11.360000'), 'end': Timedelta('0 days 01:26:12.530000'), 'text': '- Te vejo lá fora. - Sim, senhor.'}, None, 0)
# ({'start': Timedelta('0 days 01:26:32.520000'), 'end': Timedelta('0 days 01:26:34.400000'), 'text': 'Alô?'}, None, 0)
# ({'start': Timedelta('0 days 01:26:34.580000'), 'end': Timedelta('0 days 01:26:37.460000'), 'text': 'Alô. Oi.'}, None, 0)
# ({'start': Timedelta('0 days 01:26:47.560000'), 'end': Timedelta('0 days 01:26:48.560000'), 'text': 'Ah...'}, None, 0)
# ({'start': Timedelta('0 days 01:27:11.340000'), 'end': Timedelta('0 days 01:27:12.340000'), 'text': 'Ahm...'}, None, 0)
# ({'start': Timedelta('0 days 01:27:27.340000'), 'end': Timedelta('0 days 01:27:30.530000'), 'text': 'Sim. Seria bom.'}, None, 0)
# ({'start': Timedelta('0 days 01:28:00.540000'), 'end': Timedelta('0 days 01:28:02.390000'), 'text': 'Boa tarde a todos.'}, None, 0)
# ({'start': Timedelta('0 days 01:41:59.430000'), 'end': Timedelta('0 days 01:42:03.380000'), 'text': 'Sr. Presidente. Como está a nova casa?'}, None, 0)
# ({'start': Timedelta('0 days 01:42:10.560000'), 'end': Timedelta('0 days 01:42:12.540000'), 'text': 'Intencionalmente desconfortável.'}, None, 0)
# ({'start': Timedelta('0 days 01:42:21.530000'), 'end': Timedelta('0 days 01:42:22.560000'), 'text': 'Isso é bom.'}, None, 0)
# ({'start': Timedelta('0 days 01:43:51.460000'), 'end': Timedelta('0 days 01:43:52.500000'), 'text': 'Tudo bem.'}, None, 0)
# ({'start': Timedelta('0 days 01:50:56.960000'), 'end': Timedelta('0 days 01:50:58.890000'), 'text': 'Te disse que você ia perder essa aposta.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:00.140000'), 'end': Timedelta('0 days 01:51:01.530000'), 'text': 'Quer saber o que é engraçado?'}, None, 0)
# ({'start': Timedelta('0 days 01:51:02.080000'), 'end': Timedelta('0 days 01:51:04.450000'), 'text': 'Não tô com humor pra suas piadas.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:04.580000'), 'end': Timedelta('0 days 01:51:07.480000'), 'text': 'Você matou muitos homens bons tentando se vingar.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:07.500000'), 'end': Timedelta('0 days 01:51:10.440000'), 'text': 'Acredite, nós não temos o mesmo senso de humor.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:10.730000'), 'end': Timedelta('0 days 01:51:13.560000'), 'text': 'Mas dividimos o mesmo mundo, não é?'}, None, 0)
# ({'start': Timedelta('0 days 01:51:14.190000'), 'end': Timedelta('0 days 01:51:16.290000'), 'text': 'Esse mundo que você daria sua vida para salvar?'}, None, 0)
# ({'start': Timedelta('0 days 01:51:18.450000'), 'end': Timedelta('0 days 01:51:19.500000'), 'text': 'Ele está vindo.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:20.430000'), 'end': Timedelta('0 days 01:51:24.400000'), 'text': 'Eu vi isso nas probabilidades vi tão claro quanto o dia.'}, None, 0)
# ({'start': Timedelta('0 days 01:51:25.440000'), 'end': Timedelta('0 days 01:51:28.390000'), 'text': 'Todos vocês, heróis, protegendo este mundo...'}, None, 0)
# ({'start': Timedelta('0 days 01:51:29.340000'), 'end': Timedelta('0 days 01:51:30.940000'), 'text': 'acham que são os únicos?'}, None, 0)
# ({'start': Timedelta('0 days 01:51:32.250000'), 'end': Timedelta('0 days 01:51:34.360000'), 'text': 'Acham que este é o único mundo?'}, None, 0)
# ({'start': Timedelta('0 days 01:51:36.230000'), 'end': Timedelta('0 days 01:51:41.960000'), 'text': 'Vamos ver o que acontece quando vocês tiverem que proteger este lugar dos outros.'}, None, 0)
# Total unmatched pairs: 78
# Total pairs: 1667

# %%
avg_offset, max_offset, coverage, mean_score = find_offset_between_subtitles(aligned_pairs)
print(f"Average Offset: {avg_offset:.3f} s")
print(f"Maximum Offset: {max_offset:.3f} s")
print(f"Mean Score: {mean_score:.3f}")

avg_offset, max_offset, coverage, mean_score = find_offset_between_subtitles_percentile(aligned_pairs)
print(f"Average Offset With Most Similarity: {avg_offset:.3f} s")
print(f"Maximum Offset With Most Similarity: {max_offset:.3f} s")
print(f"Mean Score With Most Similarity: {mean_score:.3f}")
# Out:
# Average Offset: 17.706 s
# Maximum Offset: 27.736 s
# Mean Score: 0.757
# Average Offset With Most Similarity: 17.987 s
# Maximum Offset With Most Similarity: 21.256 s
# Mean Score With Most Similarity: 0.910

# %%
# test = [
#     {"start": pd.to_timedelta("00:00:10"), "end": pd.to_timedelta("00:00:12"), "text": "Hello"},
#     {"start": pd.to_timedelta("00:00:13"), "end": pd.to_timedelta("00:00:15"), "text": "World"},
# ]

# shifted = shift_srt(test, 2.0)  # shift by 2 seconds

# for original, new in zip(test, shifted):
#     print(f"Original: {original['start']} → Shifted: {new['start']}")

# %%
EPS_COVERAGE   = 0.0025   # 0.25% coverage improvement threshold
EPS_MEAN_SCORE = 0.01     # 1% mean score improvement threshold
EPS_OFFSET     = 0.05     # 50 ms acceptable offset

plateau_rounds = 0
MAX_PLATEAU_ROUNDS = 2

prev_coverage = 0.0
prev_mean_score = 0.0
prev_avg_offset = float('inf')
prev_max_offset = float('inf')

while True:
    aligned_pairs = align_subtitles_optimal_hungarian(merged_subs_a, merged_subs_b)
    avg_offset, max_offset, coverage, mean_score = find_offset_between_subtitles_percentile(aligned_pairs)

    print(f"Offset: {avg_offset:.3f}s (max: {max_offset:.3f}s)  Coverage: {coverage:.3f}  Mean Score: {mean_score:.3f}")

    # Break if offsets are acceptable
    if abs(avg_offset) < EPS_OFFSET and max_offset < 2*EPS_OFFSET:
        break

    # Apply shift based on average offset (could also try using max_offset)
    merged_subs_a = shift_srt(merged_subs_a, avg_offset)

    # Check for improvement
    coverage_improvement = coverage - prev_coverage
    score_improvement    = mean_score - prev_mean_score
    avg_offset_improvement = prev_avg_offset - abs(avg_offset)  
    max_offset_improvement = prev_max_offset - max_offset  

    if (coverage_improvement < EPS_COVERAGE and
        score_improvement < EPS_MEAN_SCORE and
        avg_offset_improvement < EPS_OFFSET and
        max_offset_improvement < EPS_OFFSET):
        plateau_rounds += 1
        print(f"Plateau detected ({plateau_rounds})")
        if plateau_rounds >= MAX_PLATEAU_ROUNDS:
            print("No further improvement. Stopping.")
            break
    else:
        plateau_rounds = 0  # reset if improvement detected

    prev_coverage = coverage
    prev_mean_score = mean_score
# Out:
# Offset: 17.975s (max: 21.256s)  Coverage: 0.100  Mean Score: 0.910
# Offset: 0.075s (max: 4.303s)  Coverage: 0.100  Mean Score: 0.992
# Offset: -0.000s (max: 4.378s)  Coverage: 0.100  Mean Score: 0.992
# Offset: -0.000s (max: 4.378s)  Coverage: 0.100  Mean Score: 0.992
# Offset: -0.000s (max: 4.378s)  Coverage: 0.100  Mean Score: 0.992
# Offset: -0.000s (max: 4.378s)  Coverage: 0.100  Mean Score: 0.992
# Offset: -0.000s (max: 4.378s)  Coverage: 0.100  Mean Score: 0.992
# Offset: -0.000s (max: 4.378s)  Coverage: 0.100  Mean Score: 0.992
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/rofarate/Thesis/thesis/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_14601/950733643.py", line 14, in <module>
#     aligned_pairs = align_subtitles_optimal_hungarian(merged_subs_a, merged_subs_b)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rofarate/Thesis/src/transform/align_subtitles.py", line None, in align_subtitles_optimal_hungarian
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/rofarate/Thesis/thesis/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2176, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rofarate/Thesis/thesis/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1182, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rofarate/Thesis/thesis/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1053, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rofarate/Thesis/thesis/lib/python3.11/site-packages/IPython/core/ultratb.py", line 861, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rofarate/Thesis/thesis/lib/python3.11/site-packages/IPython/core/ultratb.py", line 773, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rofarate/Thesis/thesis/lib/python3.11/site-packages/IPython/core/ultratb.py", line 536, in format_record
#     assert isinstance(frame_info.lineno, int)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError
