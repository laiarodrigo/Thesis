# %% [markdown]
# **//IMPORTS**

# %%
import os, gzip, requests, time
import pandas as pd
import pathlib, sys
import re
import matplotlib.pyplot as plt

from collections import Counter
from pathlib import Path
from datetime import datetime, timezone
from dotenv import load_dotenv         
from pathlib import Path
from opensubtitlescom import OpenSubtitles
from xmlrpc.client import ServerProxy, Error as XMLRPCError

project_root = pathlib.Path().resolve().parents[0] 
print(f"Project root: {project_root}")
sys.path.insert(0, str(project_root / "src"))
from db import connect     
from extract.access_open_subtitles import download_srt
from transform.align_subtitles import eliminate_new_lines, auto_sync_subs, align_subtitles_optimal_hungarian
from load.load_subtitles import load_subtitles
from catalog import collect_movies
from transform.align_subtitles import merge_subtitle_fragments
# Out:
# Project root: /home/rofarate/Thesis
# OpenSubtitles: logged-in session OK.

# %% [markdown]
# **//CONFIGS**

# %%
load_dotenv()

API_BASE = "https://api.opensubtitles.com/api/v1"
API_KEY = os.getenv("OPENSUBTITLES_API_KEY")
USERNAME = os.getenv("OPENSUBTITLES_USER", "")
PASSWORD = os.getenv("OPENSUBTITLES_PASS", "")
USER_AGENT = "MySubtitleApp/1.0"

# REST headers
# REST_HEADERS = {
#     "Api-Key":     API_KEY,
#     "User-Agent":  USER_AGENT,
#     "Content-Type":"application/json"
# }

# HEAD = {
#     "Api-Key": os.getenv("OPENSUBTITLES_API_KEY"),
#     "User-Agent": "TeseCollector/0.1",
#     "Accept": "application/json",
# }

BASE_HEADERS = {
    "Api-Key":     API_KEY,
    "User-Agent":  "MySubtitleApp/1.0",          # <- descriptive!
    "Accept":      "application/json",           # <- important
    "Content-Type":"application/json",
}
AUTH_HEADERS = dict(BASE_HEADERS)       # will gain 'Authorization' below

# XML-RPC client (fallback path)
ost = OpenSubtitles(user_agent=USER_AGENT, api_key=API_KEY)
# optional login for higher quotas
if USERNAME and PASSWORD:
    try:
        ost.login(USERNAME, PASSWORD)
    except Exception:
        pass

# YEARS AND LANGUAGES

YEARS = range(2023, 2024)          
LANGS = {"pt-br", "pt-pt"}             
by_lang = {lang: {} for lang in LANGS}

TIMEOUT = 15

tokenize = lambda text: re.findall(r"[A-Za-zÀ-ÖØ-öø-ÿ]+", text.lower())

# %%
p = Path("../data/duckdb")
p.mkdir(parents=True, exist_ok=True)

DUCKDB_PATH = Path("../data/duckdb/subs.duckdb")
PROCESSED_DIR = Path("../data/processed")        # <-- where anything derived lands
TIME_WINDOW = 60  

OS_API_KEY = os.getenv("OPENSUBTITLES_API_KEY")

# %%
def td_to_srt(ts) -> str:
    """
    Convert a pandas Timedelta *or* an integer millisecond offset
    to the SRT time-stamp string  HH:MM:SS,mmm
    """
    if isinstance(ts, (int, float)):             # already ms
        total_ms = int(ts)
    else:                                        # Timedelta  → ms
        total_ms = int(ts.total_seconds() * 1000)

    hours,   rem = divmod(total_ms, 3_600_000)
    minutes, rem = divmod(rem,        60_000)
    seconds, ms  = divmod(rem,         1_000)
    return f"{hours:02}:{minutes:02}:{seconds:02},{ms:03}"

def calculate_sentence_difference(row):
    pt_vocab = Counter(tokenize(row.text_pt))
    br_vocab = Counter(tokenize(row.text_br))
    shared   = set(pt_vocab) & set(br_vocab)
    return row.pair_id, shared

# %% [markdown]
# **//MAIN CODE**

# %%
con = connect()                     # ← runs the DDL, makes subs.duckdb
print(con.execute("PRAGMA show_tables").fetchall())
con.close()
# Out:
# [('movies',), ('subtitle_pairs',)]

# %%
total = collect_movies(range(2023, 2024))      # 2023 only
print("movies in DB:", total)
# Out:
# movies in DB: 672

# %%
con = connect()    
movies = con.execute("SELECT imdb_id, title FROM movies").fetchall()
len(movies)
# Out:
# 672

# %%
movies = movies[:10]
print(movies)

for imdb_id, title in movies:
    try:
        movie_id = con.execute(
            "SELECT movie_id FROM movies WHERE imdb_id = ?", 
            [imdb_id]
        ).fetchone()[0]

        # 2) skip if we've already stored pairs for this movie
        already = con.execute(
            "SELECT COUNT(*) FROM subtitle_pairs WHERE movie_id = ?", 
            [movie_id]
        ).fetchone()[0]
        if already:
            print(f"→ Skipping {imdb_id} ({title}), already in DB")
            continue
        # ---- download or reuse cache ------------------------------------
        pt_path = download_srt(imdb_id, "pt-PT", title=title)
        br_path = download_srt(imdb_id, "pt-BR", title=title)

        # ---- load & quick clean -----------------------------------------
        subs_pt = load_subtitles(pt_path)
        subs_br = load_subtitles(br_path)
        eliminate_new_lines(subs_pt)
        eliminate_new_lines(subs_br)

        # ---- sentence-level merge (optional but helps alignment) --------
        subs_pt = merge_subtitle_fragments(subs_pt, gap_threshold=pd.Timedelta(seconds=0.2))
        subs_br = merge_subtitle_fragments(subs_br, gap_threshold=pd.Timedelta(seconds=0.2))

        # ---- auto sync --------------------------------------------------
        shifted_pt, final_offset = auto_sync_subs(subs_pt, subs_br)

        # ---- fine alignment --------------------------------------------
        pairs = align_subtitles_optimal_hungarian(shifted_pt, subs_br)

        rows = []
        pair_no = 1
        for pt, br, score in pairs:
            if br is None:
                continue                   # skip unmatched lines

            rows.append({
                "imdb_id": imdb_id,
                "pair_no":  pair_no,
                #"pair_no":  pair_no,
                # store the raw millis             (handy for SQL filtering)
                "start_pt_ms": int(pt["start"].total_seconds() * 1000),
                "end_pt_ms":   int(pt["end"].total_seconds()   * 1000),
                "start_br_ms": int(br["start"].total_seconds() * 1000),
                "end_br_ms":   int(br["end"].total_seconds()   * 1000),
                # and the pretty SRT strings       (for export / debugging)
                # "start_pt_ms": td_to_srt(pt["start"]),
                # "end_pt_ms":   td_to_srt(pt["end"]),
                # "start_br_ms": td_to_srt(br["start"]),
                # "end_br_ms":   td_to_srt(br["end"]),
                "text_pt": pt["text"],
                "text_br": br["text"],
                "score":   float(score),
            })
            pair_no += 1

        pairs_df = pd.DataFrame(rows)
        #con.execute("DELETE FROM subtitle_pairs WHERE imdb_id = ?", [imdb_id])
        con.register("pairs_df", pairs_df)

        con.execute("""
            INSERT INTO subtitle_pairs (
            movie_id,
            pair_no,
            start_pt_ms,
            end_pt_ms,
            text_pt,
            start_br_ms,
            end_br_ms,
            text_br,
            score
            )
            SELECT
            m.movie_id,
            p.pair_no,
            p.start_pt_ms,
            p.end_pt_ms,
            p.text_pt,
            p.start_br_ms,
            p.end_br_ms,
            p.text_br,
            p.score
            FROM pairs_df AS p
            JOIN movies   AS m
            ON p.imdb_id = m.imdb_id
            """)
        
        print(f"✓ Movie {imdb_id} ({title}) in the database")

    except RuntimeError as e:        # e.g. no subtitles, 5xx after retries
        print("✗", imdb_id, title, "→", e)
    except Exception as e:
        print("⚠️  unexpected failure on", imdb_id, ":", e)
# Out:
# [('14230458', 'Poor Things'), ('15764854', 'Fireworks'), ('26449465', 'Peak Season'), ('19883634', 'The Old Oak'), ('27805677', 'Fairlane'), ('20465746', "L'ultima notte di Amore"), ('26671415', 'Seven Veils'), ('22687790', 'A Haunting in Venice'), ('5478456', 'We Are Zombies'), ('18072882', 'Northern Comfort')]
# → Skipping 14230458 (Poor Things), already in DB
# → Skipping 15764854 (Fireworks), already in DB
# → Skipping 26449465 (Peak Season), already in DB
# → Skipping 19883634 (The Old Oak), already in DB
# Offset +0.110s (max 0.230)  Coverage 0.104  Mean 0.947
# Offset +0.000s (max 0.283)  Coverage 0.104  Mean 0.947
# Offset +0.000s (max 0.283)  Coverage 0.104  Mean 0.947
# plateau → stop
# ✓ Movie 27805677 (Fairlane) in the database
# ⚠️  unexpected failure on 20465746 : 503 Server Error: Service Unavailable for url: https://api.opensubtitles.com/api/v1/download
# Offset -0.002s (max 1.869)  Coverage 0.101  Mean 0.969
# Offset +0.000s (max 1.871)  Coverage 0.101  Mean 0.969
# Offset +0.000s (max 1.871)  Coverage 0.101  Mean 0.969
# plateau → stop
# ✓ Movie 26671415 (Seven Veils) in the database
# Offset +0.000s (max 0.000)  Coverage 0.161  Mean 1.000
# ✓ Movie 22687790 (A Haunting in Venice) in the database
# ⚠️  unexpected failure on 5478456 : 502 Server Error: Bad Gateway for url: https://api.opensubtitles.com/api/v1/download
# Offset +0.000s (max 0.000)  Coverage 0.268  Mean 1.000
# ✓ Movie 18072882 (Northern Comfort) in the database

# %%
df_subtitle_pairs = con.execute("SELECT * FROM subtitle_pairs").df()
print(f"Subtitle pairs in DB: {len(df_subtitle_pairs)}")
low_scores_in_db = df_subtitle_pairs[df_subtitle_pairs.score < 0.4]
medium_scores_in_db = df_subtitle_pairs[(df_subtitle_pairs.score >= 0.4) & (df_subtitle_pairs.score < 0.7)]
high_scores_in_db = df_subtitle_pairs[df_subtitle_pairs.score >= 0.7]
# Out:
# Subtitle pairs in DB: 9161

# %%
pt_pt_vocab = Counter(
    token
    for sent in df_subtitle_pairs.text_pt
    for token in tokenize(sent)
)
pt_br_vocab = Counter(
    token
    for sent in df_subtitle_pairs.text_br
    for token in tokenize(sent)
)

shared       = set(pt_pt_vocab) & set(pt_br_vocab)
unique_pt_pt = set(pt_pt_vocab) - set(pt_br_vocab)
unique_pt_br = set(pt_br_vocab) - set(pt_pt_vocab)

print("Vocab sizes:", len(pt_pt_vocab), len(pt_br_vocab))
print("Shared types:",    len(shared))
print("Unique PT-PT types:", len(unique_pt_pt))
print("Unique PT-BR types:", len(unique_pt_br))

# Top-20 distinctive tokens on each side
pt_pt_distinct = sorted(unique_pt_pt, key=lambda t: pt_pt_vocab[t], reverse=True)[:20]
pt_br_distinct = sorted(unique_pt_br, key=lambda t: pt_br_vocab[t], reverse=True)[:20]
print("Top PT-PT distinct:", pt_pt_distinct)
print("Top PT-BR distinct:", pt_br_distinct)
# Out:
# Vocab sizes: 7157 6740
# Shared types: 4482
# Unique PT-PT types: 2675
# Unique PT-BR types: 2258
# Top PT-PT distinct: ['estás', 'tens', 'sabes', 'vos', 'queres', 'podes', 'pá', 'ca', 'vais', 'mna', 'contigo', 'porquê', 'pára', 'demasiado', 'câmara', 'totò', 'véni', 'fizeste', 'sítio', 'facto']
# Top PT-BR distinct: ['font', 'color', 'ffff', 'pra', 'srta', 'falando', 'tá', 'indo', 'tentando', 'câmera', 'acontecendo', 'peguei', 'h', 'entende', 'detalhes', 'vendo', 'né', 'ouvindo', 'trabalhando', 'entendi']

# %% [markdown]
# **//GOOD SCORES ANALYSIS**

# %%
good_row_count = len(high_scores_in_db)
print(f"Subtitle pairs in DB: {good_row_count}")
high_scores_in_db
# Out:
# Subtitle pairs in DB: 5735
#       pair_id  movie_id  pair_no  start_pt_ms  end_pt_ms  \
# 0           1         1        1          980       5938
# 1           2         1        2       111772     118272
# 2           3         1        3       286522     288480
# 5           6         1        6       301147     305605
# 6           7         1        7       305772     310772
# ...       ...       ...      ...          ...        ...
# 9156     9157        10     1162      5270708    5273916
# 9157     9158        10     1163      5275708    5278916
# 9158     9159        10     1164      5279000    5280708
# 9159     9160        10     1165      5280791    5282125
# 9160     9161        10     1166      5284416    5285500
#
#                                                 text_pt  start_br_ms  \
# 0           CONTÉM REPRESENTAÇÕES DE PRODUTOS DE TABACO         1000
# 1                                      POBRES CRIATURAS       111800
# 2                                                Adeus!       286542
# 5               Quem gostaria de reconstruir os órgãos?       301167
# 6     E quem consegue distinguir humano de animal, i...       305792
# ...                                                 ...          ...
# 9156  Estaremos a comer Currywurst em Römerberg ante...      5270708
# 9157  Muito bem! Segurem-se bem, pessoal. Vai ficar ...      5275708
# 9158                                 Muito bem, jóquei.      5279000
# 9159                               Pronto para evacuar.      5280791
# 9160                                  -Estás bem? -Sim.      5284416
#
#       end_br_ms                                            text_br    score
# 0          6000                          HÁ CENAS DE USO DE TABACO  0.71290
# 1        118100                                   POBRES CRIATURAS  0.99986
# 2        288500                                             Adeus.  0.88090
# 5        305625         Bem, quem gostaria de recolocar os órgãos?  0.85290
# 6        310792  E quem pode distinguir o humano do animal, se ...  0.87390
# ...         ...                                                ...      ...
# 9156    5273916  Estaremos comendo Currywurst em Römerberg ante...  0.84600
# 9157    5278916  Muito bem! Segurem-se bem, pessoal. Vai ficar ...  0.95800
# 9158    5280708                                 Muito bem, jóquei.  1.00000
# 9159    5282125                               Pronto para evacuar.  1.00000
# 9160    5285500                              -Você está bem? -Sim.  0.85300
#
# [5735 rows x 10 columns]

# %% [markdown]
# **//BAD SCORES ANALYSIS**

# %%
bad_row_count = len(low_scores_in_db)
print(f"Low-score pairs in DB: {bad_row_count}")
low_scores_in_db
# Out:
# Low-score pairs in DB: 161
#       pair_id  movie_id  pair_no  start_pt_ms  end_pt_ms  \
# 192       193         1      193      1352272    1353355
# 401       402         1      402      2526522    2527688
# 1186     1187         1     1187      6586480    6587355
# 1206     1207         1     1207      6667938    6670688
# 1244     1245         1     1245      6846647    6847522
# ...       ...       ...      ...          ...        ...
# 6454     6455         7     1055      5247851    5249251
# 6517     6518         7     1118      5764033    5765535
# 6523     6524         7     1124      5798901    5801137
# 7699     7700         8     1137      4616250    4618208
# 8437     8438        10      443      1935291    1936750
#
#                                        text_pt  start_br_ms  end_br_ms  \
# 192                             E para sempre.      1363667    1367458
# 401                               Uma pândega!      2526542    2527708
# 1186                      Armou-me uma cilada!      6549125    6552542
# 1206                   {\an8}FALECIDO em Breve      6641500    6644292
# 1244                                    Cabra!      6835167    6836167
# ...                                        ...          ...        ...
# 6454                            Ooh. Incrível.      5241347    5242348
# 6517                  -A venda é transparente.      5799071    5800072
# 6523                             -Sinto muito.      5833189    5834273
# 7699  Porque é que ele tinha de estar sozinho?      4565333    4567000
# 8437                                  A sério.      1935291    1936750
#
#                                               text_br     score
# 192   ou prisões mal equipadas e poucos funcionários?  0.355025
# 401                                          Delícia.  0.369900
# 1186     Um diabo em um corpo sedutor e insaciável...  0.330225
# 1206                       Idiota com cara de boceta.  0.370810
# 1244                                             Bam.  0.382600
# ...                                               ...       ...
# 6454                                      Como assim?  0.379480
# 6517                                        Desculpa.  0.334810
# 6523                                          Pronto?  0.338560
# 7699                 O que aconteceu? O que deu nele?  0.339415
# 8437                                       Realmente.  0.377000
#
# [161 rows x 10 columns]

# %% [markdown]
# **//MEDIUM SCORES ANALYSIS**

# %%
medium_row_count = len(medium_scores_in_db)
print(f"Medium-score pairs in DB: {medium_row_count}")
medium_scores_in_db
# Out:
# Medium-score pairs in DB: 3265
#       pair_id  movie_id  pair_no  start_pt_ms  end_pt_ms  \
# 3           4         1        4       291647     297688
# 4           5         1        5       297855     300688
# 7           8         1        8       313938     314772
# 8           9         1        9       315480     318813
# 13         14         1       14       333897     336063
# ...       ...       ...      ...          ...        ...
# 9049     9050        10     1055      4764000    4765416
# 9085     9086        10     1091      4960416    4964666
# 9090     9091        10     1096      4972416    4974416
# 9130     9131        10     1136      5103833    5110416
# 9141     9142        10     1147      5150458    5151791
#
#                                                 text_pt  start_br_ms  \
# 3     Uma pilha de órgãos sem a centelha de humanida...       291667
# 4       Parece a banca de um talhante para um banquete.       297875
# 7                                                Vá lá!       313958
# 8                   Fizeram puzzles em crianças, certo?       315500
# 13               A tua proximidade não quer dizer nada.       333917
# ...                                                 ...          ...
# 9049                      Está bem, está bem, está bem!      4764000
# 9085  Não é? Posso arranjar-vos uma estadia num hote...      4960416
# 9090                         Tens de nos pôr nesse voo.      4972416
# 9130  Olha, eu interpretei mal a situação e... Peço ...      5103833
# 9141                                  Eu vou-me embora.      5150458
#
#       end_br_ms                                            text_br   score
# 3        295458  Um monte de órgãos sem a centelha de si na men...  0.6779
# 4        300708  É só um prato do açougueiro para o almoço de d...  0.5519
# 7        314792                                             Vamos!  0.5309
# 8        318833      Montavam quebra-cabeças quando crianças, não?  0.6499
# 13       336083  Sua proximidade física conosco não o inclui nela.  0.6989
# ...         ...                                                ...     ...
# 9049    4765416                                        Ok, ok, ok!  0.4750
# 9085    4964666  Certo? Posso providenciar para que você se hos...  0.6780
# 9090    4974416              Você tem que nos colocar naquele voo.  0.6990
# 9130    5110416  Veja, eu interpretei a situação de forma total...  0.6780
# 9141    5151791                                     Eu estou indo.  0.6640
#
# [3265 rows x 10 columns]

# %%
sentence_difference = {}
different_sentence_count = 0

for row in medium_scores_in_db.itertuples():
    pid, shared = calculate_sentence_difference(row)
    sentence_difference[pid] = shared

print("Sentence more different:")
for pid, shared in sentence_difference.items():
    if len(shared) < 2:  # threshold for "more different"
        different_sentence_count += 1
        print(f"Sentence in PT, ", medium_scores_in_db.loc[medium_scores_in_db.pair_id == pid, 'text_pt'].values[0])
        print(f"Sentence in BR, ", medium_scores_in_db.loc[medium_scores_in_db.pair_id == pid, 'text_br'].values[0])

print(f"Total number of super different sentences: {different_sentence_count}")
# Out:
# Sentence more different:
# Sentence in PT,  Vá lá!
# Sentence in BR,  Vamos!
# Sentence in PT,  Fizeram puzzles em crianças, certo?
# Sentence in BR,  Montavam quebra-cabeças quando crianças, não?
# Sentence in PT,  Não chateies! Vai comprar um fato.
# Sentence in BR,  Vá se foder, velho amigo. Consiga um traje.
# Sentence in PT,  Ia gostar bastante.
# Sentence in BR,  Adoraria isso.
# Sentence in PT,  A piada é minha.
# Sentence in BR,  Foi uma piada que inventei.
# Sentence in PT,  Parece obra do demónio.
# Sentence in BR,  Servo do diabo!
# Sentence in PT,  Se deixasse crescer a barba?
# Sentence in BR,  Já pensou em ficar com barba, senhor?
# Sentence in PT,  Este trabalho.
# Sentence in BR,  Trabalha aqui.
# Sentence in PT,  Sim. Vamos.
# Sentence in BR,  Sim. Entre.
# Sentence in PT,  E eu reparei-a.
# Sentence in BR,  Notei.
# Sentence in PT,  Tenho de anotar os progressos meticulosamente.
# Sentence in BR,  Preciso anotar minuciosamente seu progresso.
# Sentence in PT,  Pode ajudar-me a fazer isso?
# Sentence in BR,  Fará isso por mim?
# Sentence in PT,  Por acaso até gosto.
# Sentence in BR,  Nem sempre os aprecio, na verdade.
# Sentence in PT,  Quando acrescentar questões idiotas, avisar-te-ei.
# Sentence in BR,  Quando quiser perguntas fúteis, lhe avisarei.
# Sentence in PT,  O que ser isso? Nenhures?
# Sentence in BR,  Onde é lugar nenhum?
# Sentence in PT,  Então cortares pais?
# Sentence in BR,  Matou meus pais, God?
# Sentence in PT,  Eles expandiram as fronteiras do conhecimento e pagaram caro por isso.
# Sentence in BR,  Ultrapassaram os limites do que era conhecido...
# Sentence in PT,  Isto, pais.
# Sentence in BR,  Aqui, meus pais.
# Sentence in PT,  Porquê escrever cada fruto?
# Sentence in BR,  Por que anota cada noz que como?
# Sentence in PT,  Só...
# Sentence in BR,  Espere...
# Sentence in PT,  Valha-me Deus!
# Sentence in BR,  Santo Deus!
# Sentence in PT,  Bella comer gelado querer.
# Sentence in BR,  Bella quer pegar sorvete.
# Sentence in PT,  Rir da minha cara.
# Sentence in BR,  Vão rir de God.
# Sentence in PT,  Deveras.
# Sentence in BR,  Isso mesmo.
# Sentence in PT,  Só não.
# Sentence in BR,  Apenas não.
# Sentence in PT,  Valha-me Deus!
# Sentence in BR,  Mãe de Deus.
# Sentence in PT,  Está a escondê-la porquê?
# Sentence in BR,  Por que a esconde?
# Sentence in PT,  Deus do Céu!
# Sentence in BR,  Jesus!
# Sentence in PT,  Tens de parar de fazer isso.
# Sentence in BR,  Pare com isso imediatamente.
# Sentence in PT,  Não comeste.
# Sentence in BR,  você não comeu nada.
# Sentence in PT,  Não!
# Sentence in BR,  Não faça.
# Sentence in PT,  Sentir esquisito?
# Sentence in BR,  Se sente divertido?
# Sentence in PT,  A que disseste...
# Sentence in BR,  Ao aceitar isso...
# Sentence in PT,  Este Contrato Atesta
# Sentence in BR,  <i>Farei um contrato legal.</i>
# Sentence in PT,  Asseguro que tem valor legal na mesma.
# Sentence in BR,  Isso é irrelevante para sua validade, eu garanto.
# Sentence in PT,  Não consegue aguentar? É alguma criança?
# Sentence in BR,  Você tem cinco anos pra não conseguir segurar um pouco?
# Sentence in PT,  É bastante bom!
# Sentence in BR,  Ficou bem e ridículo.
# Sentence in PT,  Estou a ver.
# Sentence in BR,  Entendo a razão.
# Sentence in PT,  Compreendo porquê.
# Sentence in BR,  Entendi.
# Sentence in PT,  Nem pense...
# Sentence in BR,  Não vai...
# Sentence in PT,  Tu ser quem?
# Sentence in BR,  Quem é você?
# Sentence in PT,  Trepei.
# Sentence in BR,  Escalei.
# Sentence in PT,  Não queiras saber de modos.
# Sentence in BR,  Não se importe com essa educação
# Sentence in PT,  É muito aborrecido.
# Sentence in BR,  É chata pra cacete.
# Sentence in PT,  Aquele cão asqueroso.
# Sentence in BR,  Aquele cachorro deformado.
# Sentence in PT,  Essa mesma.
# Sentence in BR,  Falo dessa Lisboa.
# Sentence in PT,  Pergunto-te a ti.
# Sentence in BR,  Estou perguntando a você.
# Sentence in PT,  Sem dúvida... que não.
# Sentence in BR,  Absolutamente... não!
# Sentence in PT,  Vou deter-te.
# Sentence in BR,  Eu impedirei.
# Sentence in PT,  Prendes Bella com muita força.
# Sentence in BR,  Você prende Bella demais.
# Sentence in PT,  Preciso de ver o mundo.
# Sentence in BR,  Preciso sair pelas águas.
# Sentence in PT,  Não pode ser!
# Sentence in BR,  Não é aceitável.
# Sentence in PT,  Eu mesmo trato dele.
# Sentence in BR,  Vou atrás desse homem.
# Sentence in PT,  Vou esmagar-lhe o crânio!
# Sentence in BR,  Vou moer a porra da cabeça dele.
# Sentence in PT,  Adeus, futura pomba.
# Sentence in BR,  Até mais tarde pombinho.
# Sentence in PT,  Ela partiu.
# Sentence in BR,  Ela se foi.
# Sentence in PT,  É dizer pouco.
# Sentence in BR,  Ela subestima isso.
# Sentence in PT,  Chupar e engolir.
# Sentence in BR,  Abra, vire e sugue.
# Sentence in PT,  Uma pândega.
# Sentence in BR,  Delícia.
# Sentence in PT,  Tenho pena de ti.
# Sentence in BR,  Sinto por você.
# Sentence in PT,  Bem, então serás o meu escolhido para brincar.
# Sentence in BR,  Então serão só com você os saltos furiosos.
# Sentence in PT,  Brincar?
# Sentence in BR,  Saltos furiosos?
# Sentence in PT,  Outra vez?
# Sentence in BR,  De novo?
# Sentence in PT,  Percebo.
# Sentence in BR,  Entendo.
# Sentence in PT,  Não.
# Sentence in BR,  Isso não.
# Sentence in PT,  O elétrico.
# Sentence in BR,  O bonde.
# Sentence in PT,  Foi um espanto.
# Sentence in BR,  Surpresa para Bella.
# Sentence in PT,  É encantador.
# Sentence in BR,  É tão charmoso.
# Sentence in PT,  Incrivelmente sagaz!
# Sentence in BR,  Muito inspirada!
# Sentence in PT,  Adorei!
# Sentence in BR,  Amei
# Sentence in PT,  És tão perversa.
# Sentence in BR,  Você é travessa.
# Sentence in PT,  Estás a falar do pénis dele.
# Sentence in BR,  Oh... quer dizer o pênis dele.
# Sentence in PT,  É encantador.
# Sentence in BR,  o bebê incomodando...
# Sentence in PT,  Deus me valha!
# Sentence in BR,  Meu Deus.
# Sentence in PT,  - Será? - Será?
# Sentence in BR,  - Acha que estão fodendo?
# Sentence in PT,  E...
# Sentence in BR,  E ainda...
# Sentence in PT,  {\an8}a engolir um elétrico.
# Sentence in BR,  chupando um bonde.
# Sentence in PT,  E estou esfomeada!
# Sentence in BR,  Também estou morrendo de fome para jantar.
# Sentence in PT,  Onde diabos te meteste?
# Sentence in BR,  Onde porra você estava?
# Sentence in PT,  Vamos?
# Sentence in BR,  Podemos ir?
# Sentence in PT,  Pede o que te apetece.
# Sentence in BR,  Peça seu favorito.
# Sentence in PT,  <i>Touché!</i>
# Sentence in BR,  Touché.
# Sentence in PT,  Estás a fazer isso porquê?
# Sentence in BR,  Por que faz isso?
# Sentence in PT,  Pisquei também.
# Sentence in BR,  Eu retribuo.
# Sentence in PT,  És louca!
# Sentence in BR,  Está muito louca.
# Sentence in PT,  Não fales! Estás a irritar Bella!
# Sentence in BR,  Pare de falar. Sua voz deixa Bella brava!
# Sentence in PT,  Quando preciso...
# Sentence in BR,  Tudo bem.
# Sentence in PT,  Achei que não seriam igualmente macias.
# Sentence in BR,  Me perguntei se talvez não fossem iguais em suavidade.
# Sentence in PT,  E a brincadeira com a língua que me ias fazer?
# Sentence in BR,  Não vai mais brincar de língua?
# Sentence in PT,  Sua...
# Sentence in BR,  Você...
# Sentence in PT,  Estás perturbado.
# Sentence in BR,  Está com problemas.
# Sentence in PT,  Estiveste a brincar com ele?
# Sentence in BR,  Pulou furiosamente nele?
# Sentence in PT,  Acho que fui afetado.
# Sentence in BR,  Devo ter inalado muito.
# Sentence in PT,  Temos de meter de lado os nossos sentimentos.
# Sentence in BR,  Acha que meu pai teria me marcado...
# Sentence in PT,  Ferros em brasa?
# Sentence in BR,  Sentimentos devem ser deixados de lado.
# Sentence in PT,  Anda despir-me.
# Sentence in BR,  Venha, tire minha roupa.
# Sentence in PT,  Azul, azul, azul.
# Sentence in BR,  Azul. Azul. Azul.
# Sentence in PT,  Pássaro idiota!
# Sentence in BR,  Filho da puta!
# Sentence in PT,  É verdade para ti?
# Sentence in BR,  É o mesmo com você?
# Sentence in PT,  Fiquei sem tinta.
# Sentence in BR,  Acabou a tinta.
# Sentence in PT,  Também reparei no teu.
# Sentence in BR,  Também notei seu cabelo.
# Sentence in PT,  Não.
# Sentence in BR,  Não, ele não.
# Sentence in PT,  São ótimas notícias.
# Sentence in BR,  É notícia tranquilizadora.
# Sentence in PT,  Encantador.
# Sentence in BR,  Será um prazer.
# Sentence in PT,  Escolheste-me a mim.
# Sentence in BR,  Você me escolheu em vez dele.
# Sentence in PT,  Por agora.
# Sentence in BR,  Pelo momento.
# Sentence in PT,  Ela está a evoluir.
# Sentence in BR,  Está aprendendo.
# Sentence in PT,  Felicity.
# Sentence in BR,  Boa sorte.
# Sentence in PT,  Mais devagar. Ou nem por isso.
# Sentence in BR,  Nem tão rápido.
# Sentence in PT,  É integrante.
# Sentence in BR,  Isso é básico.
# Sentence in PT,  Vamos apanhar ar
# Sentence in BR,  vamos entrar um pouco...
# Sentence in PT,  Anda. Vem comigo.
# Sentence in BR,  Venha. Venha. Só venha.
# Sentence in PT,  Estás a tapar-me o sol.
# Sentence in BR,  Está fazendo sombra.
# Sentence in PT,  Anda.
# Sentence in BR,  Venha.
# Sentence in PT,  Que excitação!
# Sentence in BR,  Excitante.
# Sentence in PT,  E isso tirou-me o sono.
# Sentence in BR,  e digo que não.
# Sentence in PT,  Eu mostro-te.
# Sentence in BR,  Vou mostrar a você.
# Sentence in PT,  Temos de os ir ajudar.
# Sentence in BR,  Precisamos ajudá-los.
# Sentence in PT,  Podemos tratar disso por si.
# Sentence in BR,  Cuidaremos disso para você.
# Sentence in PT,  Toda a gente precisa.
# Sentence in BR,  Todos eles.
# Sentence in PT,  Levei o dinheiro.
# Sentence in BR,  Eu peguei.
# Sentence in PT,  Estou mental e emocionalmente exausta, Wedderburn.
# Sentence in BR,  pisoteada, Duncan Wedderburn...
# Sentence in PT,  Com certeza.
# Sentence in BR,  Certamente, senhor.
# Sentence in PT,  Dei-o àquelas pessoas.
# Sentence in BR,  Dei para os pobres lá fora.
# Sentence in PT,  Tu...
# Sentence in BR,  Você...
# Sentence in PT,  Acabei de te dizer.
# Sentence in BR,  Já disse.
# Sentence in PT,  Ela está um trapo.
# Sentence in BR,  Está destroçada.
# Sentence in PT,  Não, eu queria magoar-te.
# Sentence in BR,  Não. Na verdade, quis chocar você.
# Sentence in PT,  A questão é essa.
# Sentence in BR,  Este é o ponto essencial.
# Sentence in PT,  A nossa espécie está acabada.
# Sentence in BR,  Somos uma espécie fodida.
# Sentence in PT,  Claro que estás.
# Sentence in BR,  É claro.
# Sentence in PT,  não seja das melhores,
# Sentence in BR,  Mesmo que seja verdade que minha habilidade...
# Sentence in PT,  Tu cobras trinta.
# Sentence in BR,  Você cobra 30 deles.
# Sentence in PT,  Ficamos todos contentes.
# Sentence in BR,  E todos ficam felizes.
# Sentence in PT,  Estou a ver.
# Sentence in BR,  Entendo.
# Sentence in PT,  Vai lá.
# Sentence in BR,  Vamos.
# Sentence in PT,  Anda lá!
# Sentence in BR,  Então, vá em frente.
# Sentence in PT,  Compreendo.
# Sentence in BR,  Entendo.
# Sentence in PT,  mas tenho alguma curiosidade.
# Sentence in BR,  este é o caminho mais curto.
# Sentence in PT,  Como te chamas?
# Sentence in BR,  Qual é seu nome?
# Sentence in PT,  Tive de conter uma risada.
# Sentence in BR,  Segurei o riso...
# Sentence in PT,  Vim a rir o caminho todo. Fui comprar estes <i>éclairs.</i>
# Sentence in BR,  Sorri quando peguei esses éclairs...
# Sentence in PT,  E pensei carinhosamente
# Sentence in BR,  e lembrei com tanto carinho...
# Sentence in PT,  para me esfrangalhar o espírito.
# Sentence in BR,  para rasgar minha alma em pedaços.
# Sentence in PT,  Prostituíste-te!
# Sentence in BR,  Se prostituiu.
# Sentence in PT,  Alguma vez me vais elogiar?
# Sentence in BR,  Nunca mais vou ter elogios de você?
# Sentence in PT,  Não podemos mesmo casar.
# Sentence in BR,  Definitivamente, nunca deveremos nos casar.
# Sentence in PT,  Cadela!
# Sentence in BR,  Piranha!
# Sentence in PT,  Tiveste dinheiro contigo
# Sentence in BR,  Você tinha dinheiro...
# Sentence in PT,  Foi o God que me deu.
# Sentence in BR,  É dinheiro do God.
# Sentence in PT,  Foste tu que me avariaste!
# Sentence in BR,  Você quebrou algo em mim!
# Sentence in PT,  Sinto que estamos a andar em círculos.
# Sentence in BR,  Esta conversa virou círculo vicioso.
# Sentence in PT,  Cabra!
# Sentence in BR,  Piranha!
# Sentence in PT,  Anda.
# Sentence in BR,  Venha.
# Sentence in PT,  Uma iguaria.
# Sentence in BR,  Um filé mignon.
# Sentence in PT,  Mudar o mundo.
# Sentence in BR,  <i>Une personne qui veut... change the world pour le meilleur.</i>
# Sentence in PT,  Madame Swiney!
# Sentence in BR,  Senhora Swiney...
# Sentence in PT,  Meu Deus! És linda!
# Sentence in BR,  Deus, como está bonita.
# Sentence in PT,  O trabalho assenta-te que nem uma luva.
# Sentence in BR,  quando pulasse nelas.
# Sentence in PT,  Não preferia fazê-lo por escolha da mulher,
# Sentence in BR,  Não prefere que as mulheres escolham?
# Sentence in PT,  pois seria sinal de entusiasmo em relação à sua pessoa?
# Sentence in BR,  Mostrando algum entusiasmo a você?
# Sentence in PT,  Toinette, és muito impertinente.
# Sentence in BR,  Toinette, é inteligente ao abrir a boca.
# Sentence in PT,  Tenho...
# Sentence in BR,  Eu preciso...
# Sentence in PT,  Desculpa. Fiz sangue.
# Sentence in BR,  Oh, sinto. Tirei sangue.
# Sentence in PT,  Toma.
# Sentence in BR,  Pegue.
# Sentence in PT,  És encantadora.
# Sentence in BR,  E tão graciosa.
# Sentence in PT,  Não queres? És encantadora!
# Sentence in BR,  não só o que é bom.
# Sentence in PT,  Um jogo?
# Sentence in BR,  Um teste?
# Sentence in PT,  Truz, truz!
# Sentence in BR,  Um abraço e um "queijo".
# Sentence in PT,  É uma meia que cheira a chulé.
# Sentence in BR,  Depois uma rápida cheirada...
# Sentence in PT,  Já conhecias?
# Sentence in BR,  Você sabia esta.
# Sentence in PT,  Cheiras bem.
# Sentence in BR,  Seu cheiro não é ruim.
# Sentence in PT,  Queres fazer o quê?
# Sentence in BR,  Deseja o que?
# Sentence in PT,  Compreendo.
# Sentence in BR,  Entendo.
# Sentence in PT,  Ou um pouco de estrangulamento.
# Sentence in BR,  Ou leve asfixia pode servir.
# Sentence in PT,  Eu sabia!
# Sentence in BR,  Fez sim. Eu sei!
# Sentence in PT,  São duas rameiras!
# Sentence in BR,  Vocês são putas.
# Sentence in PT,  Somos mulheres independentes.
# Sentence in BR,  Temos nosso próprio meio de sobrevivência.
# Sentence in PT,  Tem calma.
# Sentence in BR,  E me feche.
# Sentence in PT,  Podes suturar.
# Sentence in BR,  Quieto agora.
# Sentence in PT,  Tens de persistir.
# Sentence in BR,  Você deve superar isso...
# Sentence in PT,  Estou a ver.
# Sentence in BR,  Entendo.
# Sentence in PT,  E isso também.
# Sentence in BR,  É isso.
# Sentence in PT,  Ela deixou-me vazio por dentro!
# Sentence in BR,  Ela esvaziou.
# Sentence in PT,  Cantemos?
# Sentence in BR,  Vamos cantar?
# Sentence in PT,  Não era minha intenção.
# Sentence in BR,  Não quero que seja assim.
# Sentence in PT,  Mas fui forçado.
# Sentence in BR,  Você me força a isso.
# Sentence in PT,  Vou perguntar-lhe educadamente.
# Sentence in BR,  Peço da forma mais educada que posso.
# Sentence in PT,  Estou a ver.
# Sentence in BR,  Entendo.
# Sentence in PT,  E foste cobarde.
# Sentence in BR,  Foram muito covardes nisso.
# Sentence in PT,  Lamento.
# Sentence in BR,  me desculpando.
# Sentence in PT,  Bell rameira.
# Sentence in BR,  <i>Bell puta</i>
# Sentence in PT,  - Mas gosto desta. - Bell rameira.
# Sentence in BR,  <i>- Cai muito bem. - Bell puta.</i>
# Sentence in PT,  Bell rameira.
# Sentence in BR,  <i>Bell puta</i>
# Sentence in PT,  Bell rameira.
# Sentence in BR,  <i>Bell puta</i>
# Sentence in PT,  Tiveste.
# Sentence in BR,  Tinha.
# Sentence in PT,  Vou ser médica.
# Sentence in BR,  Sabia o que vem a seguir.
# Sentence in PT,  Não te sintas obrigada.
# Sentence in BR,  Não temos compromisso.
# Sentence in PT,  Fui uma rameira, percebes?
# Sentence in BR,  Sou uma puta, entende?
# Sentence in PT,  Vais aceitar isso?
# Sentence in BR,  Tudo bem com isso?
# Sentence in PT,  És livre de te entregares a quem quiseres.
# Sentence in BR,  Seu, para usar livremente.
# Sentence in PT,  Acho.
# Sentence in BR,  Acredito.
# Sentence in PT,  Caso.
# Sentence in BR,  Sim.
# Sentence in PT,  Mas, no geral, é agradável.
# Sentence in BR,  desde que a use de forma agradável.
# Sentence in PT,  E já foste examinada?
# Sentence in BR,  Foi examinada para detectar doenças?
# Sentence in PT,  Estás a andar!
# Sentence in BR,  God, está caminhando!
# Sentence in PT,  Quando soube que tinhas desaparecido, fiquei desfeito.
# Sentence in BR,  Ao descobrir sua ausência, me senti estripado.
# Sentence in PT,  És mesmo tu.
# Sentence in BR,  Aqui está.
# Sentence in PT,  Isso dói.
# Sentence in BR,  É doloroso.
# Sentence in PT,  Bella, desculpa.
# Sentence in BR,  Bella, sinto muito.
# Sentence in PT,  Temo uma rebelião.
# Sentence in BR,  Vamos, então.
# Sentence in PT,  Conheces-me?
# Sentence in BR,  Você me conhece?
# Sentence in PT,  Eu era simpática?
# Sentence in BR,  Era gentil?
# Sentence in PT,  Os teus preferidos.
# Sentence in BR,  Tudo que aprecia.
# Sentence in PT,  Detestaste o bebé.
# Sentence in BR,  Odiava o bebê.
# Sentence in PT,  Estou a ver.
# Sentence in BR,  Entendo.
# Sentence in PT,  Partilhávamos o amor pela diversão.
# Sentence in BR,  Nos agradava apreciar bons momentos.
# Sentence in PT,  Observa.
# Sentence in BR,  Veja.
# Sentence in PT,  É mais avinagrado.
# Sentence in BR,  Avinagrado ou algo parecido.
# Sentence in PT,  Quando penso nas formas como foste incorreta comigo...
# Sentence in BR,  Se eu enumerasse todas as formas em que me agrediu...
# Sentence in PT,  Na nuca.
# Sentence in BR,  e eu não estava sendo precipitado.
# Sentence in PT,  Tive saudades tuas.
# Sentence in BR,  Senti sua falta.
# Sentence in PT,  Parece-te que já terminei?
# Sentence in BR,  não acha que só sobraram os ossos deste faisão?
# Sentence in PT,  Sai facilmente?
# Sentence in BR,  <i>Sai fácil?</i>
# Sentence in PT,  <i>Timing</i> perfeito.
# Sentence in BR,  Bem a tempo.
# Sentence in PT,  Que ideia adorável.
# Sentence in BR,  Ótima ideia.
# Sentence in PT,  Resume-se a isso.
# Sentence in BR,  vou tirar isso...
# Sentence in PT,  Bebe, meu amor.
# Sentence in BR,  Beba, querida.
# Sentence in PT,  Bolas!
# Sentence in BR,  Porra.
# Sentence in PT,  Está a sangrar imenso.
# Sentence in BR,  Sangrando muito.
# Sentence in PT,  Voltaste.
# Sentence in BR,  Você voltou.
# Sentence in PT,  Um gin, minhas senhoras?
# Sentence in BR,  Senhoras, gim?
# Sentence in PT,  Felicity...
# Sentence in BR,  Saúde...
# Sentence in PT,  - Oh, tio... - Shh... shh!
# Sentence in BR,  <font color=#FFFF00>- Tio... - Cala a boca!</font>
# Sentence in PT,  - Alé. Tie cà. Tie cá.
# Sentence in BR,  <font color=#FFFF00>Ali. Pegue a espingarda.</font>
# Sentence in PT,  - Tio...
# Sentence in BR,  <font color=#FFFF00>Prontinho...</font>
# Sentence in PT,  Sentiu-o?
# Sentence in BR,  <font color=#FFFF00>Ouviram isso?</font>
# Sentence in PT,  -Lentamente, tens de estar calado.
# Sentence in BR,  <font color=#FFFF00>- Tio... - Calado. Fique quieto.</font>
# Sentence in PT,  Ele acordou.
# Sentence in BR,  <font color=#FFFF00>Ela se escondeu.</font>
# Sentence in PT,  - Tio... - Shh... cala-te.
# Sentence in BR,  <font color=#FFFF00>- Tio... - Calado.</font>
# Sentence in PT,  Descer.
# Sentence in BR,  <font color=#FFFF00>Sai de perto.</font>
# Sentence in PT,  - La piggiassi, tio
# Sentence in BR,  <font color=#FFFF00>Você acertou, tio.</font>
# Sentence in PT,  - É tudo o que tenho a dizer, não é?
# Sentence in BR,  <font color=#FFFF00>Acertou mesmo. Você a pegou.</font>
# Sentence in PT,  - Totò. Agora não te vás embora, vá lá.
# Sentence in BR,  <font color=#FFFF00>- Totó, não tenha medo, vai. - Não, eu tenho medo.</font>
# Sentence in PT,  - Me scanto, me scanto... - Maria... a nossa coisa.
# Sentence in BR,  <font color=#FFFF00>Nossa senhora!</font>
# Sentence in PT,  Annami, annami, vá lá.
# Sentence in BR,  <font color=#FFFF00>Vamos embora.</font>
# Sentence in PT,  A cùrri da Pino, Totò
# Sentence in BR,  <font color=#FFFF00>Corra chamar o Pino, Totó.</font>
# Sentence in PT,  - Pino [Pino.... Pino...].
# Sentence in BR,  <font color=#FFFF00>Ele tem medo...</font>
# Sentence in PT,  Pinho [Pinho]
# Sentence in BR,  <font color=#FFFF00>Pino!</font>
# Sentence in PT,  Pinho [Pinho]
# Sentence in BR,  <font color=#FFFF00>Pino!</font>
# Sentence in PT,  Pinho [Pino... Pino... Pino... Pino...]
# Sentence in BR,  <font color=#FFFF00>Pino!</font>
# Sentence in PT,  Mas desliguem este rádio.
# Sentence in BR,  <font color=#FFFF00>Desligue esse rádio.</font>
# Sentence in PT,  E vattinni!
# Sentence in BR,  <font color=#FFFF00>Suma daqui!</font>
# Sentence in PT,  [a sua capacidade de deslumbramento
# Sentence in BR,  <font color=#FFFF00><i>Ele é muito habilidoso.</i></font>
# Sentence in PT,  - Oh vai... puxa! Puxa!
# Sentence in BR,  <font color=#FFFF00>Vai... chuta! Chuta! Vá se foder!</font>
# Sentence in PT,  - Giannuzza
# Sentence in BR,  <font color=#FFFF00>Giannizinha.</font>
# Sentence in PT,  - Giannuzzo
# Sentence in BR,  <font color=#FFFF00>Giannizinho.</font>
# Sentence in PT,  - Giannuzzo
# Sentence in BR,  <font color=#FFFF00>Giannizinho.</font>
# Sentence in PT,  - Está a ficar surdo?
# Sentence in BR,  <font color=#FFFF00>Você ficou surdo?</font>
# Sentence in PT,  - Giannuzza
# Sentence in BR,  <font color=#FFFF00>Giannizinha.</font>
# Sentence in PT,  - Giannuzzo
# Sentence in BR,  <font color=#FFFF00>Giannizinho.</font>
# Sentence in PT,  [E lá vem o pequeno Rossi.
# Sentence in BR,  <font color=#FFFF00>Venha!</font>
# Sentence in PT,  Magath recuperado]
# Sentence in BR,  <font color=#FFFF00><i>E aí vem Rossi. Magath recupera.</i></font>
# Sentence in PT,  Véni a cà.
# Sentence in BR,  <font color=#FFFF00>Venha aqui.</font>
# Sentence in PT,  Oh, não o consegues ouvir a falar contigo.
# Sentence in BR,  <font color=#FFFF00>Não viu que ele está falando com você?</font>
# Sentence in PT,  Giannuzzo
# Sentence in BR,  <font color=#FFFF00>Giannizinho.</font>
# Sentence in PT,  - Vá lá, algo deste género...
# Sentence in BR,  <font color=#FFFF00>É só um cafezinho...</font>
# Sentence in PT,  Vèni chi ti pigli 'n caffè cu l'amici
# Sentence in BR,  <font color=#FFFF00>Venha tomar um café com seus amigos</font>
# Sentence in PT,  [o fecho deste 0-0 reconhecidamente lisonjeiro e esta noite a terceira fase]...
# Sentence in BR,  <font color=#FFFF00>Entre.</font>
# Sentence in PT,  - Uh, e andar ah...
# Sentence in BR,  <font color=#FFFF00>Continue andando.</font>
# Sentence in PT,  Gostas, não gostas?
# Sentence in BR,  <font color=#FFFF00>Você gosta disso, não é?</font>
# Sentence in PT,  E se gostares, não o estragues.
# Sentence in BR,  <font color=#FFFF00>Diga que você gosta, não seja tímido.</font>
# Sentence in PT,  - Sim, que gostas
# Sentence in BR,  <font color=#FFFF00>Claro que você gosta.</font>
# Sentence in PT,  Então, beddu
# Sentence in BR,  <font color=#FFFF00>Isso mesmo. Que lindinho!</font>
# Sentence in PT,  Olha para aquele beddu.
# Sentence in BR,  <font color=#FFFF00>Veja só que bonito.</font>
# Sentence in PT,  - Vá lá, nunca vieste dançar "cum mia", pois não?
# Sentence in BR,  <font color=#FFFF00>Quer dançar comigo essa noite?</font>
# Sentence in PT,  - Idda é, che bedda.
# Sentence in BR,  <font color=#FFFF00>Veja só que lindo!</font>
# Sentence in PT,  Bedda, Giannuzza bedda.
# Sentence in BR,  <font color=#FFFF00>Tão lindinha a Giannizinha.</font>
# Sentence in PT,  - Minchia, é mesmo Bedda Giannuzza.
# Sentence in BR,  <font color=#FFFF00><i>Giannizinha ficou bonita mesmo.</i></font>
# Sentence in PT,  - Proprio bedda.
# Sentence in BR,  <font color=#FFFF00><i>Ficou linda.</i></font>
# Sentence in PT,  - Está a fazer uma careta - Merda!
# Sentence in BR,  <font color=#FFFF00><i>- Não faça essa carinha. - Porra!</i></font>
# Sentence in PT,  - Aproxima-te, aproxima-te - Vèni ca
# Sentence in BR,  <font color=#FFFF00><i>Venha mais perto. Aproxime-se.</i></font>
# Sentence in PT,  - Pronto... já está.
# Sentence in BR,  <font color=#FFFF00><i>Isso... Prontinho.</i></font>
# Sentence in PT,  E então?
# Sentence in BR,  <font color=#FFFF00>Posso saber?</font>
# Sentence in PT,  Qual é o seu aspeto?
# Sentence in BR,  <font color=#FFFF00>Deixem o garoto em paz.</font>
# Sentence in PT,  - Se me disseres, só posso obedecer.
# Sentence in BR,  <font color=#FFFF00>Se você manda, eu obedeço.</font>
# Sentence in PT,  - Vai, vai, amunni
# Sentence in BR,  <font color=#FFFF00>Vamos dar o fora.</font>
# Sentence in PT,  - Avô
# Sentence in BR,  <font color=#FFFF00>Vovô!</font>
# Sentence in PT,  Olá, avô - Totò, mantém a calma.
# Sentence in BR,  <font color=#FFFF00>- Oi, vô. -Totó, cuidado.</font>
# Sentence in PT,  Um momento. - Olá, avô.
# Sentence in BR,  <font color=#FFFF00>- Espere um pouco. - Oi, vô.</font>
# Sentence in PT,  - Olá, pai
# Sentence in BR,  <font color=#FFFF00>Oi, pai.</font>
# Sentence in PT,  - Alfredo  Oh Petru.
# Sentence in BR,  <font color=#FFFF00>- Alfredo. - Oi, Pietro.</font>
# Sentence in PT,  Como é que correu para ti? - Foi... bom.
# Sentence in BR,  <font color=#FFFF00>- Deu tudo certo? - Sim.</font>
# Sentence in PT,  - Esperemos que alguns---------------
# Sentence in BR,  <font color=#FFFF00>- Espero que poucos. - Está tudo em ordem.</font>
# Sentence in PT,  - Não é preciso, disse.
# Sentence in BR,  <font color=#FFFF00>Não precisa, já te falei. Eu cuidarei disso.</font>
# Sentence in PT,  - Unni agghiri tu?
# Sentence in BR,  <font color=#FFFF00>Justo você que abaixa a cabeça para todo mundo?</font>
# Sentence in PT,  - Peter, pára.
# Sentence in BR,  <font color=#FFFF00>Pietro, pare. Os meninos vão ouvir.</font>
# Sentence in PT,  - Bem, é só pegar
# Sentence in BR,  <font color=#FFFF00>Bem, pegue para você.</font>
# Sentence in PT,  Foste promovido e mereceste-o.
# Sentence in BR,  <font color=#FFFF00>Você passou de ano e mereceu.</font>
# Sentence in PT,  - Até breve - Até breve - Adeus.
# Sentence in BR,  <font color=#FFFF00>- Tchau. Até logo. - Tchau.</font>
# Sentence in PT,  - O que é que estão a dizer, isso é uma treta
# Sentence in BR,  <font color=#FFFF00>Não se preocupe com essa besteira.</font>
# Sentence in PT,  E há cordel de sol, cordamina, elásticos, o que...
# Sentence in BR,  <font color=#FFFF00>Tem barbante, pavio, elástico...</font>
# Sentence in PT,  - Quem é que era meu para levar?
# Sentence in BR,  <font color=#FFFF00>E eu devo fazer isso?</font>
# Sentence in PT,  ----ca sparu fires.....
# Sentence in BR,  <font color=#FFFF00>Eu solto fogos de artifício não faço as compras.</font>
# Sentence in PT,  - Ah boh, deixo-te ca.
# Sentence in BR,  <font color=#FFFF00>Certo, mas vou deixar aqui.</font>
# Sentence in PT,  - Totò, como é que é?
# Sentence in BR,  <font color=#FFFF00>Totó, como está aí?</font>
# Sentence in PT,  - Espera um minuto, Giannì
# Sentence in BR,  <font color=#FFFF00><i>Espere um pouco, Gianni.</i></font>
# Sentence in PT,  Giannì, oh!
# Sentence in BR,  <font color=#FFFF00>Gianni!</font>
# Sentence in PT,  Estou metido nisto, sabes.
# Sentence in BR,  <font color=#FFFF00>Sinto muito.</font>
# Sentence in PT,  - Tem noção do que está a dizer?
# Sentence in BR,  <font color=#FFFF00>- Eu sou assim, você sabe. - Você consegue se ouvir?</font>
# Sentence in PT,  - Eu não te queria dizer, Gianni
# Sentence in BR,  <font color=#FFFF00>Isso, muito bem. Fique em silêncio.</font>
# Sentence in PT,  - Disseste-lhe o que te divertia.
# Sentence in BR,  <font color=#FFFF00>Você contou só para diverti-los.</font>
# Sentence in PT,  Espera, espera, espera.
# Sentence in BR,  <font color=#FFFF00><i>Espere, espere, espere.</i></font>
# Sentence in PT,  Espera!
# Sentence in BR,  <font color=#FFFF00>Espere!</font>
# Sentence in PT,  - E o que é metade?
# Sentence in BR,  <font color=#FFFF00>Ele não dá a mínima.</font>
# Sentence in PT,  O Chiddu está-se nas tintas.
# Sentence in BR,  <font color=#FFFF00>Só tem medo de ser alvo de fofocas.</font>
# Sentence in PT,  Percebem?
# Sentence in BR,  <font color=#FFFF00>Está entendendo?</font>
# Sentence in PT,  Não falas.
# Sentence in BR,  <font color=#FFFF00>Não vai falar nada.</font>
# Sentence in PT,  - Olá tio
# Sentence in BR,  <font color=#FFFF00>Oi, tio.</font>
# Sentence in PT,  - Adeusinho. - Avô.
# Sentence in BR,  <font color=#FFFF00>- Oi. - Vó!</font>
# Sentence in PT,  - Tio Pietru piggiau u cunigghiu
# Sentence in BR,  <font color=#FFFF00>- Tio Pietro pegou uma lebre. - Uma lebre?</font>
# Sentence in PT,  A mamã cozinha bonu u cunigghiu
# Sentence in BR,  <font color=#FFFF00>Lebre é gostosa. Eu sei cozinhar lebre.</font>
# Sentence in PT,  - Alè usando uma tonsura
# Sentence in BR,  <font color=#FFFF00>Por que não raspa esse cabelo?</font>
# Sentence in PT,  - Ciccio, está calado, há um pequenino.
# Sentence in BR,  <font color=#FFFF00>Fique quieto, o moleque vai ouvir.</font>
# Sentence in PT,  - Sim, sim...
# Sentence in BR,  <font color=#FFFF00>- Sim, sim... - Nino, venha aqui.</font>
# Sentence in PT,  - Tia, tio.
# Sentence in BR,  <font color=#FFFF00>Pode falar, tio.</font>
# Sentence in PT,  - Não vos estou a dizer. - Vamos lá!
# Sentence in BR,  <font color=#FFFF00>- Não vou te contar. - Por favor!</font>
# Sentence in PT,  - Vai-te lixar, disse ele.
# Sentence in BR,  <font color=#FFFF00>Vai perder o apetite assim.</font>
# Sentence in PT,  - Tem u cunigghiu
# Sentence in BR,  <font color=#FFFF00>- Veja só. - Uma lebre.</font>
# Sentence in PT,  Colocar dá.
# Sentence in BR,  <font color=#FFFF00>Coloque ali.</font>
# Sentence in PT,  - Ninuzzo, vèni ca, a mamma.
# Sentence in BR,  <font color=#FFFF00>- Não vamos almoçar? - Nino, vem cá.</font>
# Sentence in PT,  - Olá, mãe
# Sentence in BR,  <font color=#FFFF00>Oi, mãe.</font>
# Sentence in PT,  Isabela! - O quê?
# Sentence in BR,  <font color=#FFFF00>- Isabella! - O que foi?</font>
# Sentence in PT,  - Totò, pára.
# Sentence in BR,  <font color=#FFFF00>Totó, pare.</font>
# Sentence in PT,  - Uma desgraça és tu
# Sentence in BR,  <font color=#FFFF00>- Você é um desastre. - Você que é.</font>
# Sentence in PT,  Totò, vèni ca.
# Sentence in BR,  <font color=#FFFF00>Totó, vem cá.</font>
# Sentence in PT,  - Mas é verdade? - Claro que sim.
# Sentence in BR,  <font color=#FFFF00>- Está falando sério? - Claro.</font>
# Sentence in PT,  -Comer, comer.
# Sentence in BR,  <font color=#FFFF00>Coma, coma.</font>
# Sentence in PT,  - Na minha opinião, o que ele ouve é que conta. - Eu sou um idiota.
# Sentence in BR,  <font color=#FFFF00>- Você fala demais. - Seu burro.</font>
# Sentence in PT,  - U sappìa
# Sentence in BR,  <font color=#FFFF00>Eu sabia.</font>
# Sentence in PT,  - E então? Então, gostaste?
# Sentence in BR,  <font color=#FFFF00>Você gostou?</font>
# Sentence in PT,  - Obrigado, mamã.
# Sentence in BR,  <font color=#FFFF00>- Você mereceu. - Obrigado, mãe.</font>
# Sentence in PT,  - O que é, gostas? É o que querias?
# Sentence in BR,  <font color=#FFFF00>E então, gostou? É como você queria?</font>
# Sentence in PT,  Alfredo, levou-me a catare novo.
# Sentence in BR,  <font color=#FFFF00>Alfredo, deveria ter comprado uma nova,</font>
# Sentence in PT,  tendo em conta o que a guerra fez...
# Sentence in BR,  <font color=#FFFF00>essa aí é da época da guerra.</font>
# Sentence in PT,  - Tio...!
# Sentence in BR,  <font color=#FFFF00>Tio!</font>
# Sentence in PT,  é lindo.
# Sentence in BR,  <font color=#FFFF00>Caramba, ela é linda.</font>
# Sentence in PT,  - Avó, tu dizes... - Totò. Ei, espera!
# Sentence in BR,  <font color=#FFFF00>- Vó, fale para ele... - Totó, espere!</font>
# Sentence in PT,  - Tirar o Totò - Não, não
# Sentence in BR,  <font color=#FFFF00>- Saia daí, Totó - Não vou.</font>
# Sentence in PT,  - ... deixa-me experimentar, mas prometeste-me de....
# Sentence in BR,  <font color=#FFFF00>Eu quero andar. Você me prometeu.</font>
# Sentence in PT,  Só eu é que posso ficar contigo
# Sentence in BR,  <font color=#FFFF00>O que foi?</font>
# Sentence in PT,  Considere que já lá estamos, Senhor Deputado Sciacca.
# Sentence in BR,  <font color=#FFFF00>Logo estaremos aí, Sr. Sciacca.</font>
# Sentence in PT,  U motorino de lo figliu di Sciacca.
# Sentence in BR,  <font color=#FFFF00>A moto do filho do Sciacca,</font>
# Sentence in PT,  -Mas o chiddu mantém-se afastado.
# Sentence in BR,  <font color=#FFFF00>Mas a casa deles é longe.</font>
# Sentence in PT,  Como é que volto para lá?
# Sentence in BR,  <font color=#FFFF00>Como voltarei depois?</font>
# Sentence in PT,  - Está a dar um bom passeio.
# Sentence in BR,  <font color=#FFFF00>Você dará uma boa caminhada.</font>
# Sentence in PT,  - Mas porque não?
# Sentence in BR,  <font color=#FFFF00>Por que não?</font>
# Sentence in PT,  O que é que se passa contigo?
# Sentence in BR,  <font color=#FFFF00>Esqueça aqueles caras, são uns vagabundos.</font>
# Sentence in PT,  Lassali olha fixamente para chiddi, sunnu pappi.
# Sentence in BR,  <font color=#FFFF00>- Qual o problema? - Nenhum.</font>
# Sentence in PT,  Não tens de te preocupar,
# Sentence in BR,  <font color=#FFFF00>Não se preocupe,</font>
# Sentence in PT,  - Mas porquê?
# Sentence in BR,  <font color=#FFFF00>Mas por que não?</font>
# Sentence in PT,  - Calma. - Vai lá.
# Sentence in BR,  <font color=#FFFF00>- Relaxe. - Pare com isso.</font>
# Sentence in PT,  - Véni ca.
# Sentence in BR,  <font color=#FFFF00>Vem cá.</font>
# Sentence in PT,  Agora tu... mata-te!
# Sentence in BR,  <font color=#FFFF00>Suba na moto.</font>
# Sentence in PT,  Manué!
# Sentence in BR,  <font color=#FFFF00>Emanuele!</font>
# Sentence in PT,  Manué! - Oh?
# Sentence in BR,  <font color=#FFFF00>- Emanuele! - Oi?</font>
# Sentence in PT,  - Paragens
# Sentence in BR,  <font color=#FFFF00>Pare aí.</font>
# Sentence in PT,  - Ei, encosta
# Sentence in BR,  <font color=#FFFF00>Venha aqui.</font>
# Sentence in PT,  - Aproximar-se de si
# Sentence in BR,  <font color=#FFFF00>Pare a moto.</font>
# Sentence in PT,  - Parar! - Travão
# Sentence in BR,  <font color=#FFFF00>- Chega! - Freie!</font>
# Sentence in PT,  - Vamos lá, vamos lá, vamos lá
# Sentence in BR,  <font color=#FFFF00>Vamos embora. Vamos, vamos.</font>
# Sentence in PT,  Respirar
# Sentence in BR,  <font color=#FFFF00>Respire.</font>
# Sentence in PT,  Respirar
# Sentence in BR,  <font color=#FFFF00>Respire.</font>
# Sentence in PT,  Vá lá, respira.
# Sentence in BR,  <font color=#FFFF00>Vamos lá, respire.</font>
# Sentence in PT,  Respira... oh...
# Sentence in BR,  <font color=#FFFF00>Respire...</font>
# Sentence in PT,  Lançamos fogo de artifício, toda a gente nos conhece.
# Sentence in BR,  <font color=#FFFF00>Trabalhamos com rojões e todos nos conhecem.</font>
# Sentence in PT,  Tiè ca.
# Sentence in BR,  <font color=#FFFF00>Pegue.</font>
# Sentence in PT,  É melhor assim?
# Sentence in BR,  <font color=#FFFF00>Melhorou?</font>
# Sentence in PT,  - O que é que fizeste a ti próprio?
# Sentence in BR,  <font color=#FFFF00>- Onde você estava? - Sofri um acidente.</font>
# Sentence in PT,  - Mas o que é que ele fez? Nada foi feito.
# Sentence in BR,  <font color=#FFFF00>Pode ir.</font>
# Sentence in PT,  - A gasolina está lá? - Sim, há.
# Sentence in BR,  <font color=#FFFF00>- Tem gasolina? - Tem.</font>
# Sentence in PT,  E... onde é que se pode colocar?
# Sentence in BR,  <font color=#FFFF00>Prontinho.</font>
# Sentence in PT,  - Adeusinho. - Adeus.
# Sentence in BR,  <font color=#FFFF00>- Estou indo. Tchau. - Tchau.</font>
# Sentence in PT,  Parabéns a ti ♫
# Sentence in BR,  <font color=#FFFF00><i>Parabéns para você</i></font>
# Sentence in PT,  Parabéns a ti ♫
# Sentence in BR,  <font color=#FFFF00><i>Nesta data querida</i></font>
# Sentence in PT,  Parabéns a ti ♫
# Sentence in BR,  <font color=#FFFF00><i>Muitos anos de vida</i></font>
# Sentence in PT,  Olá? - Sim
# Sentence in BR,  <font color=#FFFF00>- Pronto? - Pronto.</font>
# Sentence in PT,  - Vai ver o segundo, va.
# Sentence in BR,  <font color=#FFFF00>Fique sossegado.</font>
# Sentence in PT,  Outra vez, hã? - Sim, ainda. - Ainda.
# Sentence in BR,  <font color=#FFFF00>- De novo, certo? - Sim.</font>
# Sentence in PT,  - Vèni ca.
# Sentence in BR,  <font color=#FFFF00>Vem cá.</font>
# Sentence in PT,  Não se preocupem.
# Sentence in BR,  <font color=#FFFF00>Arrume tudo.</font>
# Sentence in PT,  Muito bom.
# Sentence in BR,  <font color=#FFFF00>Excelente.</font>
# Sentence in PT,  Continua.
# Sentence in BR,  <font color=#FFFF00>Continue!</font>
# Sentence in PT,  Pai...!
# Sentence in BR,  <font color=#FFFF00>Pai!</font>
# Sentence in PT,  Onde é que o pus?
# Sentence in BR,  <font color=#FFFF00>Onde eu coloquei?</font>
# Sentence in PT,  Nino, adduma!
# Sentence in BR,  <font color=#FFFF00>Nino, vamos lá!</font>
# Sentence in PT,  - Pai!
# Sentence in BR,  <font color=#FFFF00>Pai!</font>
# Sentence in PT,  - Na carrinha. Procurem-no.
# Sentence in BR,  <font color=#FFFF00>No carro. Vá procurar.</font>
# Sentence in PT,  - Respira, vá lá.
# Sentence in BR,  <font color=#FFFF00>Respire, vamos lá.</font>
# Sentence in PT,  - Veja como está a reagir
# Sentence in BR,  <font color=#FFFF00>Cuidado com o que fala.</font>
# Sentence in PT,  - A maratona desta noite é boa de qualquer maneira
# Sentence in BR,  <font color=#FFFF00>Gata, vou te dizer o que fazer.</font>
# Sentence in PT,  Eu mostro-vos como ele celebra.
# Sentence in BR,  <font color=#FFFF00>Vou te mostrar como comemorar.</font>
# Sentence in PT,  - O que é que estás a fazer, meu? A divertir-me?
# Sentence in BR,  <font color=#FFFF00>E aí, gatinho? Quer se divertir?</font>
# Sentence in PT,  - Esqueçam-no.
# Sentence in BR,  <font color=#FFFF00>Deixa o menino.</font>
# Sentence in PT,  - O que tem andado a fazer?
# Sentence in BR,  <font color=#FFFF00>Você quer me matar?</font>
# Sentence in PT,  Sê tão bom como és.
# Sentence in BR,  <font color=#FFFF00>Bem. Estou bem, como deveria estar?</font>
# Sentence in PT,  Compreendemo-nos uns aos outros?
# Sentence in BR,  <font color=#FFFF00>Estamos entendidos?</font>
# Sentence in PT,  - Vai para o trabalho, vai!
# Sentence in BR,  <font color=#FFFF00>- Estamos. - Volte ao trabalho.</font>
# Sentence in PT,  - E o que é que tu queres?
# Sentence in BR,  <font color=#FFFF00>Quem é esse?</font>
# Sentence in PT,  - Espera ca, va.
# Sentence in BR,  <font color=#FFFF00>Espere aqui.</font>
# Sentence in PT,  - Há alguém à tua procura.
# Sentence in BR,  <font color=#FFFF00>- Tem alguém te procurando. - Nino, veja quem é, por favor.</font>
# Sentence in PT,  Foi na manhã de Sumana que te telefonei
# Sentence in BR,  <font color=#FFFF00>Finalmente! Liguei para você a manhã toda.</font>
# Sentence in PT,  - Olá - Olá
# Sentence in BR,  <font color=#FFFF00>- Oi - Oi.</font>
# Sentence in PT,  O ciclomotor está ótimo.
# Sentence in BR,  <font color=#FFFF00>A moto está ótima.</font>
# Sentence in PT,  - Mas está à procura de trabalho?
# Sentence in BR,  <font color=#FFFF00>- Você está procurando emprego? - Certo. Tchauzinho.</font>
# Sentence in PT,  - Já agora, bela camisa. Gosto dela.
# Sentence in BR,  <font color=#FFFF00>Aliás, a camisa é linda. Gostei. Venha, entre.</font>
# Sentence in PT,  Sabes que estavas errado.
# Sentence in BR,  <font color=#FFFF00>Ele sabe que errou.</font>
# Sentence in PT,  - Pede-nos desculpa agora. - Vamos, papá.
# Sentence in BR,  <font color=#FFFF00>- Peça desculpas. - Por favor, pai.</font>
# Sentence in PT,  Bravo. Accussì.
# Sentence in BR,  <font color=#FFFF00>Bom garoto. É assim que se faz.</font>
# Sentence in PT,  - Eu disse-te Totò, tens razão.
# Sentence in BR,  <font color=#FFFF00>Você tem toda razão, Totó.</font>
# Sentence in PT,  mas eu com o estômago vazio,
# Sentence in BR,  <font color=#FFFF00>não consigo nem falar de mulheres,</font>
# Sentence in PT,  Se eu ainda tiver de comer, nem as fêmeas podem falar quanto mais trabalhar.
# Sentence in BR,  <font color=#FFFF00>muito menos de trabalho. Vamos lá, rapazes.</font>
# Sentence in PT,  - Então, as mães sempre se deitaram
# Sentence in BR,  <font color=#FFFF00>Sua mãe sempre foi bonita.</font>
# Sentence in PT,  - Uma vez, gostei imediatamente
# Sentence in BR,  <font color=#FFFF00>Eu gostei dela assim que a vi.</font>
# Sentence in PT,  Chidda, levei-a para casa na última noite.
# Sentence in BR,  <font color=#FFFF00>Ainda não estávamos noivos</font>
# Sentence in PT,  - Carmela
# Sentence in BR,  <font color=#FFFF00>Carmela,</font>
# Sentence in PT,  - Carmela, estavas de cama,
# Sentence in BR,  <font color=#FFFF00>Carmela, você era linda,</font>
# Sentence in PT,  bem, elegante... talvez agora.
# Sentence in BR,  <font color=#FFFF00>fina, elegante... e continua sendo.</font>
# Sentence in PT,  - Cigarro - Hmmm...
# Sentence in BR,  <font color=#FFFF00>Apague o cigarro.</font>
# Sentence in PT,  U cunigghiu cu i mani si mancia
# Sentence in BR,  <font color=#FFFF00>Lebre se come com a mão.</font>
# Sentence in PT,  que lhe acontece.
# Sentence in BR,  <font color=#FFFF00>aparece para ele.</font>
# Sentence in PT,  Percebem?
# Sentence in BR,  <font color=#FFFF00>Entenderam?</font>
# Sentence in PT,  Bravo Gianni.
# Sentence in BR,  <font color=#FFFF00>Parabéns, Gianni. Você é um bom rapaz.</font>
# Sentence in PT,  Escuta-me.
# Sentence in BR,  <font color=#FFFF00>Preste atenção,</font>
# Sentence in PT,  - Ah, esqueci-me da salada, ca la secunda.
# Sentence in BR,  <font color=#FFFF00>e da família que tem, certo?</font>
# Sentence in PT,  Não sei...
# Sentence in BR,  <font color=#FFFF00>Não falo nada...</font>
# Sentence in PT,  - Está bem. Muito bem, sim.
# Sentence in BR,  <font color=#FFFF00>Tudo bem. Pode ser.</font>
# Sentence in PT,  - Já alguma vez partiste pedras?
# Sentence in BR,  <font color=#FFFF00>e você vem falar de cebola?</font>
# Sentence in PT,  - Se Deus quiser, eles dão-lhe este quinto ano também vais a casa do tio Petru.
# Sentence in BR,  <font color=#FFFF00>poderá trabalhar com o tio Pietro.</font>
# Sentence in PT,  Sim, é difícil!
# Sentence in BR,  <font color=#FFFF00>Só está um pouco dura.</font>
# Sentence in PT,  - Eh... - Sim, sim.
# Sentence in BR,  <font color=#FFFF00>- Isso. - Sim, vou sim.</font>
# Sentence in PT,  - Ah, eu não sabia disso. Experimenta agora.
# Sentence in BR,  <font color=#FFFF00>Tente agora.</font>
# Sentence in PT,  Voltem sempre que quiserem, sim?
# Sentence in BR,  <font color=#FFFF00>Tchau, Gianni. Volte quando quiser.</font>
# Sentence in PT,  - Adeus - Adeus
# Sentence in BR,  <font color=#FFFF00>- Tchau. - Tchau.</font>
# Sentence in PT,  - Apanhar cigarros
# Sentence in BR,  <font color=#FFFF00>Totó, compre cigarros para mim.</font>
# Sentence in PT,  - Vai, vai, vai!
# Sentence in BR,  <font color=#FFFF00>Vai, vai!</font>
# Sentence in PT,  Vai, vai, vai até ao fim!
# Sentence in BR,  <font color=#FFFF00>Vai, vai, mais um!</font>
# Sentence in PT,  - O que é que se passa?
# Sentence in BR,  <font color=#FFFF00>Vejam só quem está vindo!</font>
# Sentence in PT,  - Vamos lá, véni ca!
# Sentence in BR,  <font color=#FFFF00>Enzo, vem cá, vem!</font>
# Sentence in PT,  - Véni ca! - Vamos lá...
# Sentence in BR,  <font color=#FFFF00>Pare aqui.</font>
# Sentence in PT,  - Uh, uh, talia cu cc é.
# Sentence in BR,  <font color=#FFFF00>Vejam só quem chegou.</font>
# Sentence in PT,  - Hoje queres magoar.
# Sentence in BR,  <font color=#FFFF00>Hoje ele está a fim de apanhar.</font>
# Sentence in PT,  - Franco - Mica viu-o...
# Sentence in BR,  <font color=#FFFF00>Você não falou isso.</font>
# Sentence in PT,  Franco, u ficcardiu
# Sentence in BR,  <font color=#FFFF00>Franco, o comedor.</font>
# Sentence in PT,  - Francooooo
# Sentence in BR,  <font color=#FFFF00>Franco...</font>
# Sentence in PT,  - Mãe
# Sentence in BR,  <font color=#FFFF00>Mãe.</font>
# Sentence in PT,  - És completamente louco
# Sentence in BR,  <font color=#FFFF00>Você enlouqueceu de vez.</font>
# Sentence in PT,  Lembras-te de como éramos?
# Sentence in BR,  <font color=#FFFF00>Lembra como você e eu estávamos antes?</font>
# Sentence in PT,  Vamos para outro sítio, tu e eu. - De que é que estão a falar?
# Sentence in BR,  <font color=#FFFF00>- Nós dois sairemos daqui. - O que está dizendo?</font>
# Sentence in PT,  - Unni jè? Véni ca.
# Sentence in BR,  <font color=#FFFF00>Você não vai mais pôr os pés na minha oficina.</font>
# Sentence in PT,  - Deixem-no em paz - Tens de o deixar
# Sentence in BR,  <font color=#FFFF00>- Vá embora agora. - Pode deixar.</font>
# Sentence in PT,  - Claro que sim - Se não, farei com que te arrependas do dia em que nasceste.
# Sentence in BR,  <font color=#FFFF00>Ou vai se arrepender de ter nascido.</font>
# Sentence in PT,  - Vattinni, va
# Sentence in BR,  <font color=#FFFF00>Vai logo.</font>
# Sentence in PT,  - A equipa não está em risco. - Vamos lá.
# Sentence in BR,  <font color=#FFFF00>Pasquale, não é arriscado.</font>
# Sentence in PT,  - Antoninus... - Sim
# Sentence in BR,  <font color=#FFFF00>- Antonino, você aqui? - Pois é.</font>
# Sentence in PT,  - Vamos pegar nesta escavadora e começar. - Tudo bem
# Sentence in BR,  <font color=#FFFF00>- Pegue a escavadeira e comece. - Certo.</font>
# Sentence in PT,  - Doutor, sugnu patri di famiglia.
# Sentence in BR,  <font color=#FFFF00>Muito obrigado.</font>
# Sentence in PT,  - Vai, eu peço-te uma treva e começamos antes de eu reconsiderar. - Obrigado, Doutor.
# Sentence in BR,  <font color=#FFFF00>Melhor começar logo antes que você desista.</font>
# Sentence in PT,  - Alfré, como estás?
# Sentence in BR,  <font color=#FFFF00>- Alfredo, como você está? - Bem, estou aqui.</font>
# Sentence in PT,  - Não, não, não importa - Não, não, não importa.
# Sentence in BR,  <font color=#FFFF00>- Não, deixe isso pra lá. - Não vou deixar nada pra lá.</font>
# Sentence in PT,  - Mas porquê fazer isto? - Alfré!
# Sentence in BR,  <font color=#FFFF00>- Por que vai fazer isso? - Alfredo!</font>
# Sentence in PT,  Gianni, o que é que fazemos? Começamos? - Sim.
# Sentence in BR,  <font color=#FFFF00>- Gianni, vamos começar? - Vamos.</font>
# Sentence in PT,  Ver esses ramos
# Sentence in BR,  <font color=#FFFF00>Veja aqueles galhos.</font>
# Sentence in PT,  - Vai! Vai!
# Sentence in BR,  <font color=#FFFF00>Desça! Desça!</font>
# Sentence in PT,  Tenho uma família, como é que vou comer?
# Sentence in BR,  <font color=#FFFF00>Estou falando com você.</font>
# Sentence in PT,  - Gianni... vem cá.
# Sentence in BR,  <font color=#FFFF00>Gianni, venha aqui.</font>
# Sentence in PT,  Está muito empenhado.
# Sentence in BR,  <font color=#FFFF00>Você trabalha muito duro.</font>
# Sentence in PT,  - Obrigado.
# Sentence in BR,  <font color=#FFFF00>Obrigado.</font>
# Sentence in PT,  - Adeus - Adeus.
# Sentence in BR,  <font color=#FFFF00>- Tchau. - Tchau.</font>
# Sentence in PT,  Vai.
# Sentence in BR,  <font color=#FFFF00>Vai.</font>
# Sentence in PT,  minchia, tall explode.
# Sentence in BR,  <font color=#FFFF00>alto pra caralho, ela explode.</font>
# Sentence in PT,  - A va bene, não importa.
# Sentence in BR,  <font color=#FFFF00>Certo, deixa pra lá.</font>
# Sentence in PT,  Deixem-me mostrar-vos.
# Sentence in BR,  <font color=#FFFF00>Preste atenção no que vou te mostrar.</font>
# Sentence in PT,  Alarme!
# Sentence in BR,  <font color=#FFFF00>"Olha o rojão!"</font>
# Sentence in PT,  - Mas beijaste-me da última vez?
# Sentence in BR,  <font color=#FFFF00>Você me beijou aquele dia?</font>
# Sentence in PT,  Ao acidente.
# Sentence in BR,  <font color=#FFFF00>No dia do acidente.</font>
# Sentence in PT,  - Do que estás a falar, beijada? Já não estavas a respirar.
# Sentence in BR,  <font color=#FFFF00>De onde tirou isso? Você não estava respirando.</font>
# Sentence in PT,  Não, em.....
# Sentence in BR,  <font color=#FFFF00>Não, acha que vou me lavar aqui?</font>
# Sentence in PT,  - Vamos lá.
# Sentence in BR,  <font color=#FFFF00>Venha!</font>
# Sentence in PT,  - Nino
# Sentence in BR,  <font color=#FFFF00>Nino!</font>
# Sentence in PT,  Nino.
# Sentence in BR,  <font color=#FFFF00>Nino!</font>
# Sentence in PT,  - Minchia! Mi scantari-------------
# Sentence in BR,  <font color=#FFFF00>Cacete! Você me assustou.</font>
# Sentence in PT,  - Rápido.
# Sentence in BR,  <font color=#FFFF00>- Mais rápido. - Um segundo.</font>
# Sentence in PT,  - Espera um minuto, espera um minuto. - Issa lassalu ca. Ciao
# Sentence in BR,  <font color=#FFFF00>- Espere um pouco. - Vou te deixar aqui. Tchau.</font>
# Sentence in PT,  - Babbu, caíste na armadilha
# Sentence in BR,  <font color=#FFFF00>Seu bobo, você caiu direitinho.</font>
# Sentence in PT,  - Mas trabalhaste ca? - Sim
# Sentence in BR,  <font color=#FFFF00>- Era aqui que você trabalhava? - Era.</font>
# Sentence in PT,  - Olá - Oh...
# Sentence in BR,  <font color=#FFFF00>- Oi. - Oi.</font>
# Sentence in PT,  - Obrigado
# Sentence in BR,  <font color=#FFFF00>Obrigada.</font>
# Sentence in PT,  Entra, vamos. - Sim.
# Sentence in BR,  <font color=#FFFF00>- Suba logo. - Sim.</font>
# Sentence in PT,  - Muito bem, eu vou-me embora
# Sentence in BR,  <font color=#FFFF00>Certo, tenho que ir.</font>
# Sentence in PT,  - Ultrapassa isso, vai. Até amanhã.
# Sentence in BR,  <font color=#FFFF00>Imagina. Nos vemos amanhã.</font>
# Sentence in PT,  - Vamos lá, adeus. - Adeus.
# Sentence in BR,  <font color=#FFFF00>- Combinado. Tchau. - Tchau.</font>
# Sentence in PT,  - Está a chorar.
# Sentence in BR,  <font color=#FFFF00>Você está chorando.</font>
# Sentence in PT,  [ Com isto, vemo-nos até amanhã à hora habitual.
# Sentence in BR,  <font color=#FFFF00><i>Temos um encontro amanhã nesse mesmo horário.</i></font>
# Sentence in PT,  - Qual é que quer?
# Sentence in BR,  <font color=#FFFF00>Qual vai querer?</font>
# Sentence in PT,  - Bálsamo
# Sentence in BR,  <font color=#FFFF00>Vamos dançar.</font>
# Sentence in PT,  Beddissima
# Sentence in BR,  <font color=#FFFF00>Como assim?</font>
# ...
# Sentence in BR,  eu ainda vou subir para os aplausos?
# Sentence in PT,  Sempre gostei muito.
# Sentence in BR,  "Eu sempre amei.
# Sentence in PT,  Isso é um pouco exagerado.
# Sentence in BR,  Mas é bem diferente.
# Sentence in PT,  Uau.
# Sentence in BR,  Nossa!
# Sentence in PT,  Sabes, aquela coisa toda com a venda nos olhos.
# Sentence in BR,  Dá para ver pela venda.
# Sentence in PT,  Não, vais ser fantástica.
# Sentence in BR,  Calma, você vai se sair bem.
# Sentence in PT,  -Não, não sei.
# Sentence in BR,  Não quero mesmo.
# Sentence in PT,  Está bem.
# Sentence in BR,  Pronto.
# Sentence in PT,  Agora, abram-nas lentamente.
# Sentence in BR,  Agora pode abrir, bem devagar.
# Sentence in PT,  Mmm.
# Sentence in BR,  Minha filha agiu bem.
# Sentence in PT,  o mais mágico dos espelhos.
# Sentence in BR,  esse espelho tão mágico.
# Sentence in PT,  -Olá. Como é que correu?
# Sentence in BR,  Oi, como foi?
# Sentence in PT,  -Eu teria adorado ter estado lá.
# Sentence in BR,  Queria tanto estar aí!
# Sentence in PT,  MISTÉRIO EM VENEZA
# Sentence in BR,  A NOITE DAS BRUXAS
# Sentence in PT,  Portanto, devo dar-lhe isto.
# Sentence in BR,  Ela diz ser sua amiga.
# Sentence in PT,  Desculpe o meu guarda-costas. Segue instruções minhas.
# Sentence in BR,  Perdoe meu segurança. Eu lhe dou as ordens.
# Sentence in PT,  Isolado e reformado.
# Sentence in BR,  Se aposentou entre grades.
# Sentence in PT,  Muito bem.
# Sentence in BR,  Então...
# Sentence in PT,  O que significa "catita"?
# Sentence in BR,  Por que charmoso?
# Sentence in PT,  Poirot, descobri uma coisa. Uma pessoa.
# Sentence in BR,  Poirot, eu encontrei algo. Alguém.
# Sentence in PT,  Vi milhentos alegados médiuns, todos uns vigaristas manhosos.
# Sentence in BR,  Já vi milhões de videntes, tudo picaretagem.
# Sentence in PT,  E depois aparece-me aquela.
# Sentence in BR,  E tem essa.
# Sentence in PT,  Veja a vigarice que me escapa.
# Sentence in BR,  Desvende tudo.
# Sentence in PT,  Estão prontos, meninos?
# Sentence in BR,  Prontas, crianças?
# Sentence in PT,  Por isso, tenham cuidado.
# Sentence in BR,  Então cuidado!
# Sentence in PT,  Os jogos são frívolos.
# Sentence in BR,  Brincar é frivolidade.
# Sentence in PT,  Sente-se bem?
# Sentence in BR,  Você está bem?
# Sentence in PT,  Quer ponche?
# Sentence in BR,  Um ponche então?
# Sentence in PT,  Estou feliz.
# Sentence in BR,  Fico feliz por isso.
# Sentence in PT,  Desculpe.
# Sentence in BR,  Me perdoe.
# Sentence in PT,  Soluços.
# Sentence in BR,  Lamentos.
# Sentence in PT,  Como a sua assistente indicou.
# Sentence in BR,  Como foi especificado.
# Sentence in PT,  Tantas...
# Sentence in BR,  São muitas,
# Sentence in PT,  Uma carcaça velha?
# Sentence in BR,  Uma coroa caduca?
# Sentence in PT,  A carcaça velha.
# Sentence in BR,  A coroa. A coroa caduca.
# Sentence in PT,  A minha laia?
# Sentence in BR,  Minha espécie?
# Sentence in PT,  Estava a dizer?
# Sentence in BR,  O que dizia?
# Sentence in PT,  Não valoriza o sentido de oportunidade dramático.
# Sentence in BR,  Sem crédito pela sincronia teatral.
# Sentence in PT,  <i>Tornou-se tão bonita.</i>
# Sentence in BR,  <i>Ela ficou linda.</i>
# Sentence in PT,  A escutar.
# Sentence in BR,  Ouvindo.
# Sentence in PT,  A escutar.
# Sentence in BR,  Ouvindo.
# Sentence in PT,  A escutar.
# Sentence in BR,  Ouvindo.
# Sentence in PT,  Soube que ela é riquíssima.
# Sentence in BR,  É podre de rica.
# Sentence in PT,  Ponho-o na rua?
# Sentence in BR,  Devo expulsá-lo?
# Sentence in PT,  Considero-me, acima de tudo, uma secretária.
# Sentence in BR,  Sou mais secretária do que outra coisa.
# Sentence in PT,  Estás?
# Sentence in BR,  Fala?
# Sentence in PT,  Demasiados espíritos.
# Sentence in BR,  Espíritos demais.
# Sentence in PT,  A escutar.
# Sentence in BR,  Ouvindo.
# Sentence in PT,  "Y."
# Sentence in BR,  "S".
# Sentence in PT,  A escutar.
# Sentence in BR,  Ouvindo.
# Sentence in PT,  A escutar.
# Sentence in BR,  Ouvindo.
# Sentence in PT,  É a maré santificada.
# Sentence in BR,  É o Dia de Todos os Santos.
# Sentence in PT,  Falsa?
# Sentence in BR,  Tudo falso?
# Sentence in PT,  Onde está o Baba?
# Sentence in BR,  Cadê Baba?
# Sentence in PT,  Dói.
# Sentence in BR,  Dor.
# Sentence in PT,  Assassino!
# Sentence in BR,  Homicida!
# Sentence in PT,  Mataste-me.
# Sentence in BR,  Você me matou. Você me matou.
# Sentence in PT,  Mataste-me! Mataste-me!
# Sentence in BR,  Você me matou! Você me matou!
# Sentence in PT,  Mataste-me!
# Sentence in BR,  Você me matou!
# Sentence in PT,  - Mataste-me! - Mostra-me!
# Sentence in BR,  - Você me matou! - Me mostre!
# Sentence in PT,  Mataste-me!
# Sentence in BR,  Você me matou!
# Sentence in PT,  Assassínio!
# Sentence in BR,  Homicida!
# Sentence in PT,  Um grande livro.
# Sentence in BR,  Um <i>best-seller</i>.
# Sentence in PT,  Algo.
# Sentence in BR,  Alguma coisa.
# Sentence in PT,  É uma impostora muito dotada.
# Sentence in BR,  Entre as fraudes, a senhora tem o dom de fraudar.
# Sentence in PT,  Leva-me a mal por isso?
# Sentence in BR,  O senhor é contra?
# Sentence in PT,  Uma conveniência lucrativa.
# Sentence in BR,  Bem lucrativo.
# Sentence in PT,  Descontraia-se, amigo.
# Sentence in BR,  Relaxe, parceiro.
# Sentence in PT,  "Descontraia-se"...
# Sentence in BR,  "Relaxe."
# Sentence in PT,  Vou ligar para a minha antiga esquadra.
# Sentence in BR,  Chamarei a polícia.
# Sentence in PT,  Ela era o nosso bilhete.
# Sentence in BR,  Era nossa passagem.
# Sentence in PT,  Ela pode ter saltado.
# Sentence in BR,  Talvez tenha pulado.
# Sentence in PT,  Parecia ser desse género.
# Sentence in BR,  Ela fazia o tipo.
# Sentence in PT,  Ainda acha que ela era genuína?
# Sentence in BR,  Ainda a considera real?
# Sentence in PT,  Os canais não são seguros.
# Sentence in BR,  Canais bloqueados.
# Sentence in PT,  Está fora do controlo da polícia, <i>signora.</i>
# Sentence in BR,  A polícia não sabe.
# Sentence in PT,  Todos os assassinos são velhos amigos de alguém.
# Sentence in BR,  Todo homicida tem amigos.
# Sentence in PT,  Debaixo desse monte de quadros?
# Sentence in BR,  Sob aquela pilha de telas?
# Sentence in PT,  E depois apareceu a correr?
# Sentence in BR,  E veio correndo?
# Sentence in PT,  "que podemos comprar por seis liras."
# Sentence in BR,  O que há diretamente acima da sacada?
# Sentence in PT,  Não liguei muito.
# Sentence in BR,  Nada demais.
# Sentence in PT,  Era uma alcunha que ela usava para mim.
# Sentence in BR,  Ela me chamava por esse apelido.
# Sentence in PT,  Não voltará a cantar?
# Sentence in BR,  Não se apresentará mais?
# Sentence in PT,  Era outra vez como uma menina.
# Sentence in BR,  Ela voltou a ser criança.
# Sentence in PT,  Ela não arranjou melhor.
# Sentence in BR,  Sou a melhor que achou.
# Sentence in PT,  Escapou-me.
# Sentence in BR,  Um lapso.
# Sentence in PT,  Acha que sou maluquinho?
# Sentence in BR,  Me acha louco?
# Sentence in PT,  Sente-se bem?
# Sentence in BR,  Tudo bem?
# Sentence in PT,  Foi soldado?
# Sentence in BR,  Serviu?
# Sentence in PT,  Ajudar esqueletos a voltar à vida.
# Sentence in BR,  Revivemos esqueletos.
# Sentence in PT,  Não a escutei.
# Sentence in BR,  Eu não ouvi.
# Sentence in PT,  Já acabámos?
# Sentence in BR,  Terminamos?
# Sentence in PT,  Vou esperar.
# Sentence in BR,  Vou aguardar, senhor.
# Sentence in PT,  Nervoso.
# Sentence in BR,  Sobressaltado.
# Sentence in PT,  De volta ao normal.
# Sentence in BR,  Voltou a si.
# Sentence in PT,  Tem bom gosto para livros, mas o fogo dos fanáticos é intenso.
# Sentence in BR,  Gosta de ler, mas brasas queimam.
# Sentence in PT,  Mas aquele rapazinho
# Sentence in BR,  Mas o menino
# Sentence in PT,  Outra vez ele.
# Sentence in BR,  Ele de novo.
# Sentence in PT,  Estou a dizer-vos agora.
# Sentence in BR,  Estou mencionando.
# Sentence in PT,  Numa aldeia destruída pelo fogo.
# Sentence in BR,  Nossa vila foi incinerada.
# Sentence in PT,  De toda a nossa família,
# Sentence in BR,  Da família inteira,
# Sentence in PT,  Cuidámos um do outro.
# Sentence in BR,  Nós nos protegemos.
# Sentence in PT,  Ele diz que entraram logo após a meia-noite.
# Sentence in BR,  Ele os viu entrar depois.
# Sentence in PT,  - Safávamo-nos, antes. - Sim, roubavam.
# Sentence in BR,  - Nós sobrevivemos. - Roubavam.
# Sentence in PT,  Vigarice pura.
# Sentence in BR,  Charlatanismo.
# Sentence in PT,  Vimo-lo vezes sem conta.
# Sentence in BR,  Vimos repetidamente.
# Sentence in PT,  "Tlintlim, fazia o elétrico."
# Sentence in BR,  "Blém, blém, blém, faz o bonde."
# Sentence in PT,  Onde estás?
# Sentence in BR,  Nicholas, cadê você?
# Sentence in PT,  Não significa que a tenha matado.
# Sentence in BR,  Nem por isso a matei.
# Sentence in PT,  Ouvem isto?
# Sentence in BR,  Está ouvindo?
# Sentence in PT,  À nossa volta.
# Sentence in BR,  Ao nosso redor.
# Sentence in PT,  Nós os dois, então.
# Sentence in BR,  Eu e você então.
# Sentence in PT,  A escutar.
# Sentence in BR,  Ouvindo.
# Sentence in PT,  Continua morto.
# Sentence in BR,  Ainda mudo.
# Sentence in PT,  Não estás metida em sarilhos.
# Sentence in BR,  Não está encrencada.
# Sentence in PT,  Viste?
# Sentence in BR,  Você viu?
# Sentence in PT,  Ouvi isto.
# Sentence in BR,  Isso, eu ouvi.
# Sentence in PT,  Solte-nos!
# Sentence in BR,  Nos soltem!
# Sentence in PT,  Perturbámo-los.
# Sentence in BR,  Nós os aborrecemos.
# Sentence in PT,  Vem da cave.
# Sentence in BR,  Vem do porão.
# Sentence in PT,  Quer entrar ali?
# Sentence in BR,  Você vai descer aí?
# Sentence in PT,  Parem!
# Sentence in BR,  Pare! Pare com isso!
# Sentence in PT,  Estás bem?
# Sentence in BR,  Você está bem? Tudo bem?
# Sentence in PT,  Vê-me?
# Sentence in BR,  Está me vendo?
# Sentence in PT,  Vê-me?
# Sentence in BR,  Está me vendo?
# Sentence in PT,  Chiu, pai.
# Sentence in BR,  Pai.
# Sentence in PT,  Descanse, <i>monsieur.</i>
# Sentence in BR,  Descanse.
# Sentence in PT,  Vi.
# Sentence in BR,  Eu vi.
# Sentence in PT,  Aonde quer que vamos...
# Sentence in BR,  Aonde formos,
# Sentence in PT,  Numa aflição, ainda mais.
# Sentence in BR,  Isso se duplica com a dor.
# Sentence in PT,  Não era inevitável.
# Sentence in BR,  Não precisava.
# Sentence in PT,  Não consigo identificá-lo.
# Sentence in BR,  Não sei qual é.
# Sentence in PT,  Que felicidade radiante.
# Sentence in BR,  Uma alegria solar.
# Sentence in PT,  Foi a última vez que falámos.
# Sentence in BR,  Nunca mais nos falamos.
# Sentence in PT,  Contudo, foi-se embora.
# Sentence in BR,  Mas se afastou.
# Sentence in PT,  Chega. Está despachado. Vamos.
# Sentence in BR,  É isso. Terminou. Vamos.
# Sentence in PT,  Impus a minha presença para observá-lo como pesquisa para um livro.
# Sentence in BR,  Briguei para observar e pesquisar você.
# Sentence in PT,  Descrevi Poirot mal disfarçado.
# Sentence in BR,  Fiz um Poirot implícito.
# Sentence in PT,  Ainda não aqueceu o motor, levou umas pancadas na cabeça.
# Sentence in BR,  Foi pego de surpresa, bateu com a cabeça.
# Sentence in PT,  É o ramo familiar, basicamente.
# Sentence in BR,  Quase um negócio familiar.
# Sentence in PT,  Foi polícia, em tempos.
# Sentence in BR,  Já foi policial.
# Sentence in PT,  passa sem dificuldade.
# Sentence in BR,  passa valsando.
# Sentence in PT,  É um sarilho, então.
# Sentence in BR,  Meio complicado então.
# Sentence in PT,  Por favor, está a inventar.
# Sentence in BR,  Está jogando verde.
# Sentence in PT,  A conspirar...
# Sentence in BR,  Juntos...
# Sentence in PT,  Despache-se!
# Sentence in BR,  Depressa com isso!
# Sentence in PT,  O que foi? O que se passa com ele?
# Sentence in BR,  Por que não usá-lo para vender livros?
# Sentence in PT,  Tem um filho, por amor de Deus.
# Sentence in BR,  Por que ele precisava ficar só?
# Sentence in PT,  Vamos.
# Sentence in BR,  Saiam.
# Sentence in PT,  E foi à varanda.
# Sentence in BR,  Foi até a sacada.
# Sentence in PT,  Adorava aquela rapariga.
# Sentence in BR,  Eu a amava.
# Sentence in PT,  Como se atreve?
# Sentence in BR,  Como ousa!
# Sentence in PT,  Não consigo identificá-lo.
# Sentence in BR,  Não sei qual é.
# Sentence in PT,  Não podia fazer isso. Não fiz.
# Sentence in BR,  Eu jamais faria isso.
# Sentence in PT,  Outra vez sua.
# Sentence in BR,  Sua novamente.
# Sentence in PT,  <i>outra vez transtornada, decerto.</i>
# Sentence in BR,  <i>com certeza, perturbada.</i>
# Sentence in PT,  <i>Voltou do seu descanso</i>
# Sentence in BR,  <i>Você acordou</i>
# Sentence in PT,  <i>Havia que pará-la, pelo seguro.</i>
# Sentence in BR,  <i>Ela precisava ser detida para sua segurança.</i>
# Sentence in PT,  <i>...a sua única razão de viver...</i>
# Sentence in BR,  <i>O único motivo para ele estar vivo.</i>
# Sentence in PT,  Nunca lhe faria mal.
# Sentence in BR,  Eu nunca a feriria.
# Sentence in PT,  Deixa-me apertar o botão de cima.
# Sentence in BR,  Permita-me abotoar.
# Sentence in PT,  És um rapaz precoce
# Sentence in BR,  Você é precoce
# Sentence in PT,  Faço ideia do que isso é.
# Sentence in BR,  Eu entendo disso.
# Sentence in PT,  O pai não conseguia trabalhar.
# Sentence in BR,  Ele não trabalhava mais.
# Sentence in PT,  E mais uma.
# Sentence in BR,  E outra.
# Sentence in PT,  Para compensar os remorsos.
# Sentence in BR,  Use bem o arrependimento.
# Sentence in PT,  À esquadra?
# Sentence in BR,  À delegacia?
# Sentence in PT,  Escutou-a.
# Sentence in BR,  Você a ouviu.
# Sentence in PT,  Nem vivos nem provas. Tenho de rescrever tudo.
# Sentence in BR,  Não há fantasmas. Vou reescrever.
# Sentence in PT,  Sim. Viu algo.
# Sentence in BR,  Você viu alguma coisa.
# Sentence in PT,  Sabe.
# Sentence in BR,  Você sabe.
# Sentence in PT,  Tradução NOS Audiovisuais por Gonçalo Sousa
# Sentence in BR,  Tradução e Adaptação: Mário Menezes
# Sentence in PT,  Olá. Olá.
# Sentence in BR,  Oi, oi.
# Sentence in PT,  Estou a passar-me.
# Sentence in BR,  Estou surtando.
# Sentence in PT,  -Aproxima-te. -Ok.
# Sentence in BR,  -Chegue mais perto. -Okay.
# Sentence in PT,  O que é que ele queria dizer?
# Sentence in BR,  Qual era o objetivo dele?
# Sentence in PT,  Desculpe. Com licença.
# Sentence in BR,  Desculpe-me. Desculpe-me.
# Sentence in PT,  -Sim. -Estou a ver, está bem.
# Sentence in BR,  -Sim. -Eu entendo, ok.
# Sentence in PT,  Está um gelo do caraças.
# Sentence in BR,  Está muito frio.
# Sentence in PT,  Fizeste o quê?
# Sentence in BR,  O que você fez?
# Sentence in PT,  A sua alimentação?
# Sentence in BR,  Seu feed?
# Sentence in PT,  Tenho tanto medo.
# Sentence in BR,  Estou com muito medo.
# Sentence in PT,  Super!
# Sentence in BR,  Muito bom!
# Sentence in PT,  Lamento imenso.
# Sentence in BR,  Sinto muito.
# Sentence in PT,  Sacanas!
# Sentence in BR,  Desgraçados!
# Sentence in PT,  Lamento imenso.
# Sentence in BR,  Sinto muito, muito mesmo.
# Sentence in PT,  Este top fica-lhe tão bem.
# Sentence in BR,  Essa blusa ficou muito bonita em você.
# Sentence in PT,  Mas talvez o faça.
# Sentence in BR,  Mas pode ser que sim.
# Sentence in PT,  Avaria parcial.
# Sentence in BR,  Desmontagem parcial.
# Sentence in PT,  É verdade?
# Sentence in BR,  É isso mesmo?
# Sentence in PT,  Foi de certeza isso.
# Sentence in BR,  Definitivamente, era isso.
# Sentence in PT,  Mentiu-nos.
# Sentence in BR,  Você mentiu para nós.
# Sentence in PT,  Olá...
# Sentence in BR,  Oi, erm...
# Sentence in PT,  Olha, olha...
# Sentence in BR,  Veja, veja...
# Sentence in PT,  Olha para isto. Olha para isto!
# Sentence in BR,  Dê uma olhada nisso. Veja isso!
# Sentence in PT,  Olha, olha.
# Sentence in BR,  Veja, veja.
# Sentence in PT,  Pois é. Pois bem,
# Sentence in BR,  Ah, sim. Bem,
# Sentence in PT,  Peço desculpa.
# Sentence in BR,  Eu sinto muito.
# Sentence in PT,  Tu...
# Sentence in BR,  O senhor...
# Sentence in PT,  É muito bonito!
# Sentence in BR,  Adorável!
# Sentence in PT,  Sabes como é,
# Sentence in BR,  Erm, você sabe,
# Sentence in PT,  Já lá estive.
# Sentence in BR,  Eu já passei por isso.
# Sentence in PT,  - Sarah! - Vai! Vai!
# Sentence in BR,  - Sarah! - Vá em frente! Vá em frente!
# Sentence in PT,  Ama-te a ti próprio.
# Sentence in BR,  Ame a si mesmo.
# Sentence in PT,  És lindo, meu.
# Sentence in BR,  Você é lindo, cara.
# Sentence in PT,  Online. Peço imensa desculpa.
# Sentence in BR,  Online. Eu realmente sinto muito.
# Sentence in PT,  -Vamos lá. -Está bem.
# Sentence in BR,  -Vá em frente. -Certo.
# Sentence in PT,  Lamento imenso.
# Sentence in BR,  Sinto muito.
# Sentence in PT,  Vai!
# Sentence in BR,  Vá!
# Sentence in PT,  Está bem, está bem, está bem!
# Sentence in BR,  Ok, ok, ok!
# Sentence in PT,  Eu vou-me embora.
# Sentence in BR,  Eu estou indo.
# Total number of super different sentences: 1654
