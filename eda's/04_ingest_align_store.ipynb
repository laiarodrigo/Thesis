# %% [markdown]
# **//IMPORTS**

# %%
import os, gzip, requests, time
import pandas as pd
import pathlib, sys
import re
import matplotlib.pyplot as plt

from collections import Counter
from pathlib import Path
from datetime import datetime, timezone
from dotenv import load_dotenv         
from pathlib import Path
from opensubtitlescom import OpenSubtitles
from xmlrpc.client import ServerProxy, Error as XMLRPCError

project_root = pathlib.Path().resolve().parents[0] 
print(f"Project root: {project_root}")
sys.path.insert(0, str(project_root / "src"))
from db import connect     
from extract.access_open_subtitles import download_srt
from transform.align_subtitles import eliminate_new_lines, auto_sync_subs, align_subtitles_optimal_hungarian, clean_sub_blocks, strip_tags_str
from load.load_subtitles import load_subtitles
from catalog import collect_movies
from transform.align_subtitles import merge_subtitle_fragments
# Out:
# Project root: /home/rofarate/Thesis
# OpenSubtitles: logged-in session OK.

# %% [markdown]
# **//CONFIGS**

# %%
load_dotenv()

API_BASE = "https://api.opensubtitles.com/api/v1"
API_KEY = os.getenv("OPENSUBTITLES_API_KEY")
USERNAME = os.getenv("OPENSUBTITLES_USER", "")
PASSWORD = os.getenv("OPENSUBTITLES_PASS", "")
USER_AGENT = "MySubtitleApp/1.0"

# REST headers
# REST_HEADERS = {
#     "Api-Key":     API_KEY,
#     "User-Agent":  USER_AGENT,
#     "Content-Type":"application/json"
# }

# HEAD = {
#     "Api-Key": os.getenv("OPENSUBTITLES_API_KEY"),
#     "User-Agent": "TeseCollector/0.1",
#     "Accept": "application/json",
# }

BASE_HEADERS = {
    "Api-Key":     API_KEY,
    "User-Agent":  "MySubtitleApp/1.0",          # <- descriptive!
    "Accept":      "application/json",           # <- important
    "Content-Type":"application/json",
}
AUTH_HEADERS = dict(BASE_HEADERS)       # will gain 'Authorization' below

# XML-RPC client (fallback path)
ost = OpenSubtitles(user_agent=USER_AGENT, api_key=API_KEY)
# optional login for higher quotas
if USERNAME and PASSWORD:
    try:
        ost.login(USERNAME, PASSWORD)
    except Exception:
        pass

# YEARS AND LANGUAGES

YEARS = range(2023, 2024)          
LANGS = {"pt-br", "pt-pt"}             
by_lang = {lang: {} for lang in LANGS}

TIMEOUT = 15

tokenize = lambda text: re.findall(r"[A-Za-zÀ-ÖØ-öø-ÿ]+", text.lower())

# %%
p = Path("../data/duckdb")
p.mkdir(parents=True, exist_ok=True)

DUCKDB_PATH = Path("../data/duckdb/subs.duckdb")
PROCESSED_DIR = Path("../data/processed")        # <-- where anything derived lands
TIME_WINDOW = 60  

OS_API_KEY = os.getenv("OPENSUBTITLES_API_KEY")

# %%
def td_to_srt(ts) -> str:
    """
    Convert a pandas Timedelta *or* an integer millisecond offset
    to the SRT time-stamp string  HH:MM:SS,mmm
    """
    if isinstance(ts, (int, float)):             # already ms
        total_ms = int(ts)
    else:                                        # Timedelta  → ms
        total_ms = int(ts.total_seconds() * 1000)

    hours,   rem = divmod(total_ms, 3_600_000)
    minutes, rem = divmod(rem,        60_000)
    seconds, ms  = divmod(rem,         1_000)
    return f"{hours:02}:{minutes:02}:{seconds:02},{ms:03}"

def calculate_sentence_difference(row):
    pt_vocab = Counter(tokenize(row.text_pt))
    br_vocab = Counter(tokenize(row.text_br))
    shared   = set(pt_vocab) & set(br_vocab)
    return row.pair_id, shared

# %% [markdown]
# **//MAIN CODE**

# %%
con = connect()                     # ← runs the DDL, makes subs.duckdb
print(con.execute("PRAGMA show_tables").fetchall())
con.close()
# Out:
# [('movies',), ('subtitle_pairs',)]

# %%
total = collect_movies(range(2023, 2024))      # 2023 only
print("movies in DB:", total)
# Out:
# movies in DB: 672

# %%
con = connect()    
movies = con.execute("SELECT imdb_id, title FROM movies").fetchall()
len(movies)
# Out:
# 672

# %%
movies = movies[:100]
print(movies)
print(len(movies))
for imdb_id, title in movies:
    try:
        movie_id = con.execute(
            "SELECT movie_id FROM movies WHERE imdb_id = ?", 
            [imdb_id]
        ).fetchone()[0]

        # 2) skip if we've already stored pairs for this movie
        already = con.execute(
            "SELECT COUNT(*) FROM subtitle_pairs WHERE movie_id = ?", 
            [movie_id]
        ).fetchone()[0]
        if already:
            print(f"→ Skipping {imdb_id} ({title}), already in DB")
            continue
        # ---- download or reuse cache ------------------------------------
        pt_path = download_srt(imdb_id, "pt-PT", title=title)
        br_path = download_srt(imdb_id, "pt-BR", title=title)

        # ---- load & quick clean -----------------------------------------
        subs_pt = load_subtitles(pt_path)
        subs_br = load_subtitles(br_path)
        eliminate_new_lines(subs_pt)
        eliminate_new_lines(subs_br)
        
        clean_sub_blocks(subs_pt)
        clean_sub_blocks(subs_br)
                
        # ---- sentence-level merge (optional but helps alignment) --------
        subs_pt = merge_subtitle_fragments(subs_pt, gap_threshold=pd.Timedelta(seconds=0.2))
        subs_br = merge_subtitle_fragments(subs_br, gap_threshold=pd.Timedelta(seconds=0.2))

        # ---- auto sync --------------------------------------------------
        shifted_pt, final_offset = auto_sync_subs(subs_pt, subs_br)

        # ---- fine alignment --------------------------------------------
        pairs = align_subtitles_optimal_hungarian(shifted_pt, subs_br)

        rows = []
        pair_no = 1
        for pt, br, score in pairs:
            if br is None:
                continue                   # skip unmatched lines

            rows.append({
                "imdb_id": imdb_id,
                "pair_no":  pair_no,
                #"pair_no":  pair_no,
                # store the raw millis             (handy for SQL filtering)
                "start_pt_ms": int(pt["start"].total_seconds() * 1000),
                "end_pt_ms":   int(pt["end"].total_seconds()   * 1000),
                "start_br_ms": int(br["start"].total_seconds() * 1000),
                "end_br_ms":   int(br["end"].total_seconds()   * 1000),
                # and the pretty SRT strings       (for export / debugging)
                # "start_pt_ms": td_to_srt(pt["start"]),
                # "end_pt_ms":   td_to_srt(pt["end"]),
                # "start_br_ms": td_to_srt(br["start"]),
                # "end_br_ms":   td_to_srt(br["end"]),
                "text_pt": pt["text"],
                "text_br": br["text"],
                "score":   float(score),
            })
            pair_no += 1

        pairs_df = pd.DataFrame(rows)
        #con.execute("DELETE FROM subtitle_pairs WHERE imdb_id = ?", [imdb_id])
        con.register("pairs_df", pairs_df)

        con.execute("""
            INSERT INTO subtitle_pairs (
            movie_id,
            pair_no,
            start_pt_ms,
            end_pt_ms,
            text_pt,
            start_br_ms,
            end_br_ms,
            text_br,
            score
            )
            SELECT
            m.movie_id,
            p.pair_no,
            p.start_pt_ms,
            p.end_pt_ms,
            p.text_pt,
            p.start_br_ms,
            p.end_br_ms,
            p.text_br,
            p.score
            FROM pairs_df AS p
            JOIN movies   AS m
            ON p.imdb_id = m.imdb_id
            """)
        
        print(f"✓ Movie {imdb_id} ({title}) in the database")

    except RuntimeError as e:        # e.g. no subtitles, 5xx after retries
        print("✗", imdb_id, title, "→", e)
    except Exception as e:
        print("⚠️  unexpected failure on", imdb_id, ":", e)
# Out:
# [('14230458', 'Poor Things'), ('15764854', 'Fireworks'), ('26449465', 'Peak Season'), ('19883634', 'The Old Oak'), ('27805677', 'Fairlane'), ('20465746', "L'ultima notte di Amore"), ('26671415', 'Seven Veils'), ('22687790', 'A Haunting in Venice'), ('5478456', 'We Are Zombies'), ('18072882', 'Northern Comfort'), ('11767724', 'Skunk'), ('13652142', 'Magazine Dreams'), ('7737800', 'Woman of the Hour'), ('22751422', 'The Accidental Getaway Driver'), ('22375054', 'Strange Darling'), ('21810682', 'The End We Start From'), ('14636170', 'Metalocalypse: Army of the Doomstar'), ('21267296', 'Hell of a Summer'), ('15428134', 'Dunki'), ('27047448', 'Til Death Do Us Part'), ('20358284', 'The Lesson'), ('24486184', 'Big Boys'), ('15038732', 'Chantilly Bridge'), ('10381102', 'Brave the Dark'), ('27722543', 'The Green Border'), ('22041854', 'Priscilla'), ('22023218', "You'll Never Find Me"), ('4589218', "Five Nights at Freddy's"), ('5112584', 'Lee'), ('22890246', 'How to Have Sex'), ('6495056', 'Migration'), ('6979756', 'Creation of the Gods I: Kingdom of Storms'), ('15789472', 'Nowhere'), ('13457790', 'The Critic'), ('5755238', 'Leo'), ('26674627', 'Resident Evil: Death Island'), ('20114976', 'The Sacrifice Game'), ('3234122', 'Widow Clicquot'), ('10545296', 'The Hunger Games: The Ballad of Songbirds &amp; Snakes'), ('15353574', 'Hard Miles'), ('7160372', 'The Zone of Interest'), ('14561712', 'La Chimera'), ('14537248', 'Nefarious'), ('14097206', 'The Unlikely Pilgrimage of Harold Fry'), ('26369131', 'Squared Love All Over Again'), ('22207786', 'Red Rooms'), ('27503384', 'Perfect Days'), ('24068064', 'Reality'), ('29497240', 'The Only Girl in the Orchestra'), ('13650540', 'If You Were the Last'), ('14748950', 'All to Play For'), ('13429870', 'Robot Dreams'), ('11068094', 'White Bird'), ('11932678', 'Southern Gospel'), ('13232552', 'The Man in the White Van'), ('13287846', 'Napoleon'), ('6195756', 'Wonderwell'), ('26315142', 'Tótem'), ('14407336', 'The Beast'), ('21909764', 'Culpa mía'), ('22773644', "The Dead Don't Hurt"), ('14966898', 'Late Night with the Devil'), ('18304514', 'Impulse'), ('15078804', 'Problemista'), ('10651230', 'The Peasants'), ('9663896', 'Asphalt City'), ('10160976', 'The Nun II'), ('23952252', 'Control'), ('19798116', 'Bytte bytte baby'), ('28366692', 'Janet Planet'), ('17505998', 'Walking Supply'), ('23289160', 'Godzilla Minus One'), ('26520932', 'Wild Life'), ('24082454', 'Perpetrator'), ('24082864', "I'll Be Right There"), ('15257160', 'Pain Hustlers'), ('20102596', 'LaRoy, Texas'), ('10276482', 'Love Again'), ('6722400', 'Fast Charlie'), ('26744289', 'Infested'), ('3468380', 'Which Brings Me to You'), ('20115766', 'Knox Goes Away'), ('27498099', 'The Last Boy on Earth'), ('28259207', 'Kill'), ('14509110', 'No One Will Save You'), ('11858890', 'The Creator'), ('8417168', 'Rally Road Racers'), ('13055264', 'Strange Way of Life'), ('13521006', 'Beau Is Afraid'), ('2906216', 'Dungeons &amp; Dragons: Honor Among Thieves'), ('13539646', 'The Wandering Earth II'), ('15239014', 'Creeping Death'), ('14682800', 'Tuesday'), ('14633464', 'Desperation Road'), ('15783520', 'On Fire'), ('20561198', 'The Promised Land'), ('22640398', 'V/H/S/85'), ('13978520', 'Spy Kids: Armageddon'), ('1001520', 'The Last Voyage of the Demeter'), ('26442871', 'Wildcat')]
# 100
# → Skipping 14230458 (Poor Things), already in DB
# → Skipping 15764854 (Fireworks), already in DB
# → Skipping 26449465 (Peak Season), already in DB
# → Skipping 19883634 (The Old Oak), already in DB
# → Skipping 27805677 (Fairlane), already in DB
# → Skipping 20465746 (L'ultima notte di Amore), already in DB
# → Skipping 26671415 (Seven Veils), already in DB
# → Skipping 22687790 (A Haunting in Venice), already in DB
# → Skipping 5478456 (We Are Zombies), already in DB
# → Skipping 18072882 (Northern Comfort), already in DB
# → Skipping 11767724 (Skunk), already in DB
# → Skipping 13652142 (Magazine Dreams), already in DB
# → Skipping 7737800 (Woman of the Hour), already in DB
# → Skipping 22751422 (The Accidental Getaway Driver), already in DB
# → Skipping 22375054 (Strange Darling), already in DB
# → Skipping 21810682 (The End We Start From), already in DB
# → Skipping 14636170 (Metalocalypse: Army of the Doomstar), already in DB
# → Skipping 21267296 (Hell of a Summer), already in DB
# → Skipping 15428134 (Dunki), already in DB
# → Skipping 27047448 (Til Death Do Us Part), already in DB
# → Skipping 20358284 (The Lesson), already in DB
# → Skipping 24486184 (Big Boys), already in DB
# → Skipping 15038732 (Chantilly Bridge), already in DB
# → Skipping 10381102 (Brave the Dark), already in DB
# → Skipping 27722543 (The Green Border), already in DB
# → Skipping 22041854 (Priscilla), already in DB
# → Skipping 22023218 (You'll Never Find Me), already in DB
# → Skipping 4589218 (Five Nights at Freddy's), already in DB
# → Skipping 5112584 (Lee), already in DB
# → Skipping 22890246 (How to Have Sex), already in DB
# → Skipping 6495056 (Migration), already in DB
# → Skipping 6979756 (Creation of the Gods I: Kingdom of Storms), already in DB
# → Skipping 15789472 (Nowhere), already in DB
# → Skipping 13457790 (The Critic), already in DB
# → Skipping 5755238 (Leo), already in DB
# → Skipping 26674627 (Resident Evil: Death Island), already in DB
# → Skipping 20114976 (The Sacrifice Game), already in DB
# → Skipping 3234122 (Widow Clicquot), already in DB
# → Skipping 10545296 (The Hunger Games: The Ballad of Songbirds &amp; Snakes), already in DB
# → Skipping 15353574 (Hard Miles), already in DB
# → Skipping 7160372 (The Zone of Interest), already in DB
# → Skipping 14561712 (La Chimera), already in DB
# → Skipping 14537248 (Nefarious), already in DB
# → Skipping 14097206 (The Unlikely Pilgrimage of Harold Fry), already in DB
# → Skipping 26369131 (Squared Love All Over Again), already in DB
# → Skipping 22207786 (Red Rooms), already in DB
# → Skipping 27503384 (Perfect Days), already in DB
# → Skipping 24068064 (Reality), already in DB
# Offset +0.000s (max 4.296)  Coverage 0.102  Mean 0.994
# Offset +0.000s (max 4.296)  Coverage 0.102  Mean 0.994
# Offset +0.000s (max 4.296)  Coverage 0.102  Mean 0.994
# plateau → stop
# ✓ Movie 29497240 (The Only Girl in the Orchestra) in the database
# Offset -0.009s (max 2.962)  Coverage 0.100  Mean 0.958
# Offset +0.000s (max 2.971)  Coverage 0.101  Mean 0.958
# Offset +0.000s (max 2.971)  Coverage 0.101  Mean 0.958
# Offset +0.000s (max 2.971)  Coverage 0.101  Mean 0.958
# plateau → stop
# ✓ Movie 13650540 (If You Were the Last) in the database
# Offset -19.734s (max 30.946)  Coverage 0.101  Mean 0.882
# Offset -0.002s (max 0.640)  Coverage 0.100  Mean 0.981
# Offset +0.000s (max 1.325)  Coverage 0.100  Mean 0.981
# Offset +0.000s (max 1.325)  Coverage 0.100  Mean 0.981
# plateau → stop
# ✓ Movie 14748950 (All to Play For) in the database
# Offset +0.008s (max 0.472)  Coverage 0.143  Mean 0.502
# Offset +0.000s (max 0.464)  Coverage 0.143  Mean 0.502
# Offset +0.000s (max 0.464)  Coverage 0.143  Mean 0.502
# plateau → stop
# ✓ Movie 13429870 (Robot Dreams) in the database
# Offset -0.037s (max 3.285)  Coverage 0.101  Mean 0.996
# Offset +0.000s (max 3.248)  Coverage 0.101  Mean 0.996
# Offset +0.000s (max 3.248)  Coverage 0.101  Mean 0.996
# plateau → stop
# ✓ Movie 11068094 (White Bird) in the database
# Offset +6.287s (max 6.481)  Coverage 0.100  Mean 0.969
# Offset +0.049s (max 0.216)  Coverage 0.100  Mean 1.000
# Offset +0.014s (max 0.182)  Coverage 0.100  Mean 1.000
# Offset +0.001s (max 0.193)  Coverage 0.100  Mean 1.000
# plateau → stop
# ✓ Movie 11932678 (Southern Gospel) in the database
# Offset +0.000s (max 0.126)  Coverage 0.101  Mean 1.000
# Offset +0.000s (max 0.126)  Coverage 0.101  Mean 1.000
# Offset +0.000s (max 0.126)  Coverage 0.101  Mean 1.000
# plateau → stop
# ✓ Movie 13232552 (The Man in the White Van) in the database
# Offset -0.054s (max 0.054)  Coverage 0.178  Mean 1.000
# Offset +0.000s (max 0.000)  Coverage 0.153  Mean 1.000
# ✓ Movie 13287846 (Napoleon) in the database
# Offset -17.995s (max 19.274)  Coverage 0.100  Mean 0.890
# Offset -0.008s (max 1.278)  Coverage 0.100  Mean 0.977
# Offset +0.000s (max 1.270)  Coverage 0.100  Mean 0.977
# Offset +0.000s (max 1.270)  Coverage 0.100  Mean 0.977
# plateau → stop
# ✓ Movie 6195756 (Wonderwell) in the database
# Offset +33.594s (max 59.529)  Coverage 0.100  Mean 0.732
# Offset +9.562s (max 43.977)  Coverage 0.101  Mean 0.867
# Offset +4.083s (max 39.813)  Coverage 0.101  Mean 0.883
# Offset +1.923s (max 36.779)  Coverage 0.100  Mean 0.888
# Offset +1.900s (max 34.856)  Coverage 0.101  Mean 0.888
# Offset +0.852s (max 39.616)  Coverage 0.100  Mean 0.889
# Offset +0.201s (max 38.764)  Coverage 0.100  Mean 0.890
# Offset +0.119s (max 38.563)  Coverage 0.100  Mean 0.890
# Offset +0.000s (max 38.444)  Coverage 0.100  Mean 0.890
# plateau → stop
# ✓ Movie 26315142 (Tótem) in the database
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008342 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008342}
# ✗ 14407336 The Beast → No pt-PT subs for 14407336 (The Beast)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008342 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008342}
# ✗ 21909764 Culpa mía → No pt-PT subs for 21909764 (Culpa mía)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008342 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008342}
# ✗ 22773644 The Dead Don't Hurt → No pt-PT subs for 22773644 (The Dead Don't Hurt)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008343 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008343}
# ✗ 14966898 Late Night with the Devil → No pt-PT subs for 14966898 (Late Night with the Devil)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008343 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008343}
# ✗ 18304514 Impulse → No pt-PT subs for 18304514 (Impulse)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008343 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008343}
# ✗ 15078804 Problemista → No pt-PT subs for 15078804 (Problemista)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008344 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008344}
# ✗ 10651230 The Peasants → No pt-PT subs for 10651230 (The Peasants)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008344 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008344}
# ✗ 9663896 Asphalt City → No pt-PT subs for 9663896 (Asphalt City)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008344 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008344}
# ✗ 10160976 The Nun II → No pt-PT subs for 10160976 (The Nun II)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008344 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008344}
# ✗ 23952252 Control → No pt-PT subs for 23952252 (Control)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008345 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008345}
# ✗ 19798116 Bytte bytte baby → No pt-PT subs for 19798116 (Bytte bytte baby)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008345 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008345}
# ✗ 28366692 Janet Planet → No pt-PT subs for 28366692 (Janet Planet)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008346 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008346}
# ✗ 17505998 Walking Supply → No pt-PT subs for 17505998 (Walking Supply)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008346 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008346}
# ✗ 23289160 Godzilla Minus One → No pt-PT subs for 23289160 (Godzilla Minus One)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008346 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008346}
# ✗ 26520932 Wild Life → No pt-PT subs for 26520932 (Wild Life)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008346 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008346}
# ✗ 24082454 Perpetrator → No pt-PT subs for 24082454 (Perpetrator)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008347 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008347}
# ✗ 24082864 I'll Be Right There → No pt-PT subs for 24082864 (I'll Be Right There)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008348 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008348}
# ✗ 15257160 Pain Hustlers → No pt-PT subs for 15257160 (Pain Hustlers)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008348 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008348}
# ✗ 20102596 LaRoy, Texas → No pt-PT subs for 20102596 (LaRoy, Texas)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008349 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008349}
# ✗ 10276482 Love Again → No pt-PT subs for 10276482 (Love Again)
# ⚠️  unexpected failure on 6722400 : 429 Client Error: Too Many Requests for url: https://api.opensubtitles.com/api/v1/subtitles?imdb_id=6722400&languages=pt-pt&order_by=downloads
# ⚠️  unexpected failure on 26744289 : 429 Client Error: Too Many Requests for url: https://api.opensubtitles.com/api/v1/subtitles?imdb_id=26744289&languages=pt-pt&order_by=downloads
# ⚠️  unexpected failure on 3468380 : 429 Client Error: Too Many Requests for url: https://api.opensubtitles.com/api/v1/subtitles?imdb_id=3468380&languages=pt-pt&order_by=downloads
# ⚠️  unexpected failure on 20115766 : 429 Client Error: Too Many Requests for url: https://api.opensubtitles.com/api/v1/subtitles?imdb_id=20115766&languages=pt-pt&order_by=downloads
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008350 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008350}
# ✗ 27498099 The Last Boy on Earth → No pt-PT subs for 27498099 (The Last Boy on Earth)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008350 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008350}
# ✗ 28259207 Kill → No pt-PT subs for 28259207 (Kill)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008350 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008350}
# ✗ 14509110 No One Will Save You → No pt-PT subs for 14509110 (No One Will Save You)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008351 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008351}
# ✗ 11858890 The Creator → No pt-PT subs for 11858890 (The Creator)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008351 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008351}
# ✗ 8417168 Rally Road Racers → No pt-PT subs for 8417168 (Rally Road Racers)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008351 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008351}
# ✗ 13055264 Strange Way of Life → No pt-PT subs for 13055264 (Strange Way of Life)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008352 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008352}
# ✗ 13521006 Beau Is Afraid → No pt-PT subs for 13521006 (Beau Is Afraid)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008352 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008352}
# ✗ 2906216 Dungeons &amp; Dragons: Honor Among Thieves → No pt-PT subs for 2906216 (Dungeons &amp; Dragons: Honor Among Thieves)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008352 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008352}
# ✗ 13539646 The Wandering Earth II → No pt-PT subs for 13539646 (The Wandering Earth II)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008352 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008352}
# ✗ 15239014 Creeping Death → No pt-PT subs for 15239014 (Creeping Death)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008353 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008353}
# ✗ 14682800 Tuesday → No pt-PT subs for 14682800 (Tuesday)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008353 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008353}
# ✗ 14633464 Desperation Road → No pt-PT subs for 14633464 (Desperation Road)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008353 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008353}
# ✗ 15783520 On Fire → No pt-PT subs for 15783520 (On Fire)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008353 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008353}
# ✗ 20561198 The Promised Land → No pt-PT subs for 20561198 (The Promised Land)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008354 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008354}
# ✗ 22640398 V/H/S/85 → No pt-PT subs for 22640398 (V/H/S/85)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008354 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008354}
# ✗ 13978520 Spy Kids: Armageddon → No pt-PT subs for 13978520 (Spy Kids: Armageddon)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:58 UTC) ts=1753008354 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:58.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008354}
# ✗ 1001520 The Last Voyage of the Demeter → No pt-PT subs for 1001520 (The Last Voyage of the Demeter)
# Download refused: {'requests': 21, 'remaining': -1, 'message': 'You have downloaded your allowed 20 subtitles for 24h.Your quota will be renewed in 13 hours and 14 minutes (2025-07-20 23:59:59 UTC) ts=1753008355 ', 'reset_time': '13 hours and 14 minutes', 'reset_time_utc': '2025-07-20T23:59:59.000Z', 'uk': 'count_uid_1021626', 'uid': 1021626, 'ts': 1753008355}
# ✗ 26442871 Wildcat → No pt-PT subs for 26442871 (Wildcat)

# %%
df_subtitle_pairs = con.execute("SELECT * FROM subtitle_pairs").df()

# df_subtitle_pairs['text_pt'] = df_subtitle_pairs['text_pt'].apply(strip_tags).str.strip()
# df_subtitle_pairs['text_br'] = df_subtitle_pairs['text_br'].apply(strip_tags).str.strip()

print(f"Subtitle pairs in DB: {len(df_subtitle_pairs)}")
low_scores_in_db = df_subtitle_pairs[df_subtitle_pairs.score < 0.4]
medium_scores_in_db = df_subtitle_pairs[(df_subtitle_pairs.score >= 0.4) & (df_subtitle_pairs.score < 0.7)]
high_scores_in_db = df_subtitle_pairs[df_subtitle_pairs.score >= 0.7]
# Out:
# Subtitle pairs in DB: 59023

# %%
pt_pt_vocab = Counter(
    token
    for sent in df_subtitle_pairs.text_pt
    for token in tokenize(sent)
)
pt_br_vocab = Counter(
    token
    for sent in df_subtitle_pairs.text_br
    for token in tokenize(sent)
)

shared       = set(pt_pt_vocab) & set(pt_br_vocab)
unique_pt_pt = set(pt_pt_vocab) - set(pt_br_vocab)
unique_pt_br = set(pt_br_vocab) - set(pt_pt_vocab)

print("Vocab sizes:", len(pt_pt_vocab), len(pt_br_vocab))
print("Shared types:",    len(shared))
print("Unique PT-PT types:", len(unique_pt_pt))
print("Unique PT-BR types:", len(unique_pt_br))

# Top-20 distinctive tokens on each side
pt_pt_distinct = sorted(unique_pt_pt, key=lambda t: pt_pt_vocab[t], reverse=True)[:20]
pt_br_distinct = sorted(unique_pt_br, key=lambda t: pt_br_vocab[t], reverse=True)[:20]
print("Top PT-PT distinct:", pt_pt_distinct)
print("Top PT-BR distinct:", pt_br_distinct)
# Out:
# Vocab sizes: 21572 20858
# Shared types: 15148
# Unique PT-PT types: 6424
# Unique PT-BR types: 5710
# Top PT-PT distinct: ['sabes', 'vais', 'podes', 'demasiado', 'fizeste', 'sítio', 'disseste', 'miúdos', 'rapariga', 'facto', 'foste', 'fixe', 'bebé', 'estavas', 'fazes', 'devias', 'precisas', 'vês', 'consegues', 'viste']
# Top PT-BR distinct: ['garoto', 'alô', 'demônio', 'tô', 'garotas', 'bunda', 'somente', 'fengshen', 'garotos', 'prêmio', 'heia', 'besteira', 'belarus', 'ônibus', 'pedindo', 'policial', 'transar', 'allah', 'su', 'entendendo']

# %% [markdown]
# **//GOOD SCORES ANALYSIS**

# %%
good_row_count = len(high_scores_in_db)
print(f"Subtitle pairs in DB: {good_row_count}")

high_scores_in_db['text_pt'] = high_scores_in_db['text_pt'].apply(strip_tags_str).str.strip()
high_scores_in_db['text_br'] = high_scores_in_db['text_br'].apply(strip_tags_str).str.strip()

high_scores_in_db
# Out:
# Subtitle pairs in DB: 41230
# /tmp/ipykernel_3119/1097498026.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_scores_in_db['text_pt'] = high_scores_in_db['text_pt'].apply(strip_tags_str).str.strip()
# /tmp/ipykernel_3119/1097498026.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_scores_in_db['text_br'] = high_scores_in_db['text_br'].apply(strip_tags_str).str.strip()
#        pair_id  movie_id  pair_no  start_pt_ms  end_pt_ms  \
# 0            1         1        1          980       5938
# 1            2         1        2       111772     118272
# 2            3         1        3       286522     288480
# 5            6         1        6       301147     305605
# 6            7         1        7       305772     310772
# ...        ...       ...      ...          ...        ...
# 58418    58419        58      423      2170565    2171941
# 58421    58422        58      426      2180199    2182076
# 58426    58427        58      431      2199218    2200512
# 58480    58481        58      485      2344322    2345282
# 58485    58486        58      490      2358085    2359128
#
#                                                  text_pt  start_br_ms  \
# 0            CONTÉM REPRESENTAÇÕES DE PRODUTOS DE TABACO         1000
# 1                                       POBRES CRIATURAS       111800
# 2                                                 Adeus!       286542
# 5                Quem gostaria de reconstruir os órgãos?       301167
# 6      E quem consegue distinguir humano de animal, i...       305792
# ...                                                  ...          ...
# 58418                                   Eu acho que sim.      2115680
# 58421                             O que você bebeu, Sol?      2124600
# 58426                             Você já provou sangue?      2142720
# 58480                                              Isso.      2294920
# 58485                                              Isso.      2301720
#
#        end_br_ms                                            text_br     score
# 0           6000                          HÁ CENAS DE USO DE TABACO  0.712900
# 1         118100                                   POBRES CRIATURAS  0.999860
# 2         288500                                             Adeus.  0.880900
# 5         305625         Bem, quem gostaria de recolocar os órgãos?  0.852900
# 6         310792  E quem pode distinguir o humano do animal, se ...  0.873900
# ...          ...                                                ...       ...
# 58418    2117360                                   Eu acho que sim.  0.725575
# 58421    2126800                             O que você bebeu, Sol?  0.722005
# 58426    2144600                             Você já provou sangue?  0.717510
# 58480    2296720                                              Isso.  0.752990
# 58485    2302960                                              Isso.  0.718175
#
# [41230 rows x 10 columns]

# %% [markdown]
# **//BAD SCORES ANALYSIS**

# %%
bad_row_count = len(low_scores_in_db)
print(f"Low-score pairs in DB: {bad_row_count}")

low_scores_in_db['text_pt'] = low_scores_in_db['text_pt'].apply(strip_tags_str).str.strip()
low_scores_in_db['text_br'] = low_scores_in_db['text_br'].apply(strip_tags_str).str.strip()

low_scores_in_db
# Out:
# Low-score pairs in DB: 1393
# /tmp/ipykernel_3119/1448298724.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_scores_in_db['text_pt'] = low_scores_in_db['text_pt'].apply(strip_tags_str).str.strip()
# /tmp/ipykernel_3119/1448298724.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_scores_in_db['text_br'] = low_scores_in_db['text_br'].apply(strip_tags_str).str.strip()
#        pair_id  movie_id  pair_no  start_pt_ms  end_pt_ms  \
# 192        193         1      193      1352272    1353355
# 401        402         1      402      2526522    2527688
# 1186      1187         1     1187      6586480    6587355
# 1206      1207         1     1207      6667938    6670688
# 1244      1245         1     1245      6846647    6847522
# ...        ...       ...      ...          ...        ...
# 59016    59017        58     1021      5041798    5046150
# 59017    59018        58     1022      5046150    5049993
# 59018    59019        58     1023      5049993    5056084
# 59019    59020        58     1024      5056084    5061863
# 59020    59021        58     1025      5061863    5066679
#
#                        text_pt  start_br_ms  end_br_ms  \
# 192             E para sempre.      1363667    1367458
# 401               Uma pândega!      2526542    2527708
# 1186      Armou-me uma cilada!      6549125    6552542
# 1206         FALECIDO em Breve      6641500    6644292
# 1244                    Cabra!      6835167    6836167
# ...                        ...          ...        ...
# 59016                 Ah, sim!      4988160    4990280
# 59017                 Para mim      4997640    4999320
# 59018  O céu é lindo para mim!      5016800    5019480
# 59019                 Ah, sim!      5025800    5027680
# 59020                 Para mim      5019520    5021560
#
#                                                text_br     score
# 192    ou prisões mal equipadas e poucos funcionários?  0.355025
# 401                                           Delícia.  0.369900
# 1186      Um diabo em um corpo sedutor e insaciável...  0.330225
# 1206                        Idiota com cara de boceta.  0.370810
# 1244                                              Bam.  0.382600
# ...                                                ...       ...
# 59016                                      Uau, mamãe!  0.325810
# 59017                                  Obrigado, Nuri.  0.302450
# 59018            O que vou desejar? Um par de botas...  0.393035
# 59019                                   Não há desejo.  0.337580
# 59020                           Faça um desejo! Vamos.  0.319285
#
# [1393 rows x 10 columns]

# %% [markdown]
# **//MEDIUM SCORES ANALYSIS**

# %%
medium_row_count = len(medium_scores_in_db)
print(f"Medium-score pairs in DB: {medium_row_count}")

medium_scores_in_db['text_pt'] = medium_scores_in_db['text_pt'].apply(strip_tags_str).str.strip()
medium_scores_in_db['text_br'] = medium_scores_in_db['text_br'].apply(strip_tags_str).str.strip()

medium_scores_in_db
# Out:
# Medium-score pairs in DB: 16400
# /tmp/ipykernel_3119/3615569889.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   medium_scores_in_db['text_pt'] = medium_scores_in_db['text_pt'].apply(strip_tags_str).str.strip()
# /tmp/ipykernel_3119/3615569889.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   medium_scores_in_db['text_br'] = medium_scores_in_db['text_br'].apply(strip_tags_str).str.strip()
#        pair_id  movie_id  pair_no  start_pt_ms  end_pt_ms  \
# 3            4         1        4       291647     297688
# 4            5         1        5       297855     300688
# 7            8         1        8       313938     314772
# 8            9         1        9       315480     318813
# 13          14         1       14       333897     336063
# ...        ...       ...      ...          ...        ...
# 59010    59011        58     1015      5011140    5017395
# 59011    59012        58     1016      5017395    5023016
# 59012    59013        58     1017      5023016    5027916
# 59021    59022        58     1026      5168771    5171274
# 59022    59023        58     1027      5177488    5179198
#
#                                                  text_pt  start_br_ms  \
# 3      Uma pilha de órgãos sem a centelha de humanida...       291667
# 4        Parece a banca de um talhante para um banquete.       297875
# 7                                                 Vá lá!       313958
# 8                    Fizeram puzzles em crianças, certo?       315500
# 13                A tua proximidade não quer dizer nada.       333917
# ...                                                  ...          ...
# 59010                             Pelo meu corpo terreno      5009600
# 59011                         Enquanto lá em cima no céu      5004640
# 59012                                          Eu orarei      5007520
# 59021                                    A Nuri arrasou.      5164440
# 59022                                 De nada, meu amor.      5158381
#
#        end_br_ms                                            text_br     score
# 3         295458  Um monte de órgãos sem a centelha de si na men...  0.677900
# 4         300708  É só um prato do açougueiro para o almoço de d...  0.551900
# 7         314792                                             Vamos!  0.530900
# 8         318833      Montavam quebra-cabeças quando crianças, não?  0.649900
# 13        336083  Sua proximidade física conosco não o inclui nela.  0.698900
# ...          ...                                                ...       ...
# 59010    5012600                      Quero igual, mas com sereias.  0.593300
# 59011    5007480  Sim, meu irmão e minhas irmãs estão zombando d...  0.453225
# 59012    5009560                                        Super nerd.  0.432520
# 59021    5168480                                   PARA MINHA FILHA  0.460345
# 59022    5161883                    Legendas: Kleen Sonata Première  0.491465
#
# [16400 rows x 10 columns]

# %%
sentence_difference = {}
different_sentence_count = 0

for row in medium_scores_in_db.itertuples():
    pid, shared = calculate_sentence_difference(row)
    sentence_difference[pid] = shared

print("Sentence more different:")
for pid, shared in sentence_difference.items():
    if len(shared) < 2:  # threshold for "more different"
        different_sentence_count += 1
        print(f"Sentence in PT, ", medium_scores_in_db.loc[medium_scores_in_db.pair_id == pid, 'text_pt'].values[0])
        print(f"Sentence in BR, ", medium_scores_in_db.loc[medium_scores_in_db.pair_id == pid, 'text_br'].values[0])

print(f"Total number of super different sentences: {different_sentence_count}")
# Out:
# Sentence more different:
# Sentence in PT,  Vá lá!
# Sentence in BR,  Vamos!
# Sentence in PT,  Fizeram puzzles em crianças, certo?
# Sentence in BR,  Montavam quebra-cabeças quando crianças, não?
# Sentence in PT,  Não chateies! Vai comprar um fato.
# Sentence in BR,  Vá se foder, velho amigo. Consiga um traje.
# Sentence in PT,  Ia gostar bastante.
# Sentence in BR,  Adoraria isso.
# Sentence in PT,  A piada é minha.
# Sentence in BR,  Foi uma piada que inventei.
# Sentence in PT,  Parece obra do demónio.
# Sentence in BR,  Servo do diabo!
# Sentence in PT,  Se deixasse crescer a barba?
# Sentence in BR,  Já pensou em ficar com barba, senhor?
# Sentence in PT,  Este trabalho.
# Sentence in BR,  Trabalha aqui.
# Sentence in PT,  Sim. Vamos.
# Sentence in BR,  Sim. Entre.
# Sentence in PT,  E eu reparei-a.
# Sentence in BR,  Notei.
# Sentence in PT,  Tenho de anotar os progressos meticulosamente.
# Sentence in BR,  Preciso anotar minuciosamente seu progresso.
# Sentence in PT,  Pode ajudar-me a fazer isso?
# Sentence in BR,  Fará isso por mim?
# Sentence in PT,  Por acaso até gosto.
# Sentence in BR,  Nem sempre os aprecio, na verdade.
# Sentence in PT,  Quando acrescentar questões idiotas, avisar-te-ei.
# Sentence in BR,  Quando quiser perguntas fúteis, lhe avisarei.
# Sentence in PT,  O que ser isso? Nenhures?
# Sentence in BR,  Onde é lugar nenhum?
# Sentence in PT,  Então cortares pais?
# Sentence in BR,  Matou meus pais, God?
# Sentence in PT,  Eles expandiram as fronteiras do conhecimento e pagaram caro por isso.
# Sentence in BR,  Ultrapassaram os limites do que era conhecido...
# Sentence in PT,  Isto, pais.
# Sentence in BR,  Aqui, meus pais.
# Sentence in PT,  Porquê escrever cada fruto?
# Sentence in BR,  Por que anota cada noz que como?
# Sentence in PT,  Só...
# Sentence in BR,  Espere...
# Sentence in PT,  Valha-me Deus!
# Sentence in BR,  Santo Deus!
# Sentence in PT,  Bella comer gelado querer.
# Sentence in BR,  Bella quer pegar sorvete.
# Sentence in PT,  Rir da minha cara.
# Sentence in BR,  Vão rir de God.
# Sentence in PT,  Deveras.
# Sentence in BR,  Isso mesmo.
# Sentence in PT,  Só não.
# Sentence in BR,  Apenas não.
# Sentence in PT,  Valha-me Deus!
# Sentence in BR,  Mãe de Deus.
# Sentence in PT,  Está a escondê-la porquê?
# Sentence in BR,  Por que a esconde?
# Sentence in PT,  Deus do Céu!
# Sentence in BR,  Jesus!
# Sentence in PT,  Tens de parar de fazer isso.
# Sentence in BR,  Pare com isso imediatamente.
# Sentence in PT,  Não comeste.
# Sentence in BR,  você não comeu nada.
# Sentence in PT,  Não!
# Sentence in BR,  Não faça.
# Sentence in PT,  Sentir esquisito?
# Sentence in BR,  Se sente divertido?
# Sentence in PT,  Não é indecência.
# Sentence in BR,  Não totalmente sombrios.
# Sentence in PT,  A que disseste...
# Sentence in BR,  Ao aceitar isso...
# Sentence in PT,  Este Contrato Atesta
# Sentence in BR,  Farei um contrato legal.
# Sentence in PT,  Asseguro que tem valor legal na mesma.
# Sentence in BR,  Isso é irrelevante para sua validade, eu garanto.
# Sentence in PT,  Não consegue aguentar? É alguma criança?
# Sentence in BR,  Você tem cinco anos pra não conseguir segurar um pouco?
# Sentence in PT,  É bastante bom!
# Sentence in BR,  Ficou bem e ridículo.
# Sentence in PT,  Estou a ver.
# Sentence in BR,  Entendo a razão.
# Sentence in PT,  Compreendo porquê.
# Sentence in BR,  Entendi.
# Sentence in PT,  Nem pense...
# Sentence in BR,  Não vai...
# Sentence in PT,  Tu ser quem?
# Sentence in BR,  Quem é você?
# Sentence in PT,  Trepei.
# Sentence in BR,  Escalei.
# Sentence in PT,  Não queiras saber de modos.
# Sentence in BR,  Não se importe com essa educação
# Sentence in PT,  É muito aborrecido.
# Sentence in BR,  É chata pra cacete.
# Sentence in PT,  Aquele cão asqueroso.
# Sentence in BR,  Aquele cachorro deformado.
# Sentence in PT,  Essa mesma.
# Sentence in BR,  Falo dessa Lisboa.
# Sentence in PT,  Pergunto-te a ti.
# Sentence in BR,  Estou perguntando a você.
# Sentence in PT,  Sem dúvida... que não.
# Sentence in BR,  Absolutamente... não!
# Sentence in PT,  Vou deter-te.
# Sentence in BR,  Eu impedirei.
# Sentence in PT,  Prendes Bella com muita força.
# Sentence in BR,  Você prende Bella demais.
# Sentence in PT,  Preciso de ver o mundo.
# Sentence in BR,  Preciso sair pelas águas.
# Sentence in PT,  Não pode ser!
# Sentence in BR,  Não é aceitável.
# Sentence in PT,  Eu mesmo trato dele.
# Sentence in BR,  Vou atrás desse homem.
# Sentence in PT,  Vou esmagar-lhe o crânio!
# Sentence in BR,  Vou moer a porra da cabeça dele.
# Sentence in PT,  Adeus, futura pomba.
# Sentence in BR,  Até mais tarde pombinho.
# Sentence in PT,  Ela partiu.
# Sentence in BR,  Ela se foi.
# Sentence in PT,  É dizer pouco.
# Sentence in BR,  Ela subestima isso.
# Sentence in PT,  Chupar e engolir.
# Sentence in BR,  Abra, vire e sugue.
# Sentence in PT,  Uma pândega.
# Sentence in BR,  Delícia.
# Sentence in PT,  Tenho pena de ti.
# Sentence in BR,  Sinto por você.
# Sentence in PT,  Bem, então serás o meu escolhido para brincar.
# Sentence in BR,  Então serão só com você os saltos furiosos.
# Sentence in PT,  Brincar?
# Sentence in BR,  Saltos furiosos?
# Sentence in PT,  Outra vez?
# Sentence in BR,  De novo?
# Sentence in PT,  Percebo.
# Sentence in BR,  Entendo.
# Sentence in PT,  Não.
# Sentence in BR,  Isso não.
# Sentence in PT,  O elétrico.
# Sentence in BR,  O bonde.
# Sentence in PT,  Foi um espanto.
# Sentence in BR,  Surpresa para Bella.
# Sentence in PT,  É encantador.
# Sentence in BR,  É tão charmoso.
# Sentence in PT,  Incrivelmente sagaz!
# Sentence in BR,  Muito inspirada!
# Sentence in PT,  Adorei!
# Sentence in BR,  Amei
# Sentence in PT,  És tão perversa.
# Sentence in BR,  Você é travessa.
# Sentence in PT,  Estás a falar do pénis dele.
# Sentence in BR,  Oh... quer dizer o pênis dele.
# Sentence in PT,  É encantador.
# Sentence in BR,  o bebê incomodando...
# Sentence in PT,  Deus me valha!
# Sentence in BR,  Meu Deus.
# Sentence in PT,  - Será? - Será?
# Sentence in BR,  - Acha que estão fodendo?
# Sentence in PT,  E...
# Sentence in BR,  E ainda...
# Sentence in PT,  a engolir um elétrico.
# Sentence in BR,  chupando um bonde.
# Sentence in PT,  E estou esfomeada!
# Sentence in BR,  Também estou morrendo de fome para jantar.
# Sentence in PT,  Onde diabos te meteste?
# Sentence in BR,  Onde porra você estava?
# Sentence in PT,  Vamos?
# Sentence in BR,  Podemos ir?
# Sentence in PT,  Pede o que te apetece.
# Sentence in BR,  Peça seu favorito.
# Sentence in PT,  Touché!
# Sentence in BR,  Touché.
# Sentence in PT,  Estás a fazer isso porquê?
# Sentence in BR,  Por que faz isso?
# Sentence in PT,  Pisquei também.
# Sentence in BR,  Eu retribuo.
# Sentence in PT,  És louca!
# Sentence in BR,  Está muito louca.
# Sentence in PT,  Não fales! Estás a irritar Bella!
# Sentence in BR,  Pare de falar. Sua voz deixa Bella brava!
# Sentence in PT,  Quando preciso...
# Sentence in BR,  Tudo bem.
# Sentence in PT,  Achei que não seriam igualmente macias.
# Sentence in BR,  Me perguntei se talvez não fossem iguais em suavidade.
# Sentence in PT,  E a brincadeira com a língua que me ias fazer?
# Sentence in BR,  Não vai mais brincar de língua?
# Sentence in PT,  Sua...
# Sentence in BR,  Você...
# Sentence in PT,  Estás perturbado.
# Sentence in BR,  Está com problemas.
# Sentence in PT,  Estiveste a brincar com ele?
# Sentence in BR,  Pulou furiosamente nele?
# Sentence in PT,  Acho que fui afetado.
# Sentence in BR,  Devo ter inalado muito.
# Sentence in PT,  Temos de meter de lado os nossos sentimentos.
# Sentence in BR,  Acha que meu pai teria me marcado...
# Sentence in PT,  Ferros em brasa?
# Sentence in BR,  Sentimentos devem ser deixados de lado.
# Sentence in PT,  Anda despir-me.
# Sentence in BR,  Venha, tire minha roupa.
# Sentence in PT,  Azul, azul, azul.
# Sentence in BR,  Azul. Azul. Azul.
# Sentence in PT,  Pássaro idiota!
# Sentence in BR,  Filho da puta!
# Sentence in PT,  É verdade para ti?
# Sentence in BR,  É o mesmo com você?
# Sentence in PT,  Fiquei sem tinta.
# Sentence in BR,  Acabou a tinta.
# Sentence in PT,  Também reparei no teu.
# Sentence in BR,  Também notei seu cabelo.
# Sentence in PT,  Não.
# Sentence in BR,  Não, ele não.
# Sentence in PT,  São ótimas notícias.
# Sentence in BR,  É notícia tranquilizadora.
# Sentence in PT,  Encantador.
# Sentence in BR,  Será um prazer.
# Sentence in PT,  Escolheste-me a mim.
# Sentence in BR,  Você me escolheu em vez dele.
# Sentence in PT,  Por agora.
# Sentence in BR,  Pelo momento.
# Sentence in PT,  Ela está a evoluir.
# Sentence in BR,  Está aprendendo.
# Sentence in PT,  Felicity.
# Sentence in BR,  Boa sorte.
# Sentence in PT,  Mais devagar. Ou nem por isso.
# Sentence in BR,  Nem tão rápido.
# Sentence in PT,  É integrante.
# Sentence in BR,  Isso é básico.
# Sentence in PT,  Vamos apanhar ar
# Sentence in BR,  vamos entrar um pouco...
# Sentence in PT,  Anda. Vem comigo.
# Sentence in BR,  Venha. Venha. Só venha.
# Sentence in PT,  Estás a tapar-me o sol.
# Sentence in BR,  Está fazendo sombra.
# Sentence in PT,  Anda.
# Sentence in BR,  Venha.
# Sentence in PT,  Que excitação!
# Sentence in BR,  Excitante.
# Sentence in PT,  E isso tirou-me o sono.
# Sentence in BR,  e digo que não.
# Sentence in PT,  Eu mostro-te.
# Sentence in BR,  Vou mostrar a você.
# Sentence in PT,  Temos de os ir ajudar.
# Sentence in BR,  Precisamos ajudá-los.
# Sentence in PT,  Podemos tratar disso por si.
# Sentence in BR,  Cuidaremos disso para você.
# Sentence in PT,  Toda a gente precisa.
# Sentence in BR,  Todos eles.
# Sentence in PT,  Levei o dinheiro.
# Sentence in BR,  Eu peguei.
# Sentence in PT,  Estou mental e emocionalmente exausta, Wedderburn.
# Sentence in BR,  pisoteada, Duncan Wedderburn...
# Sentence in PT,  Com certeza.
# Sentence in BR,  Certamente, senhor.
# Sentence in PT,  Dei-o àquelas pessoas.
# Sentence in BR,  Dei para os pobres lá fora.
# Sentence in PT,  Tu...
# Sentence in BR,  Você...
# Sentence in PT,  Acabei de te dizer.
# Sentence in BR,  Já disse.
# Sentence in PT,  Ela está um trapo.
# Sentence in BR,  Está destroçada.
# Sentence in PT,  Não, eu queria magoar-te.
# Sentence in BR,  Não. Na verdade, quis chocar você.
# Sentence in PT,  A questão é essa.
# Sentence in BR,  Este é o ponto essencial.
# Sentence in PT,  A nossa espécie está acabada.
# Sentence in BR,  Somos uma espécie fodida.
# Sentence in PT,  Claro que estás.
# Sentence in BR,  É claro.
# Sentence in PT,  não seja das melhores,
# Sentence in BR,  Mesmo que seja verdade que minha habilidade...
# Sentence in PT,  Tu cobras trinta.
# Sentence in BR,  Você cobra 30 deles.
# Sentence in PT,  Ficamos todos contentes.
# Sentence in BR,  E todos ficam felizes.
# Sentence in PT,  Estou a ver.
# Sentence in BR,  Entendo.
# Sentence in PT,  Vai lá.
# Sentence in BR,  Vamos.
# Sentence in PT,  Anda lá!
# Sentence in BR,  Então, vá em frente.
# Sentence in PT,  Compreendo.
# Sentence in BR,  Entendo.
# Sentence in PT,  mas tenho alguma curiosidade.
# Sentence in BR,  este é o caminho mais curto.
# Sentence in PT,  Como te chamas?
# Sentence in BR,  Qual é seu nome?
# Sentence in PT,  Tive de conter uma risada.
# Sentence in BR,  Segurei o riso...
# Sentence in PT,  Vim a rir o caminho todo. Fui comprar estes éclairs.
# Sentence in BR,  Sorri quando peguei esses éclairs...
# Sentence in PT,  E pensei carinhosamente
# Sentence in BR,  e lembrei com tanto carinho...
# Sentence in PT,  para me esfrangalhar o espírito.
# Sentence in BR,  para rasgar minha alma em pedaços.
# Sentence in PT,  Prostituíste-te!
# Sentence in BR,  Se prostituiu.
# Sentence in PT,  Alguma vez me vais elogiar?
# Sentence in BR,  Nunca mais vou ter elogios de você?
# Sentence in PT,  Não podemos mesmo casar.
# Sentence in BR,  Definitivamente, nunca deveremos nos casar.
# Sentence in PT,  Cadela!
# Sentence in BR,  Piranha!
# Sentence in PT,  Tiveste dinheiro contigo
# Sentence in BR,  Você tinha dinheiro...
# Sentence in PT,  Foi o God que me deu.
# Sentence in BR,  É dinheiro do God.
# Sentence in PT,  Foste tu que me avariaste!
# Sentence in BR,  Você quebrou algo em mim!
# Sentence in PT,  Sinto que estamos a andar em círculos.
# Sentence in BR,  Esta conversa virou círculo vicioso.
# Sentence in PT,  Cabra!
# Sentence in BR,  Piranha!
# Sentence in PT,  Anda.
# Sentence in BR,  Venha.
# Sentence in PT,  Uma iguaria.
# Sentence in BR,  Um filé mignon.
# Sentence in PT,  Diz "formidable" no fim.
# Sentence in BR,  Diga "formidável" no final.
# Sentence in PT,  Mudar o mundo.
# Sentence in BR,  Une personne qui veut... change the world pour le meilleur.
# Sentence in PT,  Madame Swiney!
# Sentence in BR,  Senhora Swiney...
# Sentence in PT,  Meu Deus! És linda!
# Sentence in BR,  Deus, como está bonita.
# Sentence in PT,  O trabalho assenta-te que nem uma luva.
# Sentence in BR,  quando pulasse nelas.
# Sentence in PT,  Não preferia fazê-lo por escolha da mulher,
# Sentence in BR,  Não prefere que as mulheres escolham?
# Sentence in PT,  pois seria sinal de entusiasmo em relação à sua pessoa?
# Sentence in BR,  Mostrando algum entusiasmo a você?
# Sentence in PT,  Toinette, és muito impertinente.
# Sentence in BR,  Toinette, é inteligente ao abrir a boca.
# Sentence in PT,  Tenho...
# Sentence in BR,  Eu preciso...
# Sentence in PT,  Desculpa. Fiz sangue.
# Sentence in BR,  Oh, sinto. Tirei sangue.
# Sentence in PT,  Toma.
# Sentence in BR,  Pegue.
# Sentence in PT,  És encantadora.
# Sentence in BR,  E tão graciosa.
# Sentence in PT,  Não queres? És encantadora!
# Sentence in BR,  não só o que é bom.
# Sentence in PT,  Um jogo?
# Sentence in BR,  Um teste?
# Sentence in PT,  Truz, truz!
# Sentence in BR,  Um abraço e um "queijo".
# Sentence in PT,  É uma meia que cheira a chulé.
# Sentence in BR,  Depois uma rápida cheirada...
# Sentence in PT,  Já conhecias?
# Sentence in BR,  Você sabia esta.
# Sentence in PT,  Cheiras bem.
# Sentence in BR,  Seu cheiro não é ruim.
# Sentence in PT,  Queres fazer o quê?
# Sentence in BR,  Deseja o que?
# Sentence in PT,  Compreendo.
# Sentence in BR,  Entendo.
# Sentence in PT,  Ou um pouco de estrangulamento.
# Sentence in BR,  Ou leve asfixia pode servir.
# Sentence in PT,  Eu sabia!
# Sentence in BR,  Fez sim. Eu sei!
# Sentence in PT,  São duas rameiras!
# Sentence in BR,  Vocês são putas.
# Sentence in PT,  Somos mulheres independentes.
# Sentence in BR,  Temos nosso próprio meio de sobrevivência.
# Sentence in PT,  Tem calma.
# Sentence in BR,  E me feche.
# Sentence in PT,  Podes suturar.
# Sentence in BR,  Quieto agora.
# Sentence in PT,  Tens de persistir.
# Sentence in BR,  Você deve superar isso...
# Sentence in PT,  Estou a ver.
# Sentence in BR,  Entendo.
# Sentence in PT,  E isso também.
# Sentence in BR,  É isso.
# Sentence in PT,  Ela deixou-me vazio por dentro!
# Sentence in BR,  Ela esvaziou.
# Sentence in PT,  Cantemos?
# Sentence in BR,  Vamos cantar?
# Sentence in PT,  Não era minha intenção.
# Sentence in BR,  Não quero que seja assim.
# Sentence in PT,  Mas fui forçado.
# Sentence in BR,  Você me força a isso.
# Sentence in PT,  Vou perguntar-lhe educadamente.
# Sentence in BR,  Peço da forma mais educada que posso.
# Sentence in PT,  Estou a ver.
# Sentence in BR,  Entendo.
# Sentence in PT,  E foste cobarde.
# Sentence in BR,  Foram muito covardes nisso.
# Sentence in PT,  Lamento.
# Sentence in BR,  me desculpando.
# Sentence in PT,  Bell rameira.
# Sentence in BR,  Bell puta
# Sentence in PT,  - Mas gosto desta. - Bell rameira.
# Sentence in BR,  - Cai muito bem. - Bell puta.
# Sentence in PT,  Bell rameira.
# Sentence in BR,  Bell puta
# Sentence in PT,  Bell rameira.
# Sentence in BR,  Bell puta
# Sentence in PT,  É sem dúvida um dilema.
# Sentence in BR,  Um enigma, com certeza.
# Sentence in PT,  Tiveste.
# Sentence in BR,  Tinha.
# Sentence in PT,  Vou ser médica.
# Sentence in BR,  Sabia o que vem a seguir.
# Sentence in PT,  Não te sintas obrigada.
# Sentence in BR,  Não temos compromisso.
# Sentence in PT,  Fui uma rameira, percebes?
# Sentence in BR,  Sou uma puta, entende?
# Sentence in PT,  Vais aceitar isso?
# Sentence in BR,  Tudo bem com isso?
# Sentence in PT,  És livre de te entregares a quem quiseres.
# Sentence in BR,  Seu, para usar livremente.
# Sentence in PT,  Acho.
# Sentence in BR,  Acredito.
# Sentence in PT,  Caso.
# Sentence in BR,  Sim.
# Sentence in PT,  Mas, no geral, é agradável.
# Sentence in BR,  desde que a use de forma agradável.
# Sentence in PT,  E já foste examinada?
# Sentence in BR,  Foi examinada para detectar doenças?
# Sentence in PT,  Estás a andar!
# Sentence in BR,  God, está caminhando!
# Sentence in PT,  Quando soube que tinhas desaparecido, fiquei desfeito.
# Sentence in BR,  Ao descobrir sua ausência, me senti estripado.
# Sentence in PT,  És mesmo tu.
# Sentence in BR,  Aqui está.
# Sentence in PT,  Isso dói.
# Sentence in BR,  É doloroso.
# Sentence in PT,  Bella, desculpa.
# Sentence in BR,  Bella, sinto muito.
# Sentence in PT,  Temo uma rebelião.
# Sentence in BR,  Vamos, então.
# Sentence in PT,  Conheces-me?
# Sentence in BR,  Você me conhece?
# Sentence in PT,  Eu era simpática?
# Sentence in BR,  Era gentil?
# Sentence in PT,  Os teus preferidos.
# Sentence in BR,  Tudo que aprecia.
# Sentence in PT,  Detestaste o bebé.
# Sentence in BR,  Odiava o bebê.
# Sentence in PT,  Estou a ver.
# Sentence in BR,  Entendo.
# Sentence in PT,  Partilhávamos o amor pela diversão.
# Sentence in BR,  Nos agradava apreciar bons momentos.
# Sentence in PT,  Observa.
# Sentence in BR,  Veja.
# Sentence in PT,  É mais avinagrado.
# Sentence in BR,  Avinagrado ou algo parecido.
# Sentence in PT,  Quando penso nas formas como foste incorreta comigo...
# Sentence in BR,  Se eu enumerasse todas as formas em que me agrediu...
# Sentence in PT,  Na nuca.
# Sentence in BR,  e eu não estava sendo precipitado.
# Sentence in PT,  Tive saudades tuas.
# Sentence in BR,  Senti sua falta.
# Sentence in PT,  Parece-te que já terminei?
# Sentence in BR,  não acha que só sobraram os ossos deste faisão?
# Sentence in PT,  Sai facilmente?
# Sentence in BR,  Sai fácil?
# Sentence in PT,  Timing perfeito.
# Sentence in BR,  Bem a tempo.
# Sentence in PT,  Que ideia adorável.
# Sentence in BR,  Ótima ideia.
# Sentence in PT,  Resume-se a isso.
# Sentence in BR,  vou tirar isso...
# Sentence in PT,  Bebe, meu amor.
# Sentence in BR,  Beba, querida.
# Sentence in PT,  Bolas!
# Sentence in BR,  Porra.
# Sentence in PT,  Está a sangrar imenso.
# Sentence in BR,  Sangrando muito.
# Sentence in PT,  Voltaste.
# Sentence in BR,  Você voltou.
# Sentence in PT,  Um gin, minhas senhoras?
# Sentence in BR,  Senhoras, gim?
# Sentence in PT,  Felicity...
# Sentence in BR,  Saúde...
# Sentence in PT,  - Oh, tio... - Shh... shh!
# Sentence in BR,  - Tio... - Cala a boca!
# Sentence in PT,  - Alé. Tie cà. Tie cá.
# Sentence in BR,  Ali. Pegue a espingarda.
# Sentence in PT,  - Tio...
# Sentence in BR,  Prontinho...
# Sentence in PT,  Sentiu-o?
# Sentence in BR,  Ouviram isso?
# Sentence in PT,  -Lentamente, tens de estar calado.
# Sentence in BR,  - Tio... - Calado. Fique quieto.
# Sentence in PT,  Ele acordou.
# Sentence in BR,  Ela se escondeu.
# Sentence in PT,  - Tio... - Shh... cala-te.
# Sentence in BR,  - Tio... - Calado.
# Sentence in PT,  Descer.
# Sentence in BR,  Sai de perto.
# Sentence in PT,  - La piggiassi, tio
# Sentence in BR,  Você acertou, tio.
# Sentence in PT,  - É tudo o que tenho a dizer, não é?
# Sentence in BR,  Acertou mesmo. Você a pegou.
# Sentence in PT,  - Totò. Agora não te vás embora, vá lá.
# Sentence in BR,  - Totó, não tenha medo, vai. - Não, eu tenho medo.
# Sentence in PT,  - Me scanto, me scanto... - Maria... a nossa coisa.
# Sentence in BR,  Nossa senhora!
# Sentence in PT,  Annami, annami, vá lá.
# Sentence in BR,  Vamos embora.
# Sentence in PT,  A cùrri da Pino, Totò
# Sentence in BR,  Corra chamar o Pino, Totó.
# Sentence in PT,  - Pino [Pino.... Pino...].
# Sentence in BR,  Ele tem medo...
# Sentence in PT,  Pinho [Pinho]
# Sentence in BR,  Pino!
# Sentence in PT,  Pinho [Pinho]
# Sentence in BR,  Pino!
# Sentence in PT,  Pinho [Pino... Pino... Pino... Pino...]
# Sentence in BR,  Pino!
# Sentence in PT,  Mas desliguem este rádio.
# Sentence in BR,  Desligue esse rádio.
# Sentence in PT,  E vattinni!
# Sentence in BR,  Suma daqui!
# Sentence in PT,  [a sua capacidade de deslumbramento
# Sentence in BR,  Ele é muito habilidoso.
# Sentence in PT,  - Oh vai... puxa! Puxa!
# Sentence in BR,  Vai... chuta! Chuta! Vá se foder!
# Sentence in PT,  - Giannuzza
# Sentence in BR,  Giannizinha.
# Sentence in PT,  - Giannuzzo
# Sentence in BR,  Giannizinho.
# Sentence in PT,  - Giannuzzo
# Sentence in BR,  Giannizinho.
# Sentence in PT,  - Está a ficar surdo?
# Sentence in BR,  Você ficou surdo?
# Sentence in PT,  - Giannuzza
# Sentence in BR,  Giannizinha.
# Sentence in PT,  - Giannuzzo
# Sentence in BR,  Giannizinho.
# Sentence in PT,  [E lá vem o pequeno Rossi.
# Sentence in BR,  Venha!
# Sentence in PT,  Magath recuperado]
# Sentence in BR,  E aí vem Rossi. Magath recupera.
# Sentence in PT,  Véni a cà.
# Sentence in BR,  Venha aqui.
# Sentence in PT,  Oh, não o consegues ouvir a falar contigo.
# Sentence in BR,  Não viu que ele está falando com você?
# Sentence in PT,  Giannuzzo
# Sentence in BR,  Giannizinho.
# Sentence in PT,  - Vá lá, algo deste género...
# Sentence in BR,  É só um cafezinho...
# Sentence in PT,  Vèni chi ti pigli 'n caffè cu l'amici
# Sentence in BR,  Venha tomar um café com seus amigos
# Sentence in PT,  [o fecho deste 0-0 reconhecidamente lisonjeiro e esta noite a terceira fase]...
# Sentence in BR,  Entre.
# Sentence in PT,  - Uh, e andar ah...
# Sentence in BR,  Continue andando.
# Sentence in PT,  Gostas, não gostas?
# Sentence in BR,  Você gosta disso, não é?
# Sentence in PT,  E se gostares, não o estragues.
# Sentence in BR,  Diga que você gosta, não seja tímido.
# Sentence in PT,  - Sim, que gostas
# Sentence in BR,  Claro que você gosta.
# Sentence in PT,  Então, beddu
# Sentence in BR,  Isso mesmo. Que lindinho!
# Sentence in PT,  Olha para aquele beddu.
# Sentence in BR,  Veja só que bonito.
# Sentence in PT,  - Vá lá, nunca vieste dançar "cum mia", pois não?
# Sentence in BR,  Quer dançar comigo essa noite?
# Sentence in PT,  - Idda é, che bedda.
# Sentence in BR,  Veja só que lindo!
# Sentence in PT,  Bedda, Giannuzza bedda.
# Sentence in BR,  Tão lindinha a Giannizinha.
# Sentence in PT,  - Minchia, é mesmo Bedda Giannuzza.
# Sentence in BR,  Giannizinha ficou bonita mesmo.
# Sentence in PT,  - Proprio bedda.
# Sentence in BR,  Ficou linda.
# Sentence in PT,  - Está a fazer uma careta - Merda!
# Sentence in BR,  - Não faça essa carinha. - Porra!
# Sentence in PT,  - Aproxima-te, aproxima-te - Vèni ca
# Sentence in BR,  Venha mais perto. Aproxime-se.
# Sentence in PT,  - Pronto... já está.
# Sentence in BR,  Isso... Prontinho.
# Sentence in PT,  E então?
# Sentence in BR,  Posso saber?
# Sentence in PT,  Qual é o seu aspeto?
# Sentence in BR,  Deixem o garoto em paz.
# Sentence in PT,  - Se me disseres, só posso obedecer.
# Sentence in BR,  Se você manda, eu obedeço.
# Sentence in PT,  - Vai, vai, amunni
# Sentence in BR,  Vamos dar o fora.
# Sentence in PT,  - Avô
# Sentence in BR,  Vovô!
# Sentence in PT,  Olá, avô - Totò, mantém a calma.
# Sentence in BR,  - Oi, vô. -Totó, cuidado.
# Sentence in PT,  Um momento. - Olá, avô.
# Sentence in BR,  - Espere um pouco. - Oi, vô.
# Sentence in PT,  - Olá, pai
# Sentence in BR,  Oi, pai.
# Sentence in PT,  - Alfredo  Oh Petru.
# Sentence in BR,  - Alfredo. - Oi, Pietro.
# Sentence in PT,  Como é que correu para ti? - Foi... bom.
# Sentence in BR,  - Deu tudo certo? - Sim.
# Sentence in PT,  - Esperemos que alguns---------------
# Sentence in BR,  - Espero que poucos. - Está tudo em ordem.
# Sentence in PT,  - Não é preciso, disse.
# Sentence in BR,  Não precisa, já te falei. Eu cuidarei disso.
# Sentence in PT,  - Unni agghiri tu?
# Sentence in BR,  Justo você que abaixa a cabeça para todo mundo?
# Sentence in PT,  - Peter, pára.
# Sentence in BR,  Pietro, pare. Os meninos vão ouvir.
# Sentence in PT,  - Bem, é só pegar
# Sentence in BR,  Bem, pegue para você.
# Sentence in PT,  Foste promovido e mereceste-o.
# Sentence in BR,  Você passou de ano e mereceu.
# Sentence in PT,  - Até breve - Até breve - Adeus.
# Sentence in BR,  - Tchau. Até logo. - Tchau.
# Sentence in PT,  - O que é que estão a dizer, isso é uma treta
# Sentence in BR,  Não se preocupe com essa besteira.
# Sentence in PT,  E há cordel de sol, cordamina, elásticos, o que...
# Sentence in BR,  Tem barbante, pavio, elástico...
# Sentence in PT,  - Quem é que era meu para levar?
# Sentence in BR,  E eu devo fazer isso?
# Sentence in PT,  ----ca sparu fires.....
# Sentence in BR,  Eu solto fogos de artifício não faço as compras.
# Sentence in PT,  - Ah boh, deixo-te ca.
# Sentence in BR,  Certo, mas vou deixar aqui.
# Sentence in PT,  - Totò, como é que é?
# Sentence in BR,  Totó, como está aí?
# Sentence in PT,  - Espera um minuto, Giannì
# Sentence in BR,  Espere um pouco, Gianni.
# Sentence in PT,  Giannì, oh!
# Sentence in BR,  Gianni!
# Sentence in PT,  Estou metido nisto, sabes.
# Sentence in BR,  Sinto muito.
# Sentence in PT,  - Tem noção do que está a dizer?
# Sentence in BR,  - Eu sou assim, você sabe. - Você consegue se ouvir?
# Sentence in PT,  - Eu não te queria dizer, Gianni
# Sentence in BR,  Isso, muito bem. Fique em silêncio.
# Sentence in PT,  - Disseste-lhe o que te divertia.
# Sentence in BR,  Você contou só para diverti-los.
# Sentence in PT,  Espera, espera, espera.
# Sentence in BR,  Espere, espere, espere.
# Sentence in PT,  Espera!
# Sentence in BR,  Espere!
# Sentence in PT,  - E o que é metade?
# Sentence in BR,  Ele não dá a mínima.
# Sentence in PT,  O Chiddu está-se nas tintas.
# Sentence in BR,  Só tem medo de ser alvo de fofocas.
# Sentence in PT,  Percebem?
# Sentence in BR,  Está entendendo?
# Sentence in PT,  Não falas.
# Sentence in BR,  Não vai falar nada.
# Sentence in PT,  - Olá tio
# Sentence in BR,  Oi, tio.
# Sentence in PT,  - Adeusinho. - Avô.
# Sentence in BR,  - Oi. - Vó!
# Sentence in PT,  - Tio Pietru piggiau u cunigghiu
# Sentence in BR,  - Tio Pietro pegou uma lebre. - Uma lebre?
# Sentence in PT,  A mamã cozinha bonu u cunigghiu
# Sentence in BR,  Lebre é gostosa. Eu sei cozinhar lebre.
# Sentence in PT,  - Alè usando uma tonsura
# Sentence in BR,  Por que não raspa esse cabelo?
# Sentence in PT,  - Ciccio, está calado, há um pequenino.
# Sentence in BR,  Fique quieto, o moleque vai ouvir.
# Sentence in PT,  - Sim, sim...
# Sentence in BR,  - Sim, sim... - Nino, venha aqui.
# Sentence in PT,  - Tia, tio.
# Sentence in BR,  Pode falar, tio.
# Sentence in PT,  - Não vos estou a dizer. - Vamos lá!
# Sentence in BR,  - Não vou te contar. - Por favor!
# Sentence in PT,  - Vai-te lixar, disse ele.
# Sentence in BR,  Vai perder o apetite assim.
# Sentence in PT,  - Tem u cunigghiu
# Sentence in BR,  - Veja só. - Uma lebre.
# Sentence in PT,  Colocar dá.
# Sentence in BR,  Coloque ali.
# Sentence in PT,  - Ninuzzo, vèni ca, a mamma.
# Sentence in BR,  - Não vamos almoçar? - Nino, vem cá.
# Sentence in PT,  - Olá, mãe
# Sentence in BR,  Oi, mãe.
# Sentence in PT,  Isabela! - O quê?
# Sentence in BR,  - Isabella! - O que foi?
# Sentence in PT,  - Totò, pára.
# Sentence in BR,  Totó, pare.
# Sentence in PT,  - Uma desgraça és tu
# Sentence in BR,  - Você é um desastre. - Você que é.
# Sentence in PT,  Totò, vèni ca.
# Sentence in BR,  Totó, vem cá.
# Sentence in PT,  - Mas é verdade? - Claro que sim.
# Sentence in BR,  - Está falando sério? - Claro.
# Sentence in PT,  -Comer, comer.
# Sentence in BR,  Coma, coma.
# Sentence in PT,  - Na minha opinião, o que ele ouve é que conta. - Eu sou um idiota.
# Sentence in BR,  - Você fala demais. - Seu burro.
# Sentence in PT,  - U sappìa
# Sentence in BR,  Eu sabia.
# Sentence in PT,  - E então? Então, gostaste?
# Sentence in BR,  Você gostou?
# Sentence in PT,  - Obrigado, mamã.
# Sentence in BR,  - Você mereceu. - Obrigado, mãe.
# Sentence in PT,  - O que é, gostas? É o que querias?
# Sentence in BR,  E então, gostou? É como você queria?
# Sentence in PT,  Alfredo, levou-me a catare novo.
# Sentence in BR,  Alfredo, deveria ter comprado uma nova,
# Sentence in PT,  tendo em conta o que a guerra fez...
# Sentence in BR,  essa aí é da época da guerra.
# Sentence in PT,  - Tio...!
# Sentence in BR,  Tio!
# Sentence in PT,  é lindo.
# Sentence in BR,  Caramba, ela é linda.
# Sentence in PT,  - Avó, tu dizes... - Totò. Ei, espera!
# Sentence in BR,  - Vó, fale para ele... - Totó, espere!
# Sentence in PT,  - Tirar o Totò - Não, não
# Sentence in BR,  - Saia daí, Totó - Não vou.
# Sentence in PT,  - ... deixa-me experimentar, mas prometeste-me de....
# Sentence in BR,  Eu quero andar. Você me prometeu.
# Sentence in PT,  Só eu é que posso ficar contigo
# Sentence in BR,  O que foi?
# Sentence in PT,  Considere que já lá estamos, Senhor Deputado Sciacca.
# Sentence in BR,  Logo estaremos aí, Sr. Sciacca.
# Sentence in PT,  U motorino de lo figliu di Sciacca.
# Sentence in BR,  A moto do filho do Sciacca,
# Sentence in PT,  -Mas o chiddu mantém-se afastado.
# Sentence in BR,  Mas a casa deles é longe.
# Sentence in PT,  Como é que volto para lá?
# Sentence in BR,  Como voltarei depois?
# Sentence in PT,  - Está a dar um bom passeio.
# Sentence in BR,  Você dará uma boa caminhada.
# Sentence in PT,  - Mas porque não?
# Sentence in BR,  Por que não?
# Sentence in PT,  O que é que se passa contigo?
# Sentence in BR,  Esqueça aqueles caras, são uns vagabundos.
# Sentence in PT,  Lassali olha fixamente para chiddi, sunnu pappi.
# Sentence in BR,  - Qual o problema? - Nenhum.
# Sentence in PT,  Não tens de te preocupar,
# Sentence in BR,  Não se preocupe,
# Sentence in PT,  - Mas porquê?
# Sentence in BR,  Mas por que não?
# Sentence in PT,  - Calma. - Vai lá.
# Sentence in BR,  - Relaxe. - Pare com isso.
# Sentence in PT,  - Véni ca.
# Sentence in BR,  Vem cá.
# Sentence in PT,  Agora tu... mata-te!
# Sentence in BR,  Suba na moto.
# Sentence in PT,  Manué!
# Sentence in BR,  Emanuele!
# Sentence in PT,  Manué! - Oh?
# Sentence in BR,  - Emanuele! - Oi?
# Sentence in PT,  - Paragens
# Sentence in BR,  Pare aí.
# Sentence in PT,  - Ei, encosta
# Sentence in BR,  Venha aqui.
# Sentence in PT,  - Aproximar-se de si
# Sentence in BR,  Pare a moto.
# Sentence in PT,  - Parar! - Travão
# Sentence in BR,  - Chega! - Freie!
# Sentence in PT,  - Vamos lá, vamos lá, vamos lá
# Sentence in BR,  Vamos embora. Vamos, vamos.
# Sentence in PT,  Respirar
# Sentence in BR,  Respire.
# Sentence in PT,  Respirar
# Sentence in BR,  Respire.
# Sentence in PT,  Vá lá, respira.
# Sentence in BR,  Vamos lá, respire.
# Sentence in PT,  Respira... oh...
# Sentence in BR,  Respire...
# Sentence in PT,  Lançamos fogo de artifício, toda a gente nos conhece.
# Sentence in BR,  Trabalhamos com rojões e todos nos conhecem.
# Sentence in PT,  Tiè ca.
# Sentence in BR,  Pegue.
# Sentence in PT,  É melhor assim?
# Sentence in BR,  Melhorou?
# Sentence in PT,  - O que é que fizeste a ti próprio?
# Sentence in BR,  - Onde você estava? - Sofri um acidente.
# Sentence in PT,  - Mas o que é que ele fez? Nada foi feito.
# Sentence in BR,  Pode ir.
# Sentence in PT,  - A gasolina está lá? - Sim, há.
# Sentence in BR,  - Tem gasolina? - Tem.
# Sentence in PT,  E... onde é que se pode colocar?
# Sentence in BR,  Prontinho.
# Sentence in PT,  - Adeusinho. - Adeus.
# Sentence in BR,  - Estou indo. Tchau. - Tchau.
# Sentence in PT,  Parabéns a ti ♫
# Sentence in BR,  Parabéns para você
# Sentence in PT,  Parabéns a ti ♫
# Sentence in BR,  Nesta data querida
# Sentence in PT,  Parabéns a ti ♫
# Sentence in BR,  Muitos anos de vida
# Sentence in PT,  Olá? - Sim
# Sentence in BR,  - Pronto? - Pronto.
# Sentence in PT,  - Vai ver o segundo, va.
# Sentence in BR,  Fique sossegado.
# Sentence in PT,  Outra vez, hã? - Sim, ainda. - Ainda.
# Sentence in BR,  - De novo, certo? - Sim.
# Sentence in PT,  - Vèni ca.
# Sentence in BR,  Vem cá.
# Sentence in PT,  Não se preocupem.
# Sentence in BR,  Arrume tudo.
# Sentence in PT,  Muito bom.
# Sentence in BR,  Excelente.
# Sentence in PT,  Continua.
# Sentence in BR,  Continue!
# Sentence in PT,  Pai...!
# Sentence in BR,  Pai!
# Sentence in PT,  Onde é que o pus?
# Sentence in BR,  Onde eu coloquei?
# Sentence in PT,  Nino, adduma!
# Sentence in BR,  Nino, vamos lá!
# Sentence in PT,  - Pai!
# Sentence in BR,  Pai!
# Sentence in PT,  - Na carrinha. Procurem-no.
# Sentence in BR,  No carro. Vá procurar.
# Sentence in PT,  - Respira, vá lá.
# Sentence in BR,  Respire, vamos lá.
# Sentence in PT,  - Veja como está a reagir
# Sentence in BR,  Cuidado com o que fala.
# Sentence in PT,  - A maratona desta noite é boa de qualquer maneira
# Sentence in BR,  Gata, vou te dizer o que fazer.
# Sentence in PT,  Eu mostro-vos como ele celebra.
# Sentence in BR,  Vou te mostrar como comemorar.
# Sentence in PT,  - O que é que estás a fazer, meu? A divertir-me?
# Sentence in BR,  E aí, gatinho? Quer se divertir?
# Sentence in PT,  - Esqueçam-no.
# Sentence in BR,  Deixa o menino.
# Sentence in PT,  - O que tem andado a fazer?
# Sentence in BR,  Você quer me matar?
# Sentence in PT,  Sê tão bom como és.
# Sentence in BR,  Bem. Estou bem, como deveria estar?
# Sentence in PT,  Compreendemo-nos uns aos outros?
# Sentence in BR,  Estamos entendidos?
# Sentence in PT,  - Vai para o trabalho, vai!
# Sentence in BR,  - Estamos. - Volte ao trabalho.
# Sentence in PT,  - E o que é que tu queres?
# Sentence in BR,  Quem é esse?
# Sentence in PT,  - Espera ca, va.
# Sentence in BR,  Espere aqui.
# Sentence in PT,  - Há alguém à tua procura.
# Sentence in BR,  - Tem alguém te procurando. - Nino, veja quem é, por favor.
# Sentence in PT,  Foi na manhã de Sumana que te telefonei
# Sentence in BR,  Finalmente! Liguei para você a manhã toda.
# Sentence in PT,  - Olá - Olá
# Sentence in BR,  - Oi - Oi.
# Sentence in PT,  O ciclomotor está ótimo.
# Sentence in BR,  A moto está ótima.
# Sentence in PT,  - Mas está à procura de trabalho?
# Sentence in BR,  - Você está procurando emprego? - Certo. Tchauzinho.
# Sentence in PT,  - Já agora, bela camisa. Gosto dela.
# Sentence in BR,  Aliás, a camisa é linda. Gostei. Venha, entre.
# Sentence in PT,  Sabes que estavas errado.
# Sentence in BR,  Ele sabe que errou.
# Sentence in PT,  - Pede-nos desculpa agora. - Vamos, papá.
# Sentence in BR,  - Peça desculpas. - Por favor, pai.
# Sentence in PT,  Bravo. Accussì.
# Sentence in BR,  Bom garoto. É assim que se faz.
# Sentence in PT,  - Eu disse-te Totò, tens razão.
# Sentence in BR,  Você tem toda razão, Totó.
# Sentence in PT,  mas eu com o estômago vazio,
# Sentence in BR,  não consigo nem falar de mulheres,
# Sentence in PT,  Se eu ainda tiver de comer, nem as fêmeas podem falar quanto mais trabalhar.
# Sentence in BR,  muito menos de trabalho. Vamos lá, rapazes.
# Sentence in PT,  - Então, as mães sempre se deitaram
# Sentence in BR,  Sua mãe sempre foi bonita.
# Sentence in PT,  - Uma vez, gostei imediatamente
# Sentence in BR,  Eu gostei dela assim que a vi.
# Sentence in PT,  Chidda, levei-a para casa na última noite.
# Sentence in BR,  Ainda não estávamos noivos
# Sentence in PT,  - Carmela
# Sentence in BR,  Carmela,
# Sentence in PT,  - Carmela, estavas de cama,
# Sentence in BR,  Carmela, você era linda,
# Sentence in PT,  bem, elegante... talvez agora.
# Sentence in BR,  fina, elegante... e continua sendo.
# Sentence in PT,  - Cigarro - Hmmm...
# Sentence in BR,  Apague o cigarro.
# Sentence in PT,  U cunigghiu cu i mani si mancia
# Sentence in BR,  Lebre se come com a mão.
# Sentence in PT,  que lhe acontece.
# Sentence in BR,  aparece para ele.
# Sentence in PT,  Percebem?
# Sentence in BR,  Entenderam?
# Sentence in PT,  Bravo Gianni.
# Sentence in BR,  Parabéns, Gianni. Você é um bom rapaz.
# Sentence in PT,  Escuta-me.
# Sentence in BR,  Preste atenção,
# Sentence in PT,  - Ah, esqueci-me da salada, ca la secunda.
# Sentence in BR,  e da família que tem, certo?
# Sentence in PT,  Não sei...
# Sentence in BR,  Não falo nada...
# Sentence in PT,  - Está bem. Muito bem, sim.
# Sentence in BR,  Tudo bem. Pode ser.
# Sentence in PT,  - Já alguma vez partiste pedras?
# Sentence in BR,  e você vem falar de cebola?
# Sentence in PT,  - Se Deus quiser, eles dão-lhe este quinto ano também vais a casa do tio Petru.
# Sentence in BR,  poderá trabalhar com o tio Pietro.
# Sentence in PT,  Sim, é difícil!
# Sentence in BR,  Só está um pouco dura.
# Sentence in PT,  - Eh... - Sim, sim.
# Sentence in BR,  - Isso. - Sim, vou sim.
# Sentence in PT,  - Ah, eu não sabia disso. Experimenta agora.
# Sentence in BR,  Tente agora.
# Sentence in PT,  Voltem sempre que quiserem, sim?
# Sentence in BR,  Tchau, Gianni. Volte quando quiser.
# Sentence in PT,  - Adeus - Adeus
# Sentence in BR,  - Tchau. - Tchau.
# Sentence in PT,  - Apanhar cigarros
# Sentence in BR,  Totó, compre cigarros para mim.
# Sentence in PT,  - Vai, vai, vai!
# Sentence in BR,  Vai, vai!
# Sentence in PT,  Vai, vai, vai até ao fim!
# Sentence in BR,  Vai, vai, mais um!
# Sentence in PT,  - O que é que se passa?
# Sentence in BR,  Vejam só quem está vindo!
# Sentence in PT,  - Vamos lá, véni ca!
# Sentence in BR,  Enzo, vem cá, vem!
# Sentence in PT,  - Véni ca! - Vamos lá...
# Sentence in BR,  Pare aqui.
# Sentence in PT,  - Uh, uh, talia cu cc é.
# Sentence in BR,  Vejam só quem chegou.
# Sentence in PT,  - Hoje queres magoar.
# Sentence in BR,  Hoje ele está a fim de apanhar.
# Sentence in PT,  - Franco - Mica viu-o...
# Sentence in BR,  Você não falou isso.
# Sentence in PT,  Franco, u ficcardiu
# Sentence in BR,  Franco, o comedor.
# Sentence in PT,  - Francooooo
# Sentence in BR,  Franco...
# Sentence in PT,  - Mãe
# Sentence in BR,  Mãe.
# Sentence in PT,  - És completamente louco
# Sentence in BR,  Você enlouqueceu de vez.
# Sentence in PT,  Lembras-te de como éramos?
# Sentence in BR,  Lembra como você e eu estávamos antes?
# Sentence in PT,  Vamos para outro sítio, tu e eu. - De que é que estão a falar?
# Sentence in BR,  - Nós dois sairemos daqui. - O que está dizendo?
# Sentence in PT,  - Unni jè? Véni ca.
# Sentence in BR,  Você não vai mais pôr os pés na minha oficina.
# Sentence in PT,  - Deixem-no em paz - Tens de o deixar
# Sentence in BR,  - Vá embora agora. - Pode deixar.
# Sentence in PT,  - Claro que sim - Se não, farei com que te arrependas do dia em que nasceste.
# Sentence in BR,  Ou vai se arrepender de ter nascido.
# Sentence in PT,  - Vattinni, va
# Sentence in BR,  Vai logo.
# Sentence in PT,  - A equipa não está em risco. - Vamos lá.
# Sentence in BR,  Pasquale, não é arriscado.
# Sentence in PT,  - Antoninus... - Sim
# Sentence in BR,  - Antonino, você aqui? - Pois é.
# Sentence in PT,  - Vamos pegar nesta escavadora e começar. - Tudo bem
# Sentence in BR,  - Pegue a escavadeira e comece. - Certo.
# Sentence in PT,  - Doutor, sugnu patri di famiglia.
# Sentence in BR,  Muito obrigado.
# Sentence in PT,  - Vai, eu peço-te uma treva e começamos antes de eu reconsiderar. - Obrigado, Doutor.
# Sentence in BR,  Melhor começar logo antes que você desista.
# Sentence in PT,  - Alfré, como estás?
# Sentence in BR,  - Alfredo, como você está? - Bem, estou aqui.
# Sentence in PT,  - Não, não, não importa - Não, não, não importa.
# Sentence in BR,  - Não, deixe isso pra lá. - Não vou deixar nada pra lá.
# Sentence in PT,  - Mas porquê fazer isto? - Alfré!
# Sentence in BR,  - Por que vai fazer isso? - Alfredo!
# Sentence in PT,  Gianni, o que é que fazemos? Começamos? - Sim.
# Sentence in BR,  - Gianni, vamos começar? - Vamos.
# Sentence in PT,  Ver esses ramos
# Sentence in BR,  Veja aqueles galhos.
# Sentence in PT,  - Vai! Vai!
# Sentence in BR,  Desça! Desça!
# Sentence in PT,  Tenho uma família, como é que vou comer?
# Sentence in BR,  Estou falando com você.
# Sentence in PT,  - Gianni... vem cá.
# Sentence in BR,  Gianni, venha aqui.
# Sentence in PT,  Está muito empenhado.
# Sentence in BR,  Você trabalha muito duro.
# Sentence in PT,  - Obrigado.
# Sentence in BR,  Obrigado.
# Sentence in PT,  - Adeus - Adeus.
# Sentence in BR,  - Tchau. - Tchau.
# Sentence in PT,  Vai.
# Sentence in BR,  Vai.
# Sentence in PT,  minchia, tall explode.
# Sentence in BR,  alto pra caralho, ela explode.
# Sentence in PT,  - A va bene, não importa.
# Sentence in BR,  Certo, deixa pra lá.
# Sentence in PT,  Deixem-me mostrar-vos.
# Sentence in BR,  Preste atenção no que vou te mostrar.
# Sentence in PT,  Alarme!
# Sentence in BR,  "Olha o rojão!"
# Sentence in PT,  - Mas beijaste-me da última vez?
# Sentence in BR,  Você me beijou aquele dia?
# Sentence in PT,  Ao acidente.
# Sentence in BR,  No dia do acidente.
# Sentence in PT,  - Do que estás a falar, beijada? Já não estavas a respirar.
# Sentence in BR,  De onde tirou isso? Você não estava respirando.
# Sentence in PT,  Não, em.....
# Sentence in BR,  Não, acha que vou me lavar aqui?
# Sentence in PT,  - Vamos lá.
# Sentence in BR,  Venha!
# Sentence in PT,  - Nino
# Sentence in BR,  Nino!
# Sentence in PT,  Nino.
# Sentence in BR,  Nino!
# Sentence in PT,  - Minchia! Mi scantari-------------
# Sentence in BR,  Cacete! Você me assustou.
# Sentence in PT,  - Rápido.
# Sentence in BR,  - Mais rápido. - Um segundo.
# Sentence in PT,  - Espera um minuto, espera um minuto. - Issa lassalu ca. Ciao
# Sentence in BR,  - Espere um pouco. - Vou te deixar aqui. Tchau.
# Sentence in PT,  - Babbu, caíste na armadilha
# Sentence in BR,  Seu bobo, você caiu direitinho.
# Sentence in PT,  - Mas trabalhaste ca? - Sim
# Sentence in BR,  - Era aqui que você trabalhava? - Era.
# Sentence in PT,  - Olá - Oh...
# Sentence in BR,  - Oi. - Oi.
# Sentence in PT,  - Obrigado
# Sentence in BR,  Obrigada.
# Sentence in PT,  Entra, vamos. - Sim.
# Sentence in BR,  - Suba logo. - Sim.
# Sentence in PT,  - Muito bem, eu vou-me embora
# Sentence in BR,  Certo, tenho que ir.
# Sentence in PT,  - Ultrapassa isso, vai. Até amanhã.
# Sentence in BR,  Imagina. Nos vemos amanhã.
# Sentence in PT,  - Vamos lá, adeus. - Adeus.
# Sentence in BR,  - Combinado. Tchau. - Tchau.
# Sentence in PT,  - Está a chorar.
# Sentence in BR,  Você está chorando.
# Sentence in PT,  [ Com isto, vemo-nos até amanhã à hora habitual.
# Sentence in BR,  Temos um encontro amanhã nesse mesmo horário.
# Sentence in PT,  - Qual é que quer?
# Sentence in BR,  Qual vai querer?
# Sentence in PT,  - Bálsamo
# Sentence in BR,  Vamos dançar.
# Sentence in PT,  Beddissima
# Sentence in BR,  Como assim?
# Sentence in PT,  Numa altura destas ♫
# Sentence in BR,  Num momento assim
# Sentence in PT,  Tu cu si? - Rosário Puglisi.
# Sentence in BR,  - Quem é você? - Rosario Puglisi.
# Sentence in PT,  - Não, não - Annamu!
# Sentence in BR,  - Não, não. - Mexa-se!
# Sentence in PT,  vulissa iri em casa.
# Sentence in BR,  Gostaria de ir para casa.
# Sentence in PT,  Compreendeu-o? - Sim.
# Sentence in BR,  - Entendido? - Sim.
# Sentence in PT,  - Cuidar deles
# Sentence in BR,  Cuide dos documentos.
# Sentence in PT,  - Olá tio. - Talia cu cc'è
# Sentence in BR,  - Oi, tio. - Veja só quem chegou.
# Sentence in PT,  - Mas porquê?
# Sentence in BR,  - Mas por quê? - Disse que não se sentia bem,
# Sentence in PT,  - Adeus Picciotti, até à vista. - Até à vista.
# Sentence in BR,  - Tchau, rapazes. - Até mais.
# Sentence in PT,  - Mas aconteceu alguma coisa?
# Sentence in BR,  Depois eu volto. Até logo.
# Sentence in PT,  Adeus - Muito bem, adeus.
# Sentence in BR,  Está certo, tchau.
# Sentence in PT,  - Oh, tu!
# Sentence in BR,  Ei, você!
# Sentence in PT,  - Mas eu? - Tu, tu.
# Sentence in BR,  - Eu? - Isso, você mesmo.
# Sentence in PT,  - Véni ca.
# Sentence in BR,  Venha.
# Sentence in PT,  Véni.
# Sentence in BR,  Venha aqui.
# Sentence in PT,  Estavam à procura do Giannuzza, não estavam?
# Sentence in BR,  Estava procurando a Giannizinha, certo?
# Sentence in PT,  - Mas Turi, entretém-nos.
# Sentence in BR,  Turi, deixe eu me divertir.
# Sentence in PT,  - E boa Josefina
# Sentence in BR,  Isso mesmo, Giuseppina.
# Sentence in PT,  - No trabalho?
# Sentence in BR,  Trabalhando? Mas que trabalho?
# Sentence in PT,  Espera, onde é que vais?
# Sentence in BR,  Espere, aonde vai? Fique um pouco.
# Sentence in PT,  Idda faz-se de tímida.
# Sentence in BR,  Está bancando a tímida.
# Sentence in PT,  Também é mau para ti?
# Sentence in BR,  Ele chupa você também?
# Sentence in PT,  - Chega, Remu
# Sentence in BR,  Chega, cale a boca.
# Sentence in PT,  Se não, mato-te.
# Sentence in BR,  Calado! Entendeu? Senão eu mato você.
# Sentence in PT,  Ainda aí estás? Vattinni.
# Sentence in BR,  Você ainda está aqui? Dê o fora. Corra, bebê!
# Sentence in PT,  Excita-se com isso, não é?
# Sentence in BR,  Eu te deixei com medo, né?
# Sentence in PT,  - Nada.
# Sentence in BR,  Nada.
# Sentence in PT,  - Quem são vocês?
# Sentence in BR,  O que você quer?
# Sentence in PT,  Conti sulu bullshit
# Sentence in BR,  Você mente muito.
# Sentence in PT,  - O que é que sabe sobre o assunto?
# Sentence in BR,  De onde tirou isso?
# Sentence in PT,  - Si a pigghiaru puri cu mia.
# Sentence in BR,  Eles me zoaram também.
# Sentence in PT,  - Peço desculpa.
# Sentence in BR,  Sinto muito.
# Sentence in PT,  - Tretas.
# Sentence in BR,  É bobagem.
# Sentence in PT,  - Assim, a solução está encontrada.
# Sentence in BR,  Então, acharemos uma solução.
# Sentence in PT,  Nós saímos.
# Sentence in BR,  Vamos descer?
# Sentence in PT,  - Não - Tomate manco, e bem, quem sabe?
# Sentence in BR,  Ali tem tomate. Você conhece tomate?
# Sentence in PT,  e... como é que lhe chamam, caralho?
# Sentence in BR,  Deixe-me apresentar
# Sentence in PT,  sentar-se
# Sentence in BR,  Sente-se.
# Sentence in PT,  - Ninuzzo - Olá.
# Sentence in BR,  - Nino. - Oi.
# Sentence in PT,  - Aqui, come.
# Sentence in BR,  Comam.
# Sentence in PT,  Accussì ci dicisti a ta matre dell'altra sera.
# Sentence in BR,  Então você contou para sua mãe sobre a outra noite.
# Sentence in PT,  Tenho demasiadas dificuldades.
# Sentence in BR,  Eu trabalho demais.
# Sentence in PT,  E, de facto, é por causa deste pai que eu...
# Sentence in BR,  É bastante.
# Sentence in PT,  Sabes que estou a ir bem, não sabes?
# Sentence in BR,  Você sabe que consigo, né?
# Sentence in PT,  Sozinho?
# Sentence in BR,  Sozinho?
# Sentence in PT,  quem sabe...
# Sentence in BR,  Sei lá...
# Sentence in PT,  Porque não?
# Sentence in BR,  Por que não? Ele tem vontade de trabalhar.
# Sentence in PT,  Vai e pega carona em mim, vai
# Sentence in BR,  Vá pegar outra cerveja.
# Sentence in PT,  Está bem assim? - Está bem.
# Sentence in BR,  - Está certo? - Está certo.
# Sentence in PT,  - E quem é que somos todos burros?
# Sentence in BR,  - Viva São Sebastião! - Viva!
# Sentence in PT,  - Desculpe...
# Sentence in BR,  Com licença...
# Sentence in PT,  Para ser passado para o exterior.
# Sentence in BR,  Você terá que dar a volta.
# Sentence in PT,  Devo passar?
# Sentence in BR,  Deixo passar?
# Sentence in PT,  Passem por aqui. - Obrigado.
# Sentence in BR,  - Podem passar. - Obrigado.
# Sentence in PT,  - Bravo, colocar as caixas de cartão próximas umas das outras.
# Sentence in BR,  Coloque os papelões perto. Não junto, só perto. Isso.
# Sentence in PT,  - Mas queres ganhar comigo? - Véni ca, véni ca!
# Sentence in BR,  - Vem cá, vem. - Você acha que ganha de mim?
# Sentence in PT,  - A véni ca, o quê?
# Sentence in BR,  Agora quero ver.
# Sentence in PT,  - Eh, não te passes comigo - Ah
# Sentence in BR,  Não fuja mais de mim.
# Sentence in PT,  - Contru mia, não podes ganhar.
# Sentence in BR,  Contra mim você não pode vencer.
# Sentence in PT,  - Não podes ganhar.
# Sentence in BR,  - Você não pode vencer. - Chega.
# Sentence in PT,  - É suficiente.
# Sentence in BR,  Sai de cima de mim.
# Sentence in PT,  - Deixem-me arricriari picciotti.
# Sentence in BR,  Façam meu esforço valer a pena, rapazes.
# Sentence in PT,  - Véni ca - Cabe a ca.
# Sentence in BR,  - Vem cá. - Espere um pouco.
# Sentence in PT,  - O que é que se passa, pai?
# Sentence in BR,  - Oi, pai. - Gostou dos rojões?
# Sentence in PT,  - Gostaram dos fogos? - Que bonito.
# Sentence in BR,  São lindos.
# Sentence in PT,  - Eles contaram-me tudo.
# Sentence in BR,  Eu já soube de tudo.
# Sentence in PT,  - Ca è, um pequeno momento interior - Chama-o.
# Sentence in BR,  - Lá fora. O que te disseram? - Chame ele.
# Sentence in PT,  - Gianni, véni ca.
# Sentence in BR,  Gianni, vem cá.
# Sentence in PT,  O espetáculo foi bom
# Sentence in BR,  A queima de fogos foi boa.
# Sentence in PT,  Totò. - O quê?
# Sentence in BR,  - Totó. - O que foi?
# Sentence in PT,  - Totò, véni ca.
# Sentence in BR,  Vem cá.
# Sentence in PT,  Nonnu, estás a cagar.
# Sentence in BR,  Vô, estou cagando.
# Sentence in PT,  Bravo.
# Sentence in BR,  Bom trabalho.
# Sentence in PT,  - Quem é que está lá?
# Sentence in BR,  e disse que a cidade inteira
# Sentence in PT,  - E véni ca, toma este dinheiro
# Sentence in BR,  - a Itália vai perder hoje. - Venha, pegue o dinheiro.
# Sentence in PT,  - Adeus mãe, adeus, adeus - adeus mãe, adeus avô
# Sentence in BR,  - Tchau, mãe. - Tchau, mãe. Tchau, vó.
# Sentence in PT,  - Totò... - Unni sta jennu? - Adeus.
# Sentence in BR,  Totó... Aonde estão indo? Até logo, Gianni.
# Sentence in PT,  Então, estás pronto?
# Sentence in BR,  Vocês estão prontos?
# Sentence in PT,  Vamos, tio
# Sentence in BR,  Vai, tio.
# Sentence in PT,  - Eu vim acchi
# Sentence in BR,  Vem cá.
# Sentence in PT,  - Totò, véni ca! - Véni, Totò.
# Sentence in BR,  -Totó, venha! - Vem, Totó.
# Sentence in PT,  - Oh Totó, está quieto.
# Sentence in BR,  - Totó, pare com isso. - Deixa ele.
# Sentence in PT,  ver que eu cortei estas bolas.
# Sentence in BR,  Totó, eu vou furar essa bola.
# Sentence in PT,  ver o seu corte
# Sentence in BR,  Totó, juro que vou furar.
# Sentence in PT,  Totò,
# Sentence in BR,  Totó, vou furar.
# Sentence in PT,  Eu cortei-o. - No meio, é preciso passar.
# Sentence in BR,  Chute essa bola. Pode passar.
# Sentence in PT,  Parar com o balão de estuque - Bom
# Sentence in BR,  Quieto, não estou ouvindo.
# ...
# Sentence in PT,  Então acho melhor irmos.
# Sentence in BR,  Estava no banheiro.
# Sentence in PT,  Vamos para o round 27, Rocky.
# Sentence in BR,  Certo, o cobertor e depois isto.
# Sentence in PT,  E os que vierem, Tona.
# Sentence in BR,  - Fica tudo entre nós, OK? - OK.
# Sentence in PT,  - Lindo! - Que festa boa.
# Sentence in BR,  - Você nunca esteve aqui. - Certo.
# Sentence in PT,  Te amo muito, mano.
# Sentence in BR,  Está tudo feito, Garnacha.
# Sentence in PT,  Esther!
# Sentence in BR,  E este é o seu presente.
# Sentence in PT,  - Feliz aniversário, tio. - Obrigado.
# Sentence in BR,  Temos as máscaras, os balões e tudo mais.
# Sentence in PT,  Companheiros...
# Sentence in BR,  Nos reunimos para lhe dar um presente.
# Sentence in PT,  - Aproveite a festa, você é demais. - Que alegria te ver, cara.
# Sentence in BR,  É sempre um problema, mas cada professor tem o seu favorito e ele realmente era o meu.
# Sentence in PT,  - E aí, rapaz da praia? - Sobrinhão.
# Sentence in BR,  E nesse sentido, gostaria de me desculpar porque eu dei uma bronca nele por causa do carma ruim.
# Sentence in PT,  - Meus parabéns. - Obrigado, Arielito.
# Sentence in BR,  Ensinar - aprender é um processo dialógico, uma rua de mão dupla.
# Sentence in PT,  Juli, foi ideia sua, não foi?
# Sentence in BR,  Pedro de Alvarado foi chamado assim pelos indígenas e foi o pior conquistador,
# Sentence in PT,  Gostou da surpresa?
# Sentence in BR,  responsável pelo massacre de Cholula
# Sentence in PT,  Você é louca, mana. Me emocionou demais.
# Sentence in BR,  e o massacre do Grande Templo de Toxcatl.
# Sentence in PT,  Obrigado.
# Sentence in BR,  O nome Tonatiuh significa 'branco'.
# Sentence in PT,  Obrigado. Obrigado a todos.
# Sentence in BR,  existe uma parte luminosa do sol, assim como existe um sol do submundo.
# Sentence in PT,  Vasallo!
# Sentence in BR,  Mas, realmente,
# Sentence in PT,  Irmãzinha, obrigado por tudo.
# Sentence in BR,  Ilumina, sem tristeza, até o entardecer.
# Sentence in PT,  Te amo muito, moleque.
# Sentence in BR,  Mas há um sol, um sol que brilha.
# Sentence in PT,  Onde você estava?
# Sentence in BR,  Os lacandons dizem que a onça anda.
# Sentence in PT,  Coloque algo no meio desses dois.
# Sentence in BR,  E embora possa ser o sol do meio-dia, não teme o seu declínio.
# Sentence in PT,  Embaixo, coloque um cobertor sobre.
# Sentence in BR,  E assim, Tonaya se transformou em Tona, pelo trabalho, pela arte.
# Sentence in PT,  - Isso fica entre nós, está bem? - Está bem.
# Sentence in BR,  - Meu pozole está esfriando, Vassallo. - Já deu pra mim.
# Sentence in PT,  Estou com as máscaras, o balão, são várias coisas.
# Sentence in BR,  E... como Tona já sabe, o tempo na Mesoamérica é cíclico.
# Sentence in PT,  Nos reunimos para te trazer um presente.
# Sentence in BR,  os ciclos retornam a um ponto, mas não ao mesmo ponto.
# Sentence in PT,  E este é o presente.
# Sentence in BR,  É uma espiral ascendente
# Sentence in PT,  Sempre dá briga, mas todo professor tem os seus favoritos nas turmas.
# Sentence in BR,  apesar de parecer retornar ao mesmo.
# Sentence in PT,  E ele foi de fato o meu.
# Sentence in BR,  - Bravo! - Dando a volta ao sol novamente.
# Sentence in PT,  Sabe que eu gosto muito de você por isso.
# Sentence in BR,  Ótimo discurso!
# Sentence in PT,  E eu sempre falava um pouco sobre Paulo Freire, não é?
# Sentence in BR,  estamos aqui, no mesmo lugar, mas em outro lugar.
# Sentence in PT,  Ensinar...
# Sentence in BR,  Tona...
# Sentence in PT,  e aprender é um processo dialógico, uma via de mão dupla.
# Sentence in BR,  Sou péssima para falar.
# Sentence in PT,  E, nesse sentido também, eu...
# Sentence in BR,  Desculpe.
# Sentence in PT,  Nos ensine, Vasallo!
# Sentence in BR,  Vamos, Vassallo!
# Sentence in PT,  É que Pedro de Alvarado foi chamado assim pelos indígenas e foi o conquistador mais desgraçado.
# Sentence in BR,  Todas as viagens que fizemos juntos,
# Sentence in PT,  Responsável pelo Massacre de Cholula e pelo Massacre do Templo Maior de Tóxcatl.
# Sentence in BR,  através de sua amizade.
# Sentence in PT,  Mas, realmente,
# Sentence in BR,  as astrais
# Sentence in PT,  Porque há um sol do inframundo.
# Sentence in BR,  você me ensinou o amor
# Sentence in PT,  Os lacandones dizem que o jaguar caminha.
# Sentence in BR,  e as geográficas,
# Sentence in PT,  Neste momento, está caminhando. É o sol noturno.
# Sentence in BR,  Acenda! Vamos!
# Sentence in PT,  Mas há um sol...
# Sentence in BR,  amigo...
# Sentence in PT,  um sol que brilha.
# Sentence in BR,  Eu te amo.
# Sentence in PT,  Ilumina sem tristeza até o entardecer.
# Sentence in BR,  Suavemente, suavemente...
# Sentence in PT,  E assim, o Tonaya se transformou em Tona.
# Sentence in BR,  A chama está se aproximando do papel.
# Sentence in PT,  Pelo trabalho, pela arte.
# Sentence in BR,  Voe, balão, voe!
# Sentence in PT,  - Meu prato está esfriando, Vasallo! - Ótimo, ótimo!
# Sentence in BR,  Está indo, está indo!
# Sentence in PT,  Para os antepassados, um golinho. Saúde.
# Sentence in BR,  Fogo, fogo, fogo!
# Sentence in PT,  Eu queria dizer a Tona que,
# Sentence in BR,  Aqui vamos nós!
# Sentence in PT,  que é o calendário ritualístico de 260 dias da Mesoamérica.
# Sentence in BR,  - Está caindo! - Cuidado. Saia do caminho!
# Sentence in PT,  E, bem, como...
# Sentence in BR,  Voe, voe, voe!
# Sentence in PT,  Aqui, nessas terras, os ciclos retornam a um lugar, mas não é ao mesmo lugar, é uma espiral ascendente
# Sentence in BR,  - Você vai atear fogo nele. Atenção! - Cuidado com a árvore.
# Sentence in PT,  que vai indo para outros lugares, embora pareça voltar ao mesmo lugar.
# Sentence in BR,  Lá se vai a nossa oferenda aos deuses.
# Sentence in PT,  Então, neste aniversário tão especial, Tona,
# Sentence in BR,  - Estou terminando o bolo de aniversário. - Deixe o bolo por enquanto.
# Sentence in PT,  estamos aqui, no mesmo lugar, mas em outro lugar.
# Sentence in BR,  - Eu não estou de fogo. - Nuri, por favor.
# Sentence in PT,  Eu sou péssima em falar.
# Sentence in BR,  Só tomei uns goles. Relaxa.
# Sentence in PT,  - Que belo discurso! - É isso aí!
# Sentence in BR,  - Que sopro? - Você está de fogo.
# Sentence in PT,  Você me ensinou o amor
# Sentence in BR,  Você está fedendo. Por favor, beba.
# Sentence in PT,  através da sua amizade.
# Sentence in BR,  Tona perguntou por você umas quatro vezes. Você vem?
# Sentence in PT,  Eu te amo.
# Sentence in BR,  Vá embora.
# Sentence in PT,  A chama está muito perto do papel.
# Sentence in BR,  - Vê como você está? - O quê? Me deixe.
# Sentence in PT,  Está indo, está subindo.
# Sentence in BR,  - O bolo está pronto. - Ainda não está.
# Sentence in PT,  Está indo!
# Sentence in BR,  Estávamos organizando porque você queria uma festa.
# Sentence in PT,  Como diziam os charros, a beleza é bonita por si só.
# Sentence in BR,  Não me diga para parar. Eu não vou parar.
# Sentence in PT,  Lá vai a nossa oferta para os deuses.
# Sentence in BR,  Sim, eu queria dar uma festa para o meu irmão Tona.
# Sentence in PT,  Sobe, sobe!
# Sentence in BR,  Porque você sempre faz o que quer.
# Sentence in PT,  - Está descendo. - Cuidado! Afaste-se.
# Sentence in BR,  Estou farta. Você quer controlar tudo o que passa nesta casa.
# Sentence in PT,  - Aqui, aqui, aqui. - Não, não, não.
# Sentence in BR,  - Não quer estar? - Não quero estar.
# Sentence in PT,  Tirem isso da mão do Vasallo.
# Sentence in BR,  Não vim brigar. Eu vim por você.
# Sentence in PT,  - Assoprar? - Você está bêbada.
# Sentence in BR,  - Você veio para brigar. - Quero você na festa.
# Sentence in PT,  Isso não é uma festa?
# Sentence in BR,  Eu não quero estar lá.
# Sentence in PT,  - Sério? - Você está fedendo.
# Sentence in BR,  Eu não quero ir à festa, mamãe. Eu quero ajudar você.
# Sentence in PT,  Tona perguntou por você umas quatro vezes, Nuri. Venha.
# Sentence in BR,  OK, querida. Vamos arrumar seu cabelo para você ir à festa.
# Sentence in PT,  Olha só o seu estado.
# Sentence in BR,  Só hoje porque é uma festa.
# Sentence in PT,  Saia.
# Sentence in BR,  OK.
# Sentence in PT,  Há quanto tempo estamos organizando a festa, fazendo algo especial para Tona?
# Sentence in BR,  - Vá para lá agora, sim? - OK.
# Sentence in PT,  Sabe o que é?
# Sentence in BR,  OK, querida.
# Sentence in PT,  Estamos organizando esta festa porque você quis fazer uma festa pra ele.
# Sentence in BR,  É tão fofo o gatinho. Poderia estar na capa de uma revista.
# Sentence in PT,  E estou de saco cheio, de saco cheio, de você querendo me controlar.
# Sentence in BR,  Se você diz, mas você não os pegou.
# Sentence in PT,  Já estou farta.
# Sentence in BR,  - Vá agora. - OK.
# Sentence in PT,  Quer controlar tudo o que acontece nesta casa.
# Sentence in BR,  Mas ela o deixou conosco.
# Sentence in PT,  Não me diga para ficar de boa, não vou ficar de boa.
# Sentence in BR,  Minha mãe gostava muito do desenho chamado Kayú.
# Sentence in PT,  - Cale a boca. - Não, não vou calar.
# Sentence in BR,  - É gatinho. - Gatos são lindos.
# Sentence in PT,  Não vamos brigar agora, Nuri, por favor.
# Sentence in BR,  É o gatinho da Ester.
# Sentence in PT,  E eu não quero estar, cara.
# Sentence in BR,  - Então seu nome é Kayú? - Sim, sim.
# Sentence in PT,  - Você não quer estar? - Eu não quero estar.
# Sentence in BR,  - Ajude-me com ele. - Eu tenho que ir.
# Sentence in PT,  Já estou farta de você. E sabe de uma coisa?
# Sentence in BR,  Dê-me uma hora. Só mais uma hora.
# Sentence in PT,  - Por que está levando a minha bebida? - Porque você já está bêbada.
# Sentence in BR,  - Então, você gosta do seu nome? - Eu gosto.
# Sentence in PT,  E você também já me encheu o saco, faça o que quiser.
# Sentence in BR,  Passei a gostar do desenho animado e isso cresceu em mim.
# Sentence in PT,  Bom, vamos ver, só vou te pentear
# Sentence in BR,  Ok, mas só se você me ajudar.
# Sentence in PT,  para você ir para a festa, minha filha.
# Sentence in BR,  - Você vai largar isso. - Desculpe, vamos lá.
# Sentence in PT,  Sim, meu amor, mas eu tenho que terminar o bolo, filha.
# Sentence in BR,  Ajude-me com Tona, só mais uma horinha.
# Sentence in PT,  Mamãe, eu não quero que você beba.
# Sentence in BR,  - É a festa e tudo mais. - Não se preocupe.
# Sentence in PT,  Não, meu amor.
# Sentence in BR,  Obrigado por tudo. Sério.
# Sentence in PT,  Só hoje porque é uma festa.
# Sentence in BR,  Fique por mais uma horinha.
# Sentence in PT,  Está bem.
# Sentence in BR,  Estou quase terminando, eu prometo.
# Sentence in PT,  Não, meu amor, olha, estou muito atrasada, filha.
# Sentence in BR,  Escute, prometo que pago o resto na próxima sexta, sim?
# Sentence in PT,  Melhor você ir. Anda.
# Sentence in BR,  Mas é melhor que nada, pelo menos.
# Sentence in PT,  Monsi.
# Sentence in BR,  Sente-se.
# Sentence in PT,  Que bonito! Quantos meses ele tem?
# Sentence in BR,  - Sim, está ótima. - Sim?
# Sentence in PT,  Cinco.
# Sentence in BR,  Meu bichinho precioso.
# Sentence in PT,  Ai, ele é lindo, deveria estar na capa de uma revista.
# Sentence in BR,  Ainda mais surpresas para Tona.
# Sentence in PT,  - Então você se chama Kayu? - Sim, isso mesmo.
# Sentence in BR,  - Você é insuportável. Vamos. - Já vou.
# Sentence in PT,  É que a minha mãe gostava muito do desenho animado Caillou.
# Sentence in BR,  O que há? Vamos, vocês dois!
# Sentence in PT,  Sim. Veio daí.
# Sentence in BR,  Sim, adorei ver todo mundo.
# Sentence in PT,  É um personagem muito nobre, muito sentimental.
# Sentence in BR,  Eu fiz isso para te animar.
# Sentence in PT,  Teve tempo, que legal!
# Sentence in BR,  Te esperamos lá fora, OK?
# Sentence in PT,  Me dê mais uma horinha.
# Sentence in BR,  Falta quase nada.
# Sentence in PT,  Meia hora. Para dar o remédio e deixá-lo descansar.
# Sentence in BR,  Sim, vamos lá. Pare de trabalhar como escrava.
# Sentence in PT,  Mas eles estão felizes. Uma hora, vai. Me ajude com ele.
# Sentence in BR,  - Depressa. - Estou quase terminando, eu juro.
# Sentence in PT,  Uma horinha, vá.
# Sentence in BR,  Tona.
# Sentence in PT,  Você já jantou?
# Sentence in BR,  E aí, pai?
# Sentence in PT,  - Fique. - Está bem.
# Sentence in BR,  Eu quero te dar algo.
# Sentence in PT,  Me dê uma mão hoje com o Tona, só uma hora.
# Sentence in BR,  Coloquei em uma das cerâmicas da sua mãe.
# Sentence in PT,  - Me perdoe. - Não se preocupe.
# Sentence in BR,  Te dou de presente.
# Sentence in PT,  A festa e tudo mais...
# Sentence in BR,  Estou cuidando dele há oito anos.
# Sentence in PT,  Pronto, chega. Aqui está.
# Sentence in BR,  Obrigado, pai.
# Sentence in PT,  Um pouco para ajudar o meu magro.
# Sentence in BR,  Você também pode varrer e aspirar.
# Sentence in PT,  - Muito obrigada, Cruz. - De nada.
# Sentence in BR,  - Que grande presente. - Estamos brincando com você.
# Sentence in PT,  Já estou quase. Juro.
# Sentence in BR,  Com os balões e tudo.
# Sentence in PT,  O que você está fazendo, hein?
# Sentence in BR,  Obrigado, você me fez muito feliz.
# Sentence in PT,  Mais surpresas para Tona.
# Sentence in BR,  Surpresas!
# Sentence in PT,  Venha, sente-se.
# Sentence in BR,  Olha, Ester.
# Sentence in PT,  - Você está feliz? - Sim, está legal.
# Sentence in BR,  Você parece o Jimi Hendrix.
# Sentence in PT,  Meu inseto favorito.
# Sentence in BR,  Cara, isso é ótimo.
# Sentence in PT,  Você fica bem com o cabelo curto.
# Sentence in BR,  Calma, rapazes.
# Sentence in PT,  Era para te animar.
# Sentence in BR,  A outra perna.
# Sentence in PT,  Obrigado, mas você já sabe que sou...
# Sentence in BR,  Agora, há apenas uma de nós.
# Sentence in PT,  cabeludo.
# Sentence in BR,  Parabéns, Tona.
# Sentence in PT,  Vamos, venham os dois.
# Sentence in BR,  Sejam todos bem-vindos.
# Sentence in PT,  - Venham. Pare de trabalhar. - Já vamos.
# Sentence in BR,  - O que direi? - Vamos ver.
# Sentence in PT,  Só falta um pouco. Juro, nada, quase nada.
# Sentence in BR,  Tchan-tchan!
# Sentence in PT,  - Você está insuportável. Venha. - Já vou.
# Sentence in BR,  - Você nos apresenta. OK? - Sim!
# Sentence in PT,  Te esperaremos aqui fora, Nuri.
# Sentence in BR,  Veja nosso truque.
# Sentence in PT,  - Vai rápido. - Juro que não falta nada.
# Sentence in BR,  Agora, são duas.
# Sentence in PT,  Isso, a perna.
# Sentence in BR,  Vai ter uma música.
# Sentence in PT,  - Obrigado, Cruz. - De nada.
# Sentence in BR,  - "Eu sou a maestrina da orquestra." - Sim.
# Sentence in PT,  Tona.
# Sentence in BR,  Duas.
# Sentence in PT,  E aí, pai?
# Sentence in BR,  - DJ Chava. - Calma, calma!
# Sentence in PT,  Quero te dar algo.
# Sentence in BR,  Mulheres e homens?
# Sentence in PT,  Coloquei em um vaso da sua mãe.
# Sentence in BR,  Hoje temos um show para o Tio Tona!
# Sentence in PT,  Estou cuidando dele há oito anos.
# Sentence in BR,  Bem-vindos, senhoras e senhores!
# Sentence in PT,  Obrigado, pai.
# Sentence in BR,  Música, maestro!
# Sentence in PT,  É isso aí, Tona!
# Sentence in BR,  Vamos, Tona!
# Sentence in PT,  Veja o nosso truque.
# Sentence in BR,  Você pode cair, mas não quebre.
# Sentence in PT,  Agora somos apenas uma pessoa.
# Sentence in BR,  Vamos, meu charro.
# Sentence in PT,  Agora somos duas.
# Sentence in BR,  Bravo, Sol!
# Sentence in PT,  - Você vai nos apresentar. - Sim.
# Sentence in BR,  Você sempre supera.
# Sentence in PT,  Vamos ver, tente.
# Sentence in BR,  Nós amamos você, Tona.
# Sentence in PT,  mulheres e homens.
# Sentence in BR,  Acho que estou com fome.
# Sentence in PT,  Vai ter uma música.
# Sentence in BR,  Nós amamos você, cara.
# Sentence in PT,  Uma música, um espetáculo e diga: "Eu sou a maestrina."
# Sentence in BR,  E aí, cara? Está tudo bem.
# Sentence in PT,  Bem-vindos, senhores e senhoras.
# Sentence in BR,  Nós amamos você, Tona. Nós te amamos.
# Sentence in PT,  - Música, maestro! - DJ Chava!
# Sentence in BR,  - Tio, você quer um bolo? - Sim, vamos comer bolo.
# Sentence in PT,  Silêncio.
# Sentence in BR,  É lindo!
# Sentence in PT,  Espalhe um choro amargo
# Sentence in BR,  De nada, querido.
# Sentence in PT,  Pelo meu corpo terreno
# Sentence in BR,  Quero igual, mas com sereias.
# Sentence in PT,  Enquanto lá em cima no céu
# Sentence in BR,  Sim, meu irmão e minhas irmãs estão zombando de mim.
# Sentence in PT,  Eu orarei
# Sentence in BR,  Super nerd.
# Sentence in PT,  A Nuri arrasou.
# Sentence in BR,  PARA MINHA FILHA
# Sentence in PT,  De nada, meu amor.
# Sentence in BR,  Legendas: Kleen Sonata Première
# Total number of super different sentences: 9931

# %% [markdown]
# **//ARE THE SENTENCES WELL CONNECTED?**

# %%
df_subtitle_pairs.head(-50)
# Out:
#        pair_id  movie_id  pair_no  start_pt_ms  end_pt_ms  \
# 0            1         1        1          980       5938
# 1            2         1        2       111772     118272
# 2            3         1        3       286522     288480
# 3            4         1        4       291647     297688
# 4            5         1        5       297855     300688
# ...        ...       ...      ...          ...        ...
# 58968    58969        58      973      4704139    4705225
# 58969    58970        58      974      4707935    4710145
# 58970    58971        58      975      4716068    4718028
# 58971    58972        58      976      4720448    4722533
# 58972    58973        58      977      4723868    4725727
#
#                                                  text_pt  start_br_ms  \
# 0            CONTÉM REPRESENTAÇÕES DE PRODUTOS DE TABACO         1000
# 1                                       POBRES CRIATURAS       111800
# 2                                                 Adeus!       286542
# 3      Uma pilha de órgãos sem a centelha de humanida...       291667
# 4        Parece a banca de um talhante para um banquete.       297875
# ...                                                  ...          ...
# 58968                                   Venha, sente-se.      4741840
# 58969              - Você está feliz? - Sim, está legal.      4710480
# 58970                               Meu inseto favorito.      4716000
# 58971                  Você fica bem com o cabelo curto.      4730440
# 58972                                Era para te animar.      4744360
#
#        end_br_ms                                            text_br     score
# 0           6000                          HÁ CENAS DE USO DE TABACO  0.712900
# 1         118100                                   POBRES CRIATURAS  0.999860
# 2         288500                                             Adeus.  0.880900
# 3         295458  Um monte de órgãos sem a centelha de si na men...  0.677900
# 4         300708  É só um prato do açougueiro para o almoço de d...  0.551900
# ...          ...                                                ...       ...
# 58968    4743600                                       Olha, Ester.  0.510495
# 58969    4712720                        Você parece o Jimi Hendrix.  0.595275
# 58970    4718000                                Cara, isso é ótimo.  0.586660
# 58971    4731920                                    Calma, rapazes.  0.425040
# 58972    4746320                                     A outra perna.  0.533540
#
# [58973 rows x 10 columns]

# %%
import pandas as pd
import re

# 2) helper to decide merge on two fragments
def would_merge(a_text, b_text, a_end_ms, b_start_ms, gap_ms=120):
    a = strip_tags_str(a_text); b = strip_tags_str(b_text)
    gap = b_start_ms - a_end_ms
    if gap > gap_ms:
        return False
    tail = a.rstrip()[-1:]; head = b.lstrip()[:1]
    return (tail == "," or tail not in ".?!") and head.islower()

# 3) prepare DataFrame
df = df_subtitle_pairs.sort_values(['movie_id','pair_no']).reset_index(drop=True)

merge_count = 0
groups = []
current_group = [0]

# 4) build dual-language groups
for i in range(1, len(df)):
    prev, curr = df.iloc[i-1], df.iloc[i]
    same_movie = (prev.movie_id == curr.movie_id)
    pt_ok = would_merge(prev.text_pt, curr.text_pt, prev.end_pt_ms, curr.start_pt_ms)
    br_ok = would_merge(prev.text_br, curr.text_br, prev.end_br_ms, curr.start_br_ms)
    
    if same_movie and pt_ok and br_ok:
        current_group.append(i)
    else:
        groups.append(current_group)
        current_group = [i]
groups.append(current_group)

# 5) inspect & count
for grp in groups:
    if len(grp) > 1:
        merge_count += 1
        print(f"\n--- Merge group #{merge_count} (rows {grp}) ---")
        print("Original PT-PT sentences:")
        for idx in grp:
            row = df.iloc[idx]
            print(f"  • [{row.movie_id},{row.pair_no}]: {strip_tags_str(row.text_pt)}")
        print("Original PT-BR sentences:")
        for idx in grp:
            row = df.iloc[idx]
            print(f"  • [{row.movie_id},{row.pair_no}]: {strip_tags_str(row.text_br)}")

        # build the merged texts
        merged_pt = strip_tags_str(df.iloc[grp[0]].text_pt)
        merged_br = strip_tags_str(df.iloc[grp[0]].text_br)
        for idx in grp[1:]:
            txt_pt = strip_tags_str(df.iloc[idx].text_pt)
            txt_br = strip_tags_str(df.iloc[idx].text_br)
            # PT merge
            if merged_pt.rstrip().endswith(","):
                merged_pt += " " + txt_pt
            else:
                merged_pt = merged_pt.rstrip() + " " + txt_pt
            # BR merge (same logic)
            if merged_br.rstrip().endswith(","):
                merged_br += " " + txt_br
            else:
                merged_br = merged_br.rstrip() + " " + txt_br

        print("Merged PT-PT version:")
        print(f"  ▶ {merged_pt}")
        print("Merged PT-BR version:")
        print(f"  ▶ {merged_br}")

print(f"\nTotal dual-language merge events: {merge_count}")
# Out:
# --- Merge group #1 (rows [14138, 14139]) ---
# Original PT-PT sentences:
#   • [15,5]: o assassino em série norte-americano
#   • [15,6]: mais prolífico e singular do século XXI
# Original PT-BR sentences:
#   • [15,5]: o serial killer americano mais prolífico e único
#   • [15,6]: do século 21
# Merged PT-PT version:
#   ▶ o assassino em série norte-americano mais prolífico e singular do século XXI
# Merged PT-BR version:
#   ▶ o serial killer americano mais prolífico e único do século 21
#
# --- Merge group #2 (rows [14140, 14141, 14142, 14143, 14144]) ---
# Original PT-PT sentences:
#   • [15,7]: orquestrou uma onda de homicídios multiestatal
#   • [15,8]: que começou em Denver, Colorado,
#   • [15,9]: continuou por Grand Lake,
#   • [15,10]: expandiu-se pelo Wyoming e pelo centro de Idaho,
#   • [15,11]: e terminou na floresta densa do condado de Hood River,
# Original PT-BR sentences:
#   • [15,7]: orquestrou um massacre multiestadual
#   • [15,8]: que começou em Denver, Colorado,
#   • [15,9]: continuou em Grand Lake,
#   • [15,10]: e se expandiu através de Wyoming e centro de Idaho
#   • [15,11]: antes de culminar na floresta do Condado de Hood River, Oregon.
# Merged PT-PT version:
#   ▶ orquestrou uma onda de homicídios multiestatal que começou em Denver, Colorado, continuou por Grand Lake, expandiu-se pelo Wyoming e pelo centro de Idaho, e terminou na floresta densa do condado de Hood River,
# Merged PT-BR version:
#   ▶ orquestrou um massacre multiestadual que começou em Denver, Colorado, continuou em Grand Lake, e se expandiu através de Wyoming e centro de Idaho antes de culminar na floresta do Condado de Hood River, Oregon.
#
# --- Merge group #3 (rows [14145, 14146]) ---
# Original PT-PT sentences:
#   • [15,12]: Com base em entrevistas policiais,
#   • [15,13]: relatos detalhados de testemunhas,
# Original PT-BR sentences:
#   • [15,12]: Baseando-se nas entrevistas policiais,
#   • [15,13]: nos relatos detalhados de testemunhas,
# Merged PT-PT version:
#   ▶ Com base em entrevistas policiais, relatos detalhados de testemunhas,
# Merged PT-BR version:
#   ▶ Baseando-se nas entrevistas policiais, nos relatos detalhados de testemunhas,
#
# --- Merge group #4 (rows [14148, 14149]) ---
# Original PT-PT sentences:
#   • [15,15]: esta é uma dramatização da história verídica
#   • [15,16]: dos últimos assassinatos conhecidos
# Original PT-BR sentences:
#   • [15,15]: essa é uma dramatização da história real
#   • [15,16]: das últimas mortes conhecidas dessa matança.
# Merged PT-PT version:
#   ▶ esta é uma dramatização da história verídica dos últimos assassinatos conhecidos
# Merged PT-BR version:
#   ▶ essa é uma dramatização da história real das últimas mortes conhecidas dessa matança.
#
# --- Merge group #5 (rows [14154, 14155]) ---
# Original PT-PT sentences:
#   • [15,21]: Embora os céticos não acreditem que seja real,
#   • [15,22]: é.
# Original PT-BR sentences:
#   • [15,21]: Apesar de céticos não acreditarem,
#   • [15,22]: é real.
# Merged PT-PT version:
#   ▶ Embora os céticos não acreditem que seja real, é.
# Merged PT-BR version:
#   ▶ Apesar de céticos não acreditarem, é real.
#
# --- Merge group #6 (rows [14157, 14158]) ---
# Original PT-PT sentences:
#   • [15,24]: Hoje vamos falar sobre
#   • [15,25]: a descoberta arrepiante de uma família de Bigfoot
# Original PT-BR sentences:
#   • [15,24]: Hoje vamos falar sobre a descoberta arrepiante
#   • [15,25]: de uma família de Pé Grande na floresta
# Merged PT-PT version:
#   ▶ Hoje vamos falar sobre a descoberta arrepiante de uma família de Bigfoot
# Merged PT-BR version:
#   ▶ Hoje vamos falar sobre a descoberta arrepiante de uma família de Pé Grande na floresta
#
# --- Merge group #7 (rows [14179, 14180]) ---
# Original PT-PT sentences:
#   • [15,46]: O que me chateou mesmo
#   • [15,47]: foi que íamos abatê-lo no próximo mês.
# Original PT-BR sentences:
#   • [15,46]: Isso me aborreceu muito,
#   • [15,47]: pois íamos matar no próximo mês.
# Merged PT-PT version:
#   ▶ O que me chateou mesmo foi que íamos abatê-lo no próximo mês.
# Merged PT-BR version:
#   ▶ Isso me aborreceu muito, pois íamos matar no próximo mês.
#
# --- Merge group #8 (rows [14199, 14200]) ---
# Original PT-PT sentences:
#   • [15,66]: E só de ver o contorno ao luar,
#   • [15,67]: soube imediatamente o que era.
# Original PT-BR sentences:
#   • [15,66]: E mesmo só vendo a silhueta na luz da lua,
#   • [15,67]: e imediatamente sabia o que era.
# Merged PT-PT version:
#   ▶ E só de ver o contorno ao luar, soube imediatamente o que era.
# Merged PT-BR version:
#   ▶ E mesmo só vendo a silhueta na luz da lua, e imediatamente sabia o que era.
#
# --- Merge group #9 (rows [14737, 14738]) ---
# Original PT-PT sentences:
#   • [15,604]: A partir do alto deserto no majestoso Oeste americano,
#   • [15,605]: desejo a todos uma boa noite.
# Original PT-BR sentences:
#   • [15,604]: Do alto deserto no majestoso Oeste americano,
#   • [15,605]: desejo boa noite a todos.
# Merged PT-PT version:
#   ▶ A partir do alto deserto no majestoso Oeste americano, desejo a todos uma boa noite.
# Merged PT-BR version:
#   ▶ Do alto deserto no majestoso Oeste americano, desejo boa noite a todos.
#
# --- Merge group #10 (rows [14739, 14740]) ---
# Original PT-PT sentences:
#   • [15,606]: Ou bom dia, ou boa tarde,
#   • [15,607]: onde quer que estejam nesta nossa grande Terra.
# Original PT-BR sentences:
#   • [15,606]: Ou bom dia, ou boa tarde,
#   • [15,607]: onde quer que vocês estejam nesta nossa grande Terra.
# Merged PT-PT version:
#   ▶ Ou bom dia, ou boa tarde, onde quer que estejam nesta nossa grande Terra.
# Merged PT-BR version:
#   ▶ Ou bom dia, ou boa tarde, onde quer que vocês estejam nesta nossa grande Terra.
#
# --- Merge group #11 (rows [14741, 14742]) ---
# Original PT-PT sentences:
#   • [15,608]: Este é o famoso programa, De Costa a Costa,
#   • [15,609]: noite escura no deserto.
# Original PT-BR sentences:
#   • [15,608]: É o mundialmente famoso "Assustador de Costa a Costa AM",
#   • [15,609]: numa noite escura no deserto.
# Merged PT-PT version:
#   ▶ Este é o famoso programa, De Costa a Costa, noite escura no deserto.
# Merged PT-BR version:
#   ▶ É o mundialmente famoso "Assustador de Costa a Costa AM", numa noite escura no deserto.
#
# --- Merge group #12 (rows [14853, 14854]) ---
# Original PT-PT sentences:
#   • [16,110]: Sobrecarregadas por pessoas afetadas pelas cheias,
#   • [16,111]: muitas localidades em pontos mais altos
# Original PT-BR sentences:
#   • [16,110]: Sobrecarregados pelo fluxo de gente afetada pela inundação,
#   • [16,111]: muitas cidades e vilarejos em terrenos altos
# Merged PT-PT version:
#   ▶ Sobrecarregadas por pessoas afetadas pelas cheias, muitas localidades em pontos mais altos
# Merged PT-BR version:
#   ▶ Sobrecarregados pelo fluxo de gente afetada pela inundação, muitas cidades e vilarejos em terrenos altos
#
# --- Merge group #13 (rows [14950, 14951]) ---
# Original PT-PT sentences:
#   • [16,207]: Três meses após a última grande cheia,
#   • [16,208]: recomenda-se que a população se desloque até aos abrigos regionais.
# Original PT-BR sentences:
#   • [16,207]: Três meses depois da grande inundação,
#   • [16,208]: a população é aconselhada a refugiar-se em abrigos locais,
# Merged PT-PT version:
#   ▶ Três meses após a última grande cheia, recomenda-se que a população se desloque até aos abrigos regionais.
# Merged PT-BR version:
#   ▶ Três meses depois da grande inundação, a população é aconselhada a refugiar-se em abrigos locais,
#
# --- Merge group #14 (rows [14955, 14956, 14957]) ---
# Original PT-PT sentences:
#   • [16,212]: Num comunicado, pediram às pessoas
#   • [16,213]: para não tentarem regressar a casa
#   • [16,214]: e apelaram à calma no seguimento de casos de violência e pilhagem.
# Original PT-BR sentences:
#   • [16,212]: Num apelo urgente, alertam as pessoas
#   • [16,213]: para não tentarem regressar às casas
#   • [16,214]: e pedem reforço após surtos de violência e saques.
# Merged PT-PT version:
#   ▶ Num comunicado, pediram às pessoas para não tentarem regressar a casa e apelaram à calma no seguimento de casos de violência e pilhagem.
# Merged PT-BR version:
#   ▶ Num apelo urgente, alertam as pessoas para não tentarem regressar às casas e pedem reforço após surtos de violência e saques.
#
# --- Merge group #15 (rows [14958, 14959]) ---
# Original PT-PT sentences:
#   • [16,215]: As maiores agências humanitárias falam
#   • [16,216]: na falta de comida e medicamentos básicos
# Original PT-BR sentences:
#   • [16,215]: As Agências humanitárias afirmam que já sofrem escassez
#   • [16,216]: de alimentos e medicamentos básicos.
# Merged PT-PT version:
#   ▶ As maiores agências humanitárias falam na falta de comida e medicamentos básicos
# Merged PT-BR version:
#   ▶ As Agências humanitárias afirmam que já sofrem escassez de alimentos e medicamentos básicos.
#
# --- Merge group #16 (rows [14960, 14961]) ---
# Original PT-PT sentences:
#   • [16,217]: pelo que, para proteger materiais,
#   • [16,218]: polícias e militares vigiam os bancos alimentares,
# Original PT-BR sentences:
#   • [16,217]: Tentando proteger os abastecimentos,
#   • [16,218]: a polícia e militares armados estão protegendo
# Merged PT-PT version:
#   ▶ pelo que, para proteger materiais, polícias e militares vigiam os bancos alimentares,
# Merged PT-BR version:
#   ▶ Tentando proteger os abastecimentos, a polícia e militares armados estão protegendo
#
# --- Merge group #17 (rows [15300, 15301]) ---
# Original PT-PT sentences:
#   • [16,557]: Os meteorologistas anunciaram
#   • [16,558]: que a pior fase das tempestades chegou ao fim.
# Original PT-BR sentences:
#   • [16,557]: Os meteorologistas anunciaram que
#   • [16,558]: a pior das tempestades extremas finalmente passou.
# Merged PT-PT version:
#   ▶ Os meteorologistas anunciaram que a pior fase das tempestades chegou ao fim.
# Merged PT-BR version:
#   ▶ Os meteorologistas anunciaram que a pior das tempestades extremas finalmente passou.
#
# --- Merge group #18 (rows [15302, 15303, 15304]) ---
# Original PT-PT sentences:
#   • [16,559]: Estas notícias abriram caminho
#   • [16,560]: para o lançamento da operação oficial
#   • [16,561]: para a reconstrução da nossa nação.
# Original PT-BR sentences:
#   • [16,559]: Esta notícia tão esperada abriu caminho
#   • [16,560]: para o lançamento da operação oficial
#   • [16,561]: para começar a reconstruir a nossa nação.
# Merged PT-PT version:
#   ▶ Estas notícias abriram caminho para o lançamento da operação oficial para a reconstrução da nossa nação.
# Merged PT-BR version:
#   ▶ Esta notícia tão esperada abriu caminho para o lançamento da operação oficial para começar a reconstruir a nossa nação.
#
# --- Merge group #19 (rows [15310, 15311]) ---
# Original PT-PT sentences:
#   • [16,567]: Por fim, de modo a que as famílias se reencontrem,
#   • [16,568]: foi criada uma rede de desaparecidos em todos os grandes abrigos.
# Original PT-BR sentences:
#   • [16,567]: E numa tentativa de reunir as famílias,
#   • [16,568]: uma lista de desaparecidos foi colocada em cada abrigo.
# Merged PT-PT version:
#   ▶ Por fim, de modo a que as famílias se reencontrem, foi criada uma rede de desaparecidos em todos os grandes abrigos.
# Merged PT-BR version:
#   ▶ E numa tentativa de reunir as famílias, uma lista de desaparecidos foi colocada em cada abrigo.
#
# --- Merge group #20 (rows [20987, 20988]) ---
# Original PT-PT sentences:
#   • [21,18]: Não é algo que possa ser adiado ou negado,
#   • [21,19]: se tiver de o fazer.
# Original PT-BR sentences:
#   • [21,18]: Não é algo que possa ser adiado ou negado
#   • [21,19]: se você tiver que fazer.
# Merged PT-PT version:
#   ▶ Não é algo que possa ser adiado ou negado, se tiver de o fazer.
# Merged PT-BR version:
#   ▶ Não é algo que possa ser adiado ou negado se você tiver que fazer.
#
# --- Merge group #21 (rows [20992, 20993]) ---
# Original PT-PT sentences:
#   • [21,23]: Ouça, se eu soubesse de onde vêm as ideias,
#   • [21,24]: teria escrito e recebido muito mais dinheiro do que recebi.
# Original PT-BR sentences:
#   • [21,23]: Ouça, se eu soubesse de onde vieram as ideias,
#   • [21,24]: eu teria escrito e, de fato, teria sido pago
# Merged PT-PT version:
#   ▶ Ouça, se eu soubesse de onde vêm as ideias, teria escrito e recebido muito mais dinheiro do que recebi.
# Merged PT-BR version:
#   ▶ Ouça, se eu soubesse de onde vieram as ideias, eu teria escrito e, de fato, teria sido pago
#
# --- Merge group #22 (rows [20994, 20995]) ---
# Original PT-PT sentences:
#   • [21,25]: Tendo em conta que fui prolífico e não estive muito mal na vida,
#   • [21,26]: a resposta curta é que não sei.
# Original PT-BR sentences:
#   • [21,25]: Tendo em mente que tenho sido prolífico e não estou mal,
#   • [21,26]: a resposta curta é... não sei.
# Merged PT-PT version:
#   ▶ Tendo em conta que fui prolífico e não estive muito mal na vida, a resposta curta é que não sei.
# Merged PT-BR version:
#   ▶ Tendo em mente que tenho sido prolífico e não estou mal, a resposta curta é... não sei.
#
# --- Merge group #23 (rows [21329, 21330]) ---
# Original PT-PT sentences:
#   • [21,360]: Quando embarcamos num romance e começamos uma comunhão connosco,
#   • [21,361]: estamos sozinhos,
# Original PT-BR sentences:
#   • [21,360]: e começa uma comunhão consigo mesmo,
#   • [21,361]: você está sozinho.
# Merged PT-PT version:
#   ▶ Quando embarcamos num romance e começamos uma comunhão connosco, estamos sozinhos,
# Merged PT-BR version:
#   ▶ e começa uma comunhão consigo mesmo, você está sozinho.
#
# --- Merge group #24 (rows [27458, 27459, 27460]) ---
# Original PT-PT sentences:
#   • [26,341]: Senhor,
#   • [26,342]: prometo matriculá-la numa boa escola católica
#   • [26,343]: e garantir que ela se forme.
# Original PT-BR sentences:
#   • [26,341]: E minha avó
#   • [26,342]: em uma boa escola católica e
#   • [26,343]: garantirei que ela se forme.
# Merged PT-PT version:
#   ▶ Senhor, prometo matriculá-la numa boa escola católica e garantir que ela se forme.
# Merged PT-BR version:
#   ▶ E minha avó em uma boa escola católica e garantirei que ela se forme.
#
# --- Merge group #25 (rows [27461, 27462]) ---
# Original PT-PT sentences:
#   • [26,344]: Ela vai morar com o meu pai e a Dee,
#   • [26,345]: e terá uma acompanhante o tempo todo.
# Original PT-BR sentences:
#   • [26,344]: Ela viverá com meu pai e Dee
#   • [26,345]: e terá uma acompanhante o tempo todo.
# Merged PT-PT version:
#   ▶ Ela vai morar com o meu pai e a Dee, e terá uma acompanhante o tempo todo.
# Merged PT-BR version:
#   ▶ Ela viverá com meu pai e Dee e terá uma acompanhante o tempo todo.
#
# --- Merge group #26 (rows [27465, 27466]) ---
# Original PT-PT sentences:
#   • [26,348]: Eu amo a sua filha, e posso assegurar-lhe
#   • [26,349]: que as minhas intenções são honrosas, senhor.
# Original PT-BR sentences:
#   • [26,348]: Amo sua filha e posso garantir que
#   • [26,349]: minhas intenções são honrosas, senhor.
# Merged PT-PT version:
#   ▶ Eu amo a sua filha, e posso assegurar-lhe que as minhas intenções são honrosas, senhor.
# Merged PT-BR version:
#   ▶ Amo sua filha e posso garantir que minhas intenções são honrosas, senhor.
#
# --- Merge group #27 (rows [27474, 27475]) ---
# Original PT-PT sentences:
#   • [26,357]: Ela disse que se não a deixarmos ir,
#   • [26,358]: ela arranjará uma maneira de lá chegar sozinha.
# Original PT-BR sentences:
#   • [26,357]: Ela disse que se não a deixarmos ir, ela
#   • [26,358]: encontrará uma maneira de chegar lá sozinha.
# Merged PT-PT version:
#   ▶ Ela disse que se não a deixarmos ir, ela arranjará uma maneira de lá chegar sozinha.
# Merged PT-BR version:
#   ▶ Ela disse que se não a deixarmos ir, ela encontrará uma maneira de chegar lá sozinha.
#
# --- Merge group #28 (rows [27501, 27502]) ---
# Original PT-PT sentences:
#   • [26,384]: Pois é. Falta pouco para acabar a filmagem
#   • [26,385]: e então estarei em casa.
# Original PT-BR sentences:
#   • [26,384]: Sim, só tenho mais um pouco de
#   • [26,385]: filmagem e depois estarei em casa.
# Merged PT-PT version:
#   ▶ Pois é. Falta pouco para acabar a filmagem e então estarei em casa.
# Merged PT-BR version:
#   ▶ Sim, só tenho mais um pouco de filmagem e depois estarei em casa.
#
# --- Merge group #29 (rows [27526, 27527]) ---
# Original PT-PT sentences:
#   • [26,409]: Novo e luxuoso chiffon de creme de baunilha,
#   • [26,410]: com um novo sabor exótico.
# Original PT-BR sentences:
#   • [26,409]: Novo e luxuoso chiffon creme de
#   • [26,410]: baunilha com um novo sabor exótico!
# Merged PT-PT version:
#   ▶ Novo e luxuoso chiffon de creme de baunilha, com um novo sabor exótico.
# Merged PT-BR version:
#   ▶ Novo e luxuoso chiffon creme de baunilha com um novo sabor exótico!
#
# --- Merge group #30 (rows [27531, 27532]) ---
# Original PT-PT sentences:
#   • [26,414]: "Por que viríamos até Los Angeles
#   • [26,415]: para filmar as Smoky Mountains?
# Original PT-BR sentences:
#   • [26,414]: "Por que viemos até Los Angeles
#   • [26,415]: para filmar em Smoky Mountains?
# Merged PT-PT version:
#   ▶ "Por que viríamos até Los Angeles para filmar as Smoky Mountains?
# Merged PT-BR version:
#   ▶ "Por que viemos até Los Angeles para filmar em Smoky Mountains?
#
# --- Merge group #31 (rows [27533, 27534]) ---
# Original PT-PT sentences:
#   • [26,416]: Você pode saber mais sobre cinema,
#   • [26,417]: mas eu conheço as Smoky Mountains.
# Original PT-BR sentences:
#   • [26,416]: Você pode saber mais sobre produção de filmes,
#   • [26,417]: mas eu sei uma coisa ou duas sobre as Smoky Mountains.
# Merged PT-PT version:
#   ▶ Você pode saber mais sobre cinema, mas eu conheço as Smoky Mountains.
# Merged PT-BR version:
#   ▶ Você pode saber mais sobre produção de filmes, mas eu sei uma coisa ou duas sobre as Smoky Mountains.
#
# --- Merge group #32 (rows [27535, 27536]) ---
# Original PT-PT sentences:
#   • [26,418]: E vou dizer-lhe,
#   • [26,419]: lá não há coqueiros!"
# Original PT-BR sentences:
#   • [26,418]: E vou te dizer uma coisa,
#   • [26,419]: eles não têm coqueiros!"
# Merged PT-PT version:
#   ▶ E vou dizer-lhe, lá não há coqueiros!"
# Merged PT-BR version:
#   ▶ E vou te dizer uma coisa, eles não têm coqueiros!"
#
# --- Merge group #33 (rows [27740, 27741]) ---
# Original PT-PT sentences:
#   • [26,623]: Todos os close-ups são dela
#   • [26,624]: e agora querem que ela cante umas canções comigo.
# Original PT-BR sentences:
#   • [26,623]: Ela tem todos os holofotes e agora eles
#   • [26,624]: querem que ela cante algumas músicas comigo.
# Merged PT-PT version:
#   ▶ Todos os close-ups são dela e agora querem que ela cante umas canções comigo.
# Merged PT-BR version:
#   ▶ Ela tem todos os holofotes e agora eles querem que ela cante algumas músicas comigo.
#
# --- Merge group #34 (rows [28633, 28634]) ---
# Original PT-PT sentences:
#   • [27,552]: Sempre preocupado que alguém me esteja a ver,
#   • [27,553]: que alguém me tenha seguido até casa.
# Original PT-BR sentences:
#   • [27,552]: Preocupado que estejam vigiando,
#   • [27,553]: que alguém me seguiu até em casa.
# Merged PT-PT version:
#   ▶ Sempre preocupado que alguém me esteja a ver, que alguém me tenha seguido até casa.
# Merged PT-BR version:
#   ▶ Preocupado que estejam vigiando, que alguém me seguiu até em casa.
#
# --- Merge group #35 (rows [28652, 28653]) ---
# Original PT-PT sentences:
#   • [27,571]: Pequena voz, pequena voz, pequena voz, a pequena voz,
#   • [27,572]: a pequena voz, a pequena voz,
# Original PT-BR sentences:
#   • [27,571]: A vozinha, a vozinha, a vozinha, a vozinha,
#   • [27,572]: a vozinha, a vozinha, a vozinha, a vozinha,
# Merged PT-PT version:
#   ▶ Pequena voz, pequena voz, pequena voz, a pequena voz, a pequena voz, a pequena voz,
# Merged PT-BR version:
#   ▶ A vozinha, a vozinha, a vozinha, a vozinha, a vozinha, a vozinha, a vozinha, a vozinha,
#
# --- Merge group #36 (rows [29765, 29766]) ---
# Original PT-PT sentences:
#   • [29,159]: Esta menina na Feira do Sapato e da Pele
#   • [29,160]: está a mostrar calçado elegante para polícias.
# Original PT-BR sentences:
#   • [29,159]: Essa moça na Feira de Calçados
#   • [29,160]: está exibindo sapatos delicados para policiais.
# Merged PT-PT version:
#   ▶ Esta menina na Feira do Sapato e da Pele está a mostrar calçado elegante para polícias.
# Merged PT-BR version:
#   ▶ Essa moça na Feira de Calçados está exibindo sapatos delicados para policiais.
#
# --- Merge group #37 (rows [29772, 29773, 29774]) ---
# Original PT-PT sentences:
#   • [29,166]: Aliás, por aqueles lados a receita de sucesso para festas de aniversário
#   • [29,167]: parece ser algo como
#   • [29,168]: juntar centenas de homens numa parada, pôr umas dúzias de bandeiras ao vento...
# Original PT-BR sentences:
#   • [29,166]: Na verdade, ali, a receita para festas bem-sucedidas
#   • [29,167]: parece ser algo como juntar algumas centenas de homens,
#   • [29,168]: apresentar bandeiras flutuando ao vento...
# Merged PT-PT version:
#   ▶ Aliás, por aqueles lados a receita de sucesso para festas de aniversário parece ser algo como juntar centenas de homens numa parada, pôr umas dúzias de bandeiras ao vento...
# Merged PT-BR version:
#   ▶ Na verdade, ali, a receita para festas bem-sucedidas parece ser algo como juntar algumas centenas de homens, apresentar bandeiras flutuando ao vento...
#
# --- Merge group #38 (rows [29794, 29795]) ---
# Original PT-PT sentences:
#   • [29,188]: O Roland, como artista e objector de consciência,
#   • [29,189]: foi contratado para desenvolver técnicas de camuflagem
# Original PT-BR sentences:
#   • [29,188]: Roland, como artista e objetor de consciência,
#   • [29,189]: fora contratado para desenvolver técnicas de camuflagem para o esforço de guerra.
# Merged PT-PT version:
#   ▶ O Roland, como artista e objector de consciência, foi contratado para desenvolver técnicas de camuflagem
# Merged PT-BR version:
#   ▶ Roland, como artista e objetor de consciência, fora contratado para desenvolver técnicas de camuflagem para o esforço de guerra.
#
# --- Merge group #39 (rows [30382, 30383]) ---
# Original PT-PT sentences:
#   • [29,776]: Mas quando a próxima edição for a publicar
#   • [29,777]: tenho a certeza de que haverá mais boas notícias.
# Original PT-BR sentences:
#   • [29,776]: Mas quando a próxima edição sair,
#   • [29,777]: tenho certeza de que haverá boas notícias.
# Merged PT-PT version:
#   ▶ Mas quando a próxima edição for a publicar tenho a certeza de que haverá mais boas notícias.
# Merged PT-BR version:
#   ▶ Mas quando a próxima edição sair, tenho certeza de que haverá boas notícias.
#
# --- Merge group #40 (rows [30637, 30638]) ---
# Original PT-PT sentences:
#   • [30,4]: até o avião ter parado totalmente
#   • [30,5]: e o capitão ter desligado o sinal dos cintos apertados.
# Original PT-BR sentences:
#   • [30,4]: até que a aeronave pare por completo
#   • [30,5]: e o aviso luminoso apague.
# Merged PT-PT version:
#   ▶ até o avião ter parado totalmente e o capitão ter desligado o sinal dos cintos apertados.
# Merged PT-BR version:
#   ▶ até que a aeronave pare por completo e o aviso luminoso apague.
#
# --- Merge group #41 (rows [30639, 30640]) ---
# Original PT-PT sentences:
#   • [30,6]: Cuidado a abrir os compartimentos,
#   • [30,7]: pois a bagagem pode ter-se deslocado durante o voo.
# Original PT-BR sentences:
#   • [30,6]: Cuidado ao abrir os compartimentos superiores,
#   • [30,7]: os pertences podem ter se deslocado.
# Merged PT-PT version:
#   ▶ Cuidado a abrir os compartimentos, pois a bagagem pode ter-se deslocado durante o voo.
# Merged PT-BR version:
#   ▶ Cuidado ao abrir os compartimentos superiores, os pertences podem ter se deslocado.
#
# --- Merge group #42 (rows [33403, 33404]) ---
# Original PT-PT sentences:
#   • [33,1]: Passaram-se sete meses desde que Espanha começou a implementar medidas europeias
#   • [33,2]: para combater a falta de recursos essenciais.
# Original PT-BR sentences:
#   • [33,1]: A Espanha entra no 7º mês de implementação das medidas europeias
#   • [33,2]: para combate à falta de recursos básicos.
# Merged PT-PT version:
#   ▶ Passaram-se sete meses desde que Espanha começou a implementar medidas europeias para combater a falta de recursos essenciais.
# Merged PT-BR version:
#   ▶ A Espanha entra no 7º mês de implementação das medidas europeias para combate à falta de recursos básicos.
#
# --- Merge group #43 (rows [33405, 33406, 33407]) ---
# Original PT-PT sentences:
#   • [33,3]: O plano "Não Chega Para Todos" começou a dar frutos,
#   • [33,4]: mas, por agora, Espanha, bem como os seus vizinhos,
#   • [33,5]: não conseguirá sustentar cidadãos dependentes
# Original PT-BR sentences:
#   • [33,3]: O plano "Não tem para todo mundo" começou a dar frutos,
#   • [33,4]: mas, por enquanto, a Espanha e países vizinhos
#   • [33,5]: não poderão sustentar cidadãos dependentes sem o equilíbrio de recursos.
# Merged PT-PT version:
#   ▶ O plano "Não Chega Para Todos" começou a dar frutos, mas, por agora, Espanha, bem como os seus vizinhos, não conseguirá sustentar cidadãos dependentes
# Merged PT-BR version:
#   ▶ O plano "Não tem para todo mundo" começou a dar frutos, mas, por enquanto, a Espanha e países vizinhos não poderão sustentar cidadãos dependentes sem o equilíbrio de recursos.
#
# --- Merge group #44 (rows [34316, 34317]) ---
# Original PT-PT sentences:
#   • [34,201]: Depois de três longas horas,
#   • [34,202]: quando a Srta. Land finalmente e abençoadamente,
# Original PT-BR sentences:
#   • [34,201]: Após três longas horas,
#   • [34,202]: quando a Srta. Land, graças a Deus, finalmente morre,
# Merged PT-PT version:
#   ▶ Depois de três longas horas, quando a Srta. Land finalmente e abençoadamente,
# Merged PT-BR version:
#   ▶ Após três longas horas, quando a Srta. Land, graças a Deus, finalmente morre,
#
# --- Merge group #45 (rows [35112, 35113]) ---
# Original PT-PT sentences:
#   • [34,997]: Quem sabe que demónios levaram
#   • [34,998]: a pobre Nina à sua sepultura solitária?
# Original PT-BR sentences:
#   • [34,997]: Quem sabe que demônios
#   • [34,998]: levaram a pobre Nina à sua solitária sepultura?
# Merged PT-PT version:
#   ▶ Quem sabe que demónios levaram a pobre Nina à sua sepultura solitária?
# Merged PT-BR version:
#   ▶ Quem sabe que demônios levaram a pobre Nina à sua solitária sepultura?
#
# --- Merge group #46 (rows [36617, 36618]) ---
# Original PT-PT sentences:
#   • [36,70]: A polícia enviou a SWAT à sua última localização,
#   • [36,71]: mas foram atacados por um grupo desconhecido com muitas armas.
# Original PT-BR sentences:
#   • [36,70]: A polícia enviou a S.W.A.T. à sua última localização,
#   • [36,71]: mas foram atacados por um grupo desconhecido com muitas armas.
# Merged PT-PT version:
#   ▶ A polícia enviou a SWAT à sua última localização, mas foram atacados por um grupo desconhecido com muitas armas.
# Merged PT-BR version:
#   ▶ A polícia enviou a S.W.A.T. à sua última localização, mas foram atacados por um grupo desconhecido com muitas armas.
#
# --- Merge group #47 (rows [36762, 36763]) ---
# Original PT-PT sentences:
#   • [36,215]: Se está na vossa lista de coisas a visitar em São Francisco,
#   • [36,216]: podem riscá-la agora mesmo.
# Original PT-BR sentences:
#   • [36,215]: Se está na nossa lista de coisas pra visitar em São Francisco,
#   • [36,216]: podem riscá-la agora mesmo.
# Merged PT-PT version:
#   ▶ Se está na vossa lista de coisas a visitar em São Francisco, podem riscá-la agora mesmo.
# Merged PT-BR version:
#   ▶ Se está na nossa lista de coisas pra visitar em São Francisco, podem riscá-la agora mesmo.
#
# --- Merge group #48 (rows [36773, 36774]) ---
# Original PT-PT sentences:
#   • [36,226]: Quando o Serviço Nacional de Parques se envolveu, abriram a ilha
#   • [36,227]: para que o público pudesse desfrutar não só da sua rica história...
# Original PT-BR sentences:
#   • [36,226]: Quando o Serviço Nacional de Parques se envolveu, abriram a ilha
#   • [36,227]: para que o público pudesse desfrutar não só da sua rica história...
# Merged PT-PT version:
#   ▶ Quando o Serviço Nacional de Parques se envolveu, abriram a ilha para que o público pudesse desfrutar não só da sua rica história...
# Merged PT-BR version:
#   ▶ Quando o Serviço Nacional de Parques se envolveu, abriram a ilha para que o público pudesse desfrutar não só da sua rica história...
#
# --- Merge group #49 (rows [36776, 36777]) ---
# Original PT-PT sentences:
#   • [36,229]: ...mas também da vida de aves, aquática e animal
#   • [36,230]: que floresceu aqui ao longo dos anos. Alcatraz tem...
# Original PT-BR sentences:
#   • [36,229]: ...mas também da vida da fauna aquática e de outros animais
#   • [36,230]: que floresceu aqui ao longo dos anos. Alcatraz tem...
# Merged PT-PT version:
#   ▶ ...mas também da vida de aves, aquática e animal que floresceu aqui ao longo dos anos. Alcatraz tem...
# Merged PT-BR version:
#   ▶ ...mas também da vida da fauna aquática e de outros animais que floresceu aqui ao longo dos anos. Alcatraz tem...
#
# --- Merge group #50 (rows [36957, 36958]) ---
# Original PT-PT sentences:
#   • [36,410]: Procuravam ficheiros secretos de casos anteriores de bioterrorismo,
#   • [36,411]: desde Raccoon City.
# Original PT-BR sentences:
#   • [36,410]: Procuravam arquivos secretos de casos anteriores de bioterrorismo,
#   • [36,411]: desde Raccoon City.
# Merged PT-PT version:
#   ▶ Procuravam ficheiros secretos de casos anteriores de bioterrorismo, desde Raccoon City.
# Merged PT-BR version:
#   ▶ Procuravam arquivos secretos de casos anteriores de bioterrorismo, desde Raccoon City.
#
# --- Merge group #51 (rows [37120, 37121]) ---
# Original PT-PT sentences:
#   • [36,573]: Quando os biodrones saírem dos hospedeiros,
#   • [36,574]: teremos milhões.
# Original PT-BR sentences:
#   • [36,573]: Quando os biodrones saírem dos hospedeiros,
#   • [36,574]: teremos milhões.
# Merged PT-PT version:
#   ▶ Quando os biodrones saírem dos hospedeiros, teremos milhões.
# Merged PT-BR version:
#   ▶ Quando os biodrones saírem dos hospedeiros, teremos milhões.
#
# --- Merge group #52 (rows [39732, 39733]) ---
# Original PT-PT sentences:
#   • [39,566]: Tributos, Mentores, têm 15 minutos para examinarem o espaço
#   • [39,567]: e discutirem uma estratégia.
# Original PT-BR sentences:
#   • [39,566]: Tributos, mentores,
#   • [39,567]: vocês têm 15 minutos para ver o espaço e discutir estratégias.
# Merged PT-PT version:
#   ▶ Tributos, Mentores, têm 15 minutos para examinarem o espaço e discutirem uma estratégia.
# Merged PT-BR version:
#   ▶ Tributos, mentores, vocês têm 15 minutos para ver o espaço e discutir estratégias.
#
# --- Merge group #53 (rows [46500, 46501]) ---
# Original PT-PT sentences:
#   • [45,17]: A salsa está ao dobro do preço devido à inflação,
#   • [45,18]: e a imprensa adora a Monika. Estás em todo o lado.
# Original PT-BR sentences:
#   • [45,17]: a salsinha dobrou de preço devido à inflação
#   • [45,18]: e a mídia adora a Monika. Você está em todos os lugares.
# Merged PT-PT version:
#   ▶ A salsa está ao dobro do preço devido à inflação, e a imprensa adora a Monika. Estás em todo o lado.
# Merged PT-BR version:
#   ▶ a salsinha dobrou de preço devido à inflação e a mídia adora a Monika. Você está em todos os lugares.
#
# --- Merge group #54 (rows [46831, 46832]) ---
# Original PT-PT sentences:
#   • [45,348]: Gosto de tocar piano, mas o professor disse
#   • [45,349]: que as aulas são caras, e tenho de esperar.
# Original PT-BR sentences:
#   • [45,348]: Gosto de tocar piano, mas nosso professor disse
#   • [45,349]: que as aulas são caras, e tenho que esperar.
# Merged PT-PT version:
#   ▶ Gosto de tocar piano, mas o professor disse que as aulas são caras, e tenho de esperar.
# Merged PT-BR version:
#   ▶ Gosto de tocar piano, mas nosso professor disse que as aulas são caras, e tenho que esperar.
#
# --- Merge group #55 (rows [47640, 47641]) ---
# Original PT-PT sentences:
#   • [45,1157]: Bem-vindos à exposição de carros rétro deste ano,
#   • [45,1158]: o ponto de encontro dos entusiastas de carros antigos com alma.
# Original PT-BR sentences:
#   • [45,1157]: Bem-vindos à exibição de carros antigos deste ano,
#   • [45,1158]: o ponto de encontro dos entusiastas de automóveis antigos com alma.
# Merged PT-PT version:
#   ▶ Bem-vindos à exposição de carros rétro deste ano, o ponto de encontro dos entusiastas de carros antigos com alma.
# Merged PT-BR version:
#   ▶ Bem-vindos à exibição de carros antigos deste ano, o ponto de encontro dos entusiastas de automóveis antigos com alma.
#
# --- Merge group #56 (rows [47642, 47643]) ---
# Original PT-PT sentences:
#   • [45,1159]: Teremos uma corrida de rali
#   • [45,1160]: com os veículos mais bonitos do século passado.
# Original PT-BR sentences:
#   • [45,1159]: Teremos uma corrida de rali
#   • [45,1160]: com os veículos mais bonitos do século passado.
# Merged PT-PT version:
#   ▶ Teremos uma corrida de rali com os veículos mais bonitos do século passado.
# Merged PT-BR version:
#   ▶ Teremos uma corrida de rali com os veículos mais bonitos do século passado.
#
# --- Merge group #57 (rows [47693, 47694]) ---
# Original PT-PT sentences:
#   • [45,1210]: É uma viagem sentimental ao tempo
#   • [45,1211]: em que a palavra "beleza" era associada a veículos motorizados.
# Original PT-BR sentences:
#   • [45,1210]: É uma viagem sentimental pela história
#   • [45,1211]: quando a palavra "beleza" estava ligada aos veículos motorizados.
# Merged PT-PT version:
#   ▶ É uma viagem sentimental ao tempo em que a palavra "beleza" era associada a veículos motorizados.
# Merged PT-BR version:
#   ▶ É uma viagem sentimental pela história quando a palavra "beleza" estava ligada aos veículos motorizados.
#
# --- Merge group #58 (rows [48243, 48244]) ---
# Original PT-PT sentences:
#   • [46,396]: e Justine Roy, de 14 anos,
#   • [46,397]: foram encontradas ao lado dela no quintal da anterior casa de Ludovic Chevalier,
# Original PT-BR sentences:
#   • [46,396]: e Justine Roy, de 14 anos,
#   • [46,397]: estavam ao lado dela, no antigo quintal de Ludovic Chevalier,
# Merged PT-PT version:
#   ▶ e Justine Roy, de 14 anos, foram encontradas ao lado dela no quintal da anterior casa de Ludovic Chevalier,
# Merged PT-BR version:
#   ▶ e Justine Roy, de 14 anos, estavam ao lado dela, no antigo quintal de Ludovic Chevalier,
#
# --- Merge group #59 (rows [48751, 48752]) ---
# Original PT-PT sentences:
#   • [46,904]: Relembro que o julgamento inicial foi cancelado a meio,
#   • [46,905]: quando novas provas fundamentais foram entregues anonimamente à polícia.
# Original PT-BR sentences:
#   • [46,904]: Vale lembrar que processo inicial foi abortado no meio do caminho
#   • [46,905]: quando novas provas de peso
# Merged PT-PT version:
#   ▶ Relembro que o julgamento inicial foi cancelado a meio, quando novas provas fundamentais foram entregues anonimamente à polícia.
# Merged PT-BR version:
#   ▶ Vale lembrar que processo inicial foi abortado no meio do caminho quando novas provas de peso
#
# --- Merge group #60 (rows [48913, 48914]) ---
# Original PT-PT sentences:
#   • [47,141]: Hirayama,
#   • [47,142]: acho que não tenho hipóteses com a Aya. Talvez 2 em 10 possíveis.
# Original PT-BR sentences:
#   • [47,141]: Hirayama,
#   • [47,142]: acho que não tenho chance com a Aya. Talvez 2 em 10 possíveis.
# Merged PT-PT version:
#   ▶ Hirayama, acho que não tenho hipóteses com a Aya. Talvez 2 em 10 possíveis.
# Merged PT-BR version:
#   ▶ Hirayama, acho que não tenho chance com a Aya. Talvez 2 em 10 possíveis.
#
# --- Merge group #61 (rows [49247, 49248, 49249, 49250]) ---
# Original PT-PT sentences:
#   • [48,2]: Recorde-se que Hillary Clinton, a secretária de Estado,
#   • [48,3]: revelou recentemente que as cartas de Jim Comey
#   • [48,4]: e o que ele disse, foram uma das razões
#   • [48,5]: por que ela perdeu a eleição.
# Original PT-BR sentences:
#   • [48,2]: Lembrando que Hillary Clinton, a secretária de Clinton,
#   • [48,3]: revelou recentemente que as cartas de Jim Comey
#   • [48,4]: e o que ele disse, foram uma das razões
#   • [48,5]: de que ela perdeu a eleição.
# Merged PT-PT version:
#   ▶ Recorde-se que Hillary Clinton, a secretária de Estado, revelou recentemente que as cartas de Jim Comey e o que ele disse, foram uma das razões por que ela perdeu a eleição.
# Merged PT-BR version:
#   ▶ Lembrando que Hillary Clinton, a secretária de Clinton, revelou recentemente que as cartas de Jim Comey e o que ele disse, foram uma das razões de que ela perdeu a eleição.
#
# --- Merge group #62 (rows [49251, 49252]) ---
# Original PT-PT sentences:
#   • [48,6]: Agora estamos a dizer que ele foi despedido,
#   • [48,7]: em suma, por ter tomado essas decisões.
# Original PT-BR sentences:
#   • [48,6]: Agora estão dizendo que ele foi despedido,
#   • [48,7]: em suma, por ter tomado essas decisões.
# Merged PT-PT version:
#   ▶ Agora estamos a dizer que ele foi despedido, em suma, por ter tomado essas decisões.
# Merged PT-BR version:
#   ▶ Agora estão dizendo que ele foi despedido, em suma, por ter tomado essas decisões.
#
# --- Merge group #63 (rows [49253, 49254]) ---
# Original PT-PT sentences:
#   • [48,8]: Quero ler uma carta do presidente Trump,
#   • [48,9]: emitida há poucos momentos.
# Original PT-BR sentences:
#   • [48,8]: Quero ler uma carta do presidente Trump,
#   • [48,9]: emitida há poucos minutos.
# Merged PT-PT version:
#   ▶ Quero ler uma carta do presidente Trump, emitida há poucos momentos.
# Merged PT-BR version:
#   ▶ Quero ler uma carta do presidente Trump, emitida há poucos minutos.
#
# --- Merge group #64 (rows [50094, 50095]) ---
# Original PT-PT sentences:
#   • [48,849]: Com isso em mente,
#   • [48,850]: porque tomou a decisão de enviá-lo à mesma?
# Original PT-BR sentences:
#   • [48,849]: Com isso em mente,
#   • [48,850]: com sucesso e dados essenciais
# Merged PT-PT version:
#   ▶ Com isso em mente, porque tomou a decisão de enviá-lo à mesma?
# Merged PT-BR version:
#   ▶ Com isso em mente, com sucesso e dados essenciais
#
# --- Merge group #65 (rows [50096, 50097]) ---
# Original PT-PT sentences:
#   • [48,851]: Pareceu-me que aquilo que estávamos a usar
#   • [48,852]: já estaria comprometido.
# Original PT-BR sentences:
#   • [48,851]: Me pareceu que aquilo que estávamos usando
#   • [48,852]: já estaria comprometido.
# Merged PT-PT version:
#   ▶ Pareceu-me que aquilo que estávamos a usar já estaria comprometido.
# Merged PT-BR version:
#   ▶ Me pareceu que aquilo que estávamos usando já estaria comprometido.
#
# --- Merge group #66 (rows [50189, 50190, 50191]) ---
# Original PT-PT sentences:
#   • [48,944]: Esta chamada é pré-paga a cobrar no destino,
#   • [48,945]: de um detido na Prisão de Lincoln County
#   • [48,946]: em Lincolnton, Georgia.
# Original PT-BR sentences:
#   • [48,944]: Alô. Esta chamada é pré-paga a cobrar no destino,
#   • [48,945]: de um preso na Prisão de Lincoln County
#   • [48,946]: em Lincolnton, Georgia.
# Merged PT-PT version:
#   ▶ Esta chamada é pré-paga a cobrar no destino, de um detido na Prisão de Lincoln County em Lincolnton, Georgia.
# Merged PT-BR version:
#   ▶ Alô. Esta chamada é pré-paga a cobrar no destino, de um preso na Prisão de Lincoln County em Lincolnton, Georgia.
#
# --- Merge group #67 (rows [50194, 50195]) ---
# Original PT-PT sentences:
#   • [48,949]: Quando a mãe e o Gary chegarem a Georgia, vão buscar a Mina,
#   • [48,950]: e a Mickey vai voltar para o abrigo, mas estão seguras em casa.
# Original PT-BR sentences:
#   • [48,949]: Quando a mãe e o Gary chegarem a Georgia, vão buscar a Mina,
#   • [48,950]: e a Mickey vai voltar para o abrigo, mas estão seguras em casa.
# Merged PT-PT version:
#   ▶ Quando a mãe e o Gary chegarem a Georgia, vão buscar a Mina, e a Mickey vai voltar para o abrigo, mas estão seguras em casa.
# Merged PT-BR version:
#   ▶ Quando a mãe e o Gary chegarem a Georgia, vão buscar a Mina, e a Mickey vai voltar para o abrigo, mas estão seguras em casa.
#
# --- Merge group #68 (rows [50198, 50199]) ---
# Original PT-PT sentences:
#   • [48,953]: Pois, foi isso que, quando o FBI me estava a interrogar,
#   • [48,954]: diziam, tipo,
# Original PT-BR sentences:
#   • [48,953]: Sim, foi isso que o FBI disse quando estava me interrogando,
#   • [48,954]: diziam...
# Merged PT-PT version:
#   ▶ Pois, foi isso que, quando o FBI me estava a interrogar, diziam, tipo,
# Merged PT-BR version:
#   ▶ Sim, foi isso que o FBI disse quando estava me interrogando, diziam...
#
# --- Merge group #69 (rows [50215, 50216]) ---
# Original PT-PT sentences:
#   • [48,970]: Relembro-me sempre de agir mais como
#   • [48,971]: se tivesse feito uma coisa errada.
# Original PT-BR sentences:
#   • [48,970]: Lembro sempre de agir mais
#   • [48,971]: como se tivesse feito uma coisa errada.
# Merged PT-PT version:
#   ▶ Relembro-me sempre de agir mais como se tivesse feito uma coisa errada.
# Merged PT-BR version:
#   ▶ Lembro sempre de agir mais como se tivesse feito uma coisa errada.
#
# Total dual-language merge events: 69

# %%
import numpy as np

# random indices (excluding the last one so i+1 exists)
idxs = np.random.choice(df_subtitle_pairs.index[:-1], size=500, replace=False)

for i in idxs:
    a = df_subtitle_pairs.loc[i]
    b = df_subtitle_pairs.loc[i+1]
    print(f"Checking rows {i} → {i+1}")
    print(" A PT-PT:", strip_tags_str(a.text_pt).strip())
    print(" B PT-PT:", strip_tags_str(b.text_pt).strip())
    print(" would_merge:", would_merge(a.text_pt, b.text_pt, a.end_pt_ms, b.start_pt_ms))
    print("-" * 50)
# Out:
# Checking rows 52850 → 52851
#  A PT-PT: Não te queria magoar.
#  B PT-PT: Então... vou esperar um pouco e depois vou.
#  would_merge: False
# --------------------------------------------------
# Checking rows 6758 → 6759
#  A PT-PT: Bonsoir, madame, devo dizer que esperava uma pessoa mais...
#  B PT-PT: Dramática? Ridícula?
#  would_merge: False
# --------------------------------------------------
# Checking rows 46047 → 46048
#  A PT-PT: - Sim? - É espetacular.
#  B PT-PT: O que é que te posso dar?
#  would_merge: False
# --------------------------------------------------
# Checking rows 18081 → 18082
#  A PT-PT: Agora, vivemos no anexo.
#  B PT-PT: Entre.
#  would_merge: False
# --------------------------------------------------
# Checking rows 862 → 863
#  A PT-PT: Estou sempre à espera que melhore.
#  B PT-PT: Claro que estás.
#  would_merge: False
# --------------------------------------------------
# Checking rows 50274 → 50275
#  A PT-PT: É tão impossível como qualquer outro milagre."
#  B PT-PT: A ÚNICA RAPARIGA DA ORQUESTRA
#  would_merge: False
# --------------------------------------------------
# Checking rows 37566 → 37567
#  A PT-PT: Lamento que tenhas de estar aqui.
#  B PT-PT: Eu sei que não é o vosso Natal ideal.
#  would_merge: False
# --------------------------------------------------
# Checking rows 21482 → 21483
#  A PT-PT: Já pensou em ensinar?
#  B PT-PT: Não se trata da escrita.
#  would_merge: False
# --------------------------------------------------
# Checking rows 56092 → 56093
#  A PT-PT: Ordem, alto!
#  B PT-PT: Para a mãe.
#  would_merge: False
# --------------------------------------------------
# Checking rows 26693 → 26694
#  A PT-PT: Certo.
#  B PT-PT: Obrigado, meu.
#  would_merge: False
# --------------------------------------------------
# Checking rows 15976 → 15977
#  A PT-PT: ...que é apenas uma celebridade gorda.
#  B PT-PT: Que você é fraco.
#  would_merge: False
# --------------------------------------------------
# Checking rows 28531 → 28532
#  A PT-PT: Mas não disse que sim.
#  B PT-PT: Não estás a ver bem as coisas.
#  would_merge: False
# --------------------------------------------------
# Checking rows 16860 → 16861
#  A PT-PT: Claire, isso é verdade?
#  B PT-PT: Claro que não. Estou a comer uma barra de cereais a uns 8 metros de ti e tu estás a entrar em pânico.
#  would_merge: False
# --------------------------------------------------
# Checking rows 3431 → 3432
#  A PT-PT: - Sim. Ótimo. - Ótimo.
#  B PT-PT: - Percebeste? - Uh-huh.
#  would_merge: False
# --------------------------------------------------
# Checking rows 33129 → 33130
#  A PT-PT: Ou, quanto tempo é necessário para aprender?
#  B PT-PT: São precisos milhares de anos para que uma pessoa insignificante pratique
#  would_merge: False
# --------------------------------------------------
# Checking rows 37141 → 37142
#  A PT-PT: Estamos todos a morrer.
#  B PT-PT: Como podem estar tão calmos?
#  would_merge: False
# --------------------------------------------------
# Checking rows 3614 → 3615
#  A PT-PT: Mas eu não acho que tu sabe do que está a falar porque não és de cá.
#  B PT-PT: - Acho que precisas precisa do Josh aqui para o fazer sentir melhor sobre a sua vida.
#  would_merge: False
# --------------------------------------------------
# Checking rows 17301 → 17302
#  A PT-PT: Mas sabem que eu não sou o assassino.
#  B PT-PT: A Shannon disse isso.
#  would_merge: False
# --------------------------------------------------
# Checking rows 44190 → 44191
#  A PT-PT: Vamos fazer um brinde.
#  B PT-PT: Mister, mister...
#  would_merge: False
# --------------------------------------------------
# Checking rows 7291 → 7292
#  A PT-PT: Não a escutei.
#  B PT-PT: Quando ela estava a enlouquecer, culpei o desgosto amoroso.
#  would_merge: False
# --------------------------------------------------
# Checking rows 15890 → 15891
#  A PT-PT: É um aglomerado invisível de frequências e vibrações que, quando bem feito, contagia a alma do ouvinte com uma baita emoção legal.
#  B PT-PT: É o poder de mudar os sentimentos de uma pessoa meus bebezinhos lindos.
#  would_merge: False
# --------------------------------------------------
# Checking rows 32376 → 32377
#  A PT-PT: Quá!
#  B PT-PT: Muito bem. Outra vez.
#  would_merge: False
# --------------------------------------------------
# Checking rows 52421 → 52422
#  A PT-PT: Não, ninguém.
#  B PT-PT: Não tenho tempo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 10348 → 10349
#  A PT-PT: - Ele estava aqui? - Baixou!
#  B PT-PT: Deveriam estar lá.
#  would_merge: False
# --------------------------------------------------
# Checking rows 22896 → 22897
#  A PT-PT: Eles vêm para o encontro de atletismo?
#  B PT-PT: Arranjem um quarto, vocês os dois.
#  would_merge: False
# --------------------------------------------------
# Checking rows 37486 → 37487
#  A PT-PT: Eu guardo para mim.
#  B PT-PT: O que é isto?
#  would_merge: False
# --------------------------------------------------
# Checking rows 47287 → 47288
#  A PT-PT: Costumavas fazê-lo. Não te lembras de como é?
#  B PT-PT: Wiesiek, passa-me a luz.
#  would_merge: False
# --------------------------------------------------
# Checking rows 6453 → 6454
#  A PT-PT: ... as respostas às coisas.
#  B PT-PT: Ooh. Incrível.
#  would_merge: False
# --------------------------------------------------
# Checking rows 53368 → 53369
#  A PT-PT: Vou para a cave.
#  B PT-PT: Se alguém perguntar por mim, fui para casa constipado, sim?
#  would_merge: False
# --------------------------------------------------
# Checking rows 7599 → 7600
#  A PT-PT: Não acabámos de o interrogar.
#  B PT-PT: Ia revelar alguma mentira que ele contou e provavelmente acusá-lo de apoiar secretamente Vichy.
#  would_merge: False
# --------------------------------------------------
# Checking rows 11390 → 11391
#  A PT-PT: Sabes que raio de hora é é? É o raio do fim do tempo!
#  B PT-PT: Perigosos bioterroristas reivindicaram responsabilidade pelo atual ataque à ataque à Galeria de Arte Maddox.
#  would_merge: False
# --------------------------------------------------
# Checking rows 53176 → 53177
#  A PT-PT: Jean-Jacques, deixei 10 mensagens.
#  B PT-PT: Diz-me onde estás e eu vou buscar-te.
#  would_merge: False
# --------------------------------------------------
# Checking rows 9489 → 9490
#  A PT-PT: Chorão e de focinho comprido como o Calimero?
#  B PT-PT: O quê?
#  would_merge: False
# --------------------------------------------------
# Checking rows 44018 → 44019
#  A PT-PT: Arthur! O que é que fizeste?
#  B PT-PT: Raios partam!
#  would_merge: False
# --------------------------------------------------
# Checking rows 26117 → 26118
#  A PT-PT: Baby, isso só dificultará a próxima vez.
#  B PT-PT: Tenho que fazer outro filme.
#  would_merge: False
# --------------------------------------------------
# Checking rows 24669 → 24670
#  A PT-PT: é ter o pior passaporte do mundo.
#  B PT-PT: O ISIS veio.
#  would_merge: False
# --------------------------------------------------
# Checking rows 32806 → 32807
#  A PT-PT: Durante todo o dia só sei caçar lobos e cães
#  B PT-PT: veste a tua armadura
#  would_merge: False
# --------------------------------------------------
# Checking rows 13486 → 13487
#  A PT-PT: Como é que ele descreveu? Ele disse…
#  B PT-PT: Então?
#  would_merge: False
# --------------------------------------------------
# Checking rows 27894 → 27895
#  A PT-PT: Está tudo bem.
#  B PT-PT: Não estou chateado.
#  would_merge: False
# --------------------------------------------------
# Checking rows 58892 → 58893
#  A PT-PT: Tona perguntou por você umas quatro vezes, Nuri. Venha.
#  B PT-PT: Venha um pouquinho.
#  would_merge: False
# --------------------------------------------------
# Checking rows 13755 → 13756
#  A PT-PT: Certo? Mas seguidos.
#  B PT-PT: Senão, não conta.
#  would_merge: False
# --------------------------------------------------
# Checking rows 48298 → 48299
#  A PT-PT: Sim, comi qualquer coisa.
#  B PT-PT: Oferecem comida num abrigo aqui perto, e não é má.
#  would_merge: False
# --------------------------------------------------
# Checking rows 30768 → 30769
#  A PT-PT: Assim, não! Dêem-me isso.
#  B PT-PT: - Estou cheia de sede. - Tara.
#  would_merge: False
# --------------------------------------------------
# Checking rows 6335 → 6336
#  A PT-PT: -Porque é que a tua mão na tua cara assim?
#  B PT-PT: É brincalhão?
#  would_merge: False
# --------------------------------------------------
# Checking rows 40014 → 40015
#  A PT-PT: Confia em mim.
#  B PT-PT: Está bem.
#  would_merge: False
# --------------------------------------------------
# Checking rows 29566 → 29567
#  A PT-PT: That's ass, I'm sorry.
#  B PT-PT: Which one are you guys at?
#  would_merge: False
# --------------------------------------------------
# Checking rows 53861 → 53862
#  A PT-PT: Porque quando a bondade te pode tirar a vida,
#  B PT-PT: torna-se um milagre.
#  would_merge: False
# --------------------------------------------------
# Checking rows 38449 → 38450
#  A PT-PT: Sim. Tolamente.
#  B PT-PT: Por favor, não aprendas tão rapidamente como a tua mãe porque quero ser capaz de ensinar-vos alguma coisa.
#  would_merge: False
# --------------------------------------------------
# Checking rows 28207 → 28208
#  A PT-PT: Já não temos idade para birras, pois não, Vanessa?
#  B PT-PT: Não estou a brincar, pai.
#  would_merge: False
# --------------------------------------------------
# Checking rows 11385 → 11386
#  A PT-PT: Oh, isso era sarcasmo. I...
#  B PT-PT: Oh, por amor de Deus!
#  would_merge: False
# --------------------------------------------------
# Checking rows 9459 → 9460
#  A PT-PT: Desculpe, eu não queria ofendê-lo. Era para ser claro.
#  B PT-PT: Um acordo direto...
#  would_merge: False
# --------------------------------------------------
# Checking rows 50420 → 50421
#  A PT-PT: - Queres ver o meu primeiro álbum? - Sim.
#  B PT-PT: Este é o pai, esta é a mãe e esta sou eu.
#  would_merge: False
# --------------------------------------------------
# Checking rows 12901 → 12902
#  A PT-PT: Olha, quero dizer, daquela vez que rasgaste um tendão no teu cotovelo três semanas de férias, sem fazer perguntas, certo?
#  B PT-PT: Tenho clientes a queixarem-se de si.
#  would_merge: False
# --------------------------------------------------
# Checking rows 58754 → 58755
#  A PT-PT: Conhecendo ela, sempre é esquerda.
#  B PT-PT: Esquerda.
#  would_merge: False
# --------------------------------------------------
# Checking rows 47777 → 47778
#  A PT-PT: - Olha. - Podemos roubar os sonhos às crianças?
#  B PT-PT: A honestidade vende.
#  would_merge: False
# --------------------------------------------------
# Checking rows 7421 → 7422
#  A PT-PT: "St. Louis, Missouri."
#  B PT-PT: Bastava dizer essas palavras para a minha irmã adormecer.
#  would_merge: False
# --------------------------------------------------
# Checking rows 51412 → 51413
#  A PT-PT: - Sim, sabes que mais, Frank? Eu não quero ouvir isso.
#  B PT-PT: Este projeto de lei vai ser aprovado com ou sem si.
#  would_merge: False
# --------------------------------------------------
# Checking rows 30458 → 30459
#  A PT-PT: Mmhmm.
#  B PT-PT: You got a girlfriend?
#  would_merge: False
# --------------------------------------------------
# Checking rows 914 → 915
#  A PT-PT: Quase parece coisa do destino.
#  B PT-PT: Vamos fazer isto.
#  would_merge: False
# --------------------------------------------------
# Checking rows 50982 → 50983
#  A PT-PT: - Eu não queria dizer isto, mas deve ser mencionado.
#  B PT-PT: Desde que estamos aqui fora com toda a radiação, provavelmente és estéril de qualquer forma.
#  would_merge: False
# --------------------------------------------------
# Checking rows 27218 → 27219
#  A PT-PT: Engole.
#  B PT-PT: Engole!
#  would_merge: False
# --------------------------------------------------
# Checking rows 16906 → 16907
#  A PT-PT: Ele vai buscar as algemas e eu digo,
#  B PT-PT: "Esqueci-me de mencionar,
#  would_merge: False
# --------------------------------------------------
# Checking rows 49243 → 49244
#  A PT-PT: "Komorebi"
#  B PT-PT: É a palavra japonesa para o brilhantar de luz e sombras que é criado por folhas a esvoaçar ao vento.
#  would_merge: False
# --------------------------------------------------
# Checking rows 29074 → 29075
#  A PT-PT: Não, não.
#  B PT-PT: Mudou tudo. Agora está tudo diferente.
#  would_merge: False
# --------------------------------------------------
# Checking rows 40349 → 40350
#  A PT-PT: Tem cuidado.
#  B PT-PT: Está bem?
#  would_merge: False
# --------------------------------------------------
# Checking rows 48224 → 48225
#  A PT-PT: e sobretudo às que estão todos os dias na sala de audiências.
#  B PT-PT: Nós vemos-vos, e vocês são obscenas!
#  would_merge: False
# --------------------------------------------------
# Checking rows 8202 → 8203
#  A PT-PT: És um escritor, Edward?
#  B PT-PT: Sim, sou de facto. Escrevo romances.
#  would_merge: False
# --------------------------------------------------
# Checking rows 29592 → 29593
#  A PT-PT: - Stop! - You know what I'm talking about!
#  B PT-PT: Okay.
#  would_merge: False
# --------------------------------------------------
# Checking rows 38217 → 38218
#  A PT-PT: Por favor, despachem-se.
#  B PT-PT: As raparigas de Blackvale olham cuidam umas das outras.
#  would_merge: False
# --------------------------------------------------
# Checking rows 38374 → 38375
#  A PT-PT: Esperei tanto tempo.
#  B PT-PT: Estou tão perto.
#  would_merge: False
# --------------------------------------------------
# Checking rows 35201 → 35202
#  A PT-PT: Mais um ano, mais uma leva de tresloucados do 5.º ano.
#  B PT-PT: Kabir, Anthony, bem-vindos.
#  would_merge: False
# --------------------------------------------------
# Checking rows 51079 → 51080
#  A PT-PT: E eu não lhe vou dizer.
#  B PT-PT: Está bem, eu não lhe vou dizer.
#  would_merge: False
# --------------------------------------------------
# Checking rows 4783 → 4784
#  A PT-PT: Está bem, pode ser.
#  B PT-PT: E já agora, arranjei uma máquina de sumos industrial.
#  would_merge: False
# --------------------------------------------------
# Checking rows 9414 → 9415
#  A PT-PT: Apaixonei-me por ele desde o primeiro momento.
#  B PT-PT: Este peixe grande!
#  would_merge: False
# --------------------------------------------------
# Checking rows 27450 → 27451
#  A PT-PT: Vigia o teu irmão.
#  B PT-PT: Garrett.
#  would_merge: False
# --------------------------------------------------
# Checking rows 34083 → 34084
#  A PT-PT: Noa!
#  B PT-PT: Noa!
#  would_merge: False
# --------------------------------------------------
# Checking rows 47062 → 47063
#  A PT-PT: Conseguia montar um carro desses de olhos fechados num dia.
#  B PT-PT: Claro. Então, fá-lo! Mas faz bem, desta vez.
#  would_merge: False
# --------------------------------------------------
# Checking rows 8146 → 8147
#  A PT-PT: Olá, malta. Desculpem o atraso. Tive um problema com o comboio.
#  B PT-PT: -Onde é que está a Esther? -Bem...
#  would_merge: False
# --------------------------------------------------
# Checking rows 55560 → 55561
#  A PT-PT: Um momento, Shelly.
#  B PT-PT: O que estás a fazer aqui?
#  would_merge: False
# --------------------------------------------------
# Checking rows 26810 → 26811
#  A PT-PT: - Não, eu realmente não... - Está tudo bem. Senta-te.
#  B PT-PT: Devias dar descanso aos nós dos dedos depois de teres esmurrado a minha porta.
#  would_merge: False
# --------------------------------------------------
# Checking rows 26571 → 26572
#  A PT-PT: Podes ter os teus livros e a mim também.
#  B PT-PT: O Coronel está na linha!
#  would_merge: False
# --------------------------------------------------
# Checking rows 56463 → 56464
#  A PT-PT: Sabe da minha carta de paz para o seu rei?
#  B PT-PT: Não.
#  would_merge: False
# --------------------------------------------------
# Checking rows 52143 → 52144
#  A PT-PT: Ele viu-te. Disse-te para estacionares noutro sítio.
#  B PT-PT: Agora está a ver.
#  would_merge: False
# --------------------------------------------------
# Checking rows 27995 → 27996
#  A PT-PT: Podes fazer o que quiseres com a tua vida mas se voltas a trazer a Abby aqui dou-te um tiro.
#  B PT-PT: Ela parecia tão zangada.
#  would_merge: False
# --------------------------------------------------
# Checking rows 38854 → 38855
#  A PT-PT: Obrigado por terem vindo.
#  B PT-PT: Claro que sim.
#  would_merge: False
# --------------------------------------------------
# Checking rows 4816 → 4817
#  A PT-PT: -Isso é triste, vindo de ti, amigo. -Triste és tu, amigo.
#  B PT-PT: Sabes o que eu acho? Estou a tentar perceber.
#  would_merge: False
# --------------------------------------------------
# Checking rows 35284 → 35285
#  A PT-PT: Vai ter um bebé?
#  B PT-PT: De certeza? Pediu uma segunda opinião?
#  would_merge: False
# --------------------------------------------------
# Checking rows 7043 → 7044
#  A PT-PT: Soldados...
#  B PT-PT: amigos...
#  would_merge: False
# --------------------------------------------------
# Checking rows 26249 → 26250
#  A PT-PT: Tenho tentado arranjar coisas para fazer no meu...
#  B PT-PT: Tens que continuar os estudos senão o teu pai não te deixará ficar.
#  would_merge: False
# --------------------------------------------------
# Checking rows 34296 → 34297
#  A PT-PT: Adoro-te!
#  B PT-PT: Um conselho.
#  would_merge: False
# --------------------------------------------------
# Checking rows 58671 → 58672
#  A PT-PT: Desça aqui!
#  B PT-PT: Me deixem!
#  would_merge: False
# --------------------------------------------------
# Checking rows 12904 → 12905
#  A PT-PT: Não te posso ter aqui, Killian.
#  B PT-PT: O quê?
#  would_merge: False
# --------------------------------------------------
# Checking rows 11575 → 11576
#  A PT-PT: - Não, tu consegues? - Não, não me atrevo a fazê-lo.
#  B PT-PT: Qualquer pessoa que goste de trabalhar com animais pode vir aqui.
#  would_merge: False
# --------------------------------------------------
# Checking rows 19952 → 19953
#  A PT-PT: - Guarda-a. - Sim, aqui.
#  B PT-PT: - Aqui? - Aqui mesmo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 1804 → 1805
#  A PT-PT: - Parar! - Travão
#  B PT-PT: - Vamos lá, vamos lá, vamos lá
#  would_merge: False
# --------------------------------------------------
# Checking rows 46006 → 46007
#  A PT-PT: Quando as pessoas não têm ninguém, tendem a passar depressa.
#  B PT-PT: Estou a ver.
#  would_merge: False
# --------------------------------------------------
# Checking rows 39810 → 39811
#  A PT-PT: Obrigada... por cuidares de mim.
#  B PT-PT: Não posso deixar-te morrer.
#  would_merge: False
# --------------------------------------------------
# Checking rows 7021 → 7022
#  A PT-PT: Na sua enfermaria na sua mente.
#  B PT-PT: Vaga após vaga de moribundos e mortos.
#  would_merge: False
# --------------------------------------------------
# Checking rows 23993 → 23994
#  A PT-PT: Pode levar-me?
#  B PT-PT: Olá mãe.
#  would_merge: False
# --------------------------------------------------
# Checking rows 4664 → 4665
#  A PT-PT: Até cheguei a deixar um bilhete nesta mesa.
#  B PT-PT: "Tommy Joe Ballantyne foi dar um mergulho."
#  would_merge: False
# --------------------------------------------------
# Checking rows 4035 → 4036
#  A PT-PT: Fica tudo ao abandono.
#  B PT-PT: Já nem sei o que diga. Quer dizer, eu e a Mary, nós...
#  would_merge: False
# --------------------------------------------------
# Checking rows 42146 → 42147
#  A PT-PT: - Eles serão capazes de o fazer. - Greg.
#  B PT-PT: Sabes, oito horas de viagem, dividimos em duas.
#  would_merge: False
# --------------------------------------------------
# Checking rows 5291 → 5292
#  A PT-PT: - Merda!
#  B PT-PT: - Vai-te lixar.
#  would_merge: False
# --------------------------------------------------
# Checking rows 7520 → 7521
#  A PT-PT: Está tudo bem. Pai.
#  B PT-PT: Só precisa de descansar.
#  would_merge: False
# --------------------------------------------------
# Checking rows 19548 → 19549
#  A PT-PT: mas a embaixada indiana negou-nos os vistos.
#  B PT-PT: Porquê?
#  would_merge: False
# --------------------------------------------------
# Checking rows 12634 → 12635
#  A PT-PT: Oh. I...
#  B PT-PT: A minha mãe também morreu, na verdade.
#  would_merge: False
# --------------------------------------------------
# Checking rows 39522 → 39523
#  A PT-PT: Não preciso da tua ajuda, Sejanus.
#  B PT-PT: Que os Tributos são seres humanos, tal como nós.
#  would_merge: False
# --------------------------------------------------
# Checking rows 19209 → 19210
#  A PT-PT: Balli?
#  B PT-PT: Treinador.
#  would_merge: False
# --------------------------------------------------
# Checking rows 50896 → 50897
#  A PT-PT: - Eu vi-o, tipo, mil vezes.
#  B PT-PT: - Bem, vamos ver 1.001. Funciona.
#  would_merge: False
# --------------------------------------------------
# Checking rows 50529 → 50530
#  A PT-PT: Queres tornar-me mais importante e isso deixa-me desconfortável.
#  B PT-PT: Está bem.
#  would_merge: False
# --------------------------------------------------
# Checking rows 15942 → 15943
#  A PT-PT: Você sabe, a porra do rei, basicamente... talvez.
#  B PT-PT: O quê? Eu estou brincando.
#  would_merge: False
# --------------------------------------------------
# Checking rows 47789 → 47790
#  A PT-PT: Kazik!
#  B PT-PT: Estes são todos os concorrentes desde a primeira ronda de qualificação.
#  would_merge: False
# --------------------------------------------------
# Checking rows 4577 → 4578
#  A PT-PT: Marra!
#  B PT-PT: Deixa!
#  would_merge: False
# --------------------------------------------------
# Checking rows 46519 → 46520
#  A PT-PT: Olha para ela.
#  B PT-PT: Como te atreves a voltar bronzeada e descansada no primeiro dia de aulas?
#  would_merge: False
# --------------------------------------------------
# Checking rows 31334 → 31335
#  A PT-PT: - Esperem, como se chamam? - Gemma.
#  B PT-PT: - Gemma. - Leah.
#  would_merge: False
# --------------------------------------------------
# Checking rows 32540 → 32541
#  A PT-PT: Sim! E agora, tu e eu vamos resgatar os nossos filhos para acabarmos esta louca e maravilhosa aventura.
#  B PT-PT: E vamos ensinar-lhes que, quando estás perante uma ameaça nunca foges dela.
#  would_merge: False
# --------------------------------------------------
# Checking rows 40026 → 40027
#  A PT-PT: Posso não te ter apanhado esta noite,
#  B PT-PT: mas a tua ave canora é a próxima na minha lista.
#  would_merge: False
# --------------------------------------------------
# Checking rows 36933 → 36934
#  A PT-PT: Devias pegar no Davis e voltar para a cidade.
#  B PT-PT: E tu?
#  would_merge: False
# --------------------------------------------------
# Checking rows 49530 → 49531
#  A PT-PT: A minha pélvis não estava em rotação, por isso, separei a articulação.
#  B PT-PT: - Deve ter doído. - Pois.
#  would_merge: False
# --------------------------------------------------
# Checking rows 5815 → 5816
#  A PT-PT: -Não sabias disso?
#  B PT-PT: Sobre a produção.
#  would_merge: False
# --------------------------------------------------
# Checking rows 40762 → 40763
#  A PT-PT: Dizem que o nome dele é Spruce.
#  B PT-PT: Passei três anos a lutar pelo Capitólio durante a guerra.
#  would_merge: False
# --------------------------------------------------
# Checking rows 34366 → 34367
#  A PT-PT: Eu não tentaria.
#  B PT-PT: Estás diante do vice-capitão júnior do Clube de Boxe de Wigan.
#  would_merge: False
# --------------------------------------------------
# Checking rows 5029 → 5030
#  A PT-PT: Sabem como é, vidas ocupadas e tudo mais.
#  B PT-PT: Tão cedo não consegues vender este sítio.
#  would_merge: False
# --------------------------------------------------
# Checking rows 36963 → 36964
#  A PT-PT: O que são eles?
#  B PT-PT: Biodrones.
#  would_merge: False
# --------------------------------------------------
# Checking rows 9106 → 9107
#  A PT-PT: Deixem-me ir. Não!
#  B PT-PT: Não faz mal. Eu tenho-o. Não, a sério.
#  would_merge: False
# --------------------------------------------------
# Checking rows 49074 → 49075
#  A PT-PT: Aqui tem.
#  B PT-PT: Obrigado. Devo ir por ali?
#  would_merge: False
# --------------------------------------------------
# Checking rows 42903 → 42904
#  A PT-PT: Mas eu vou dormir aqui?
#  B PT-PT: Sim, mas elas são...
#  would_merge: False
# --------------------------------------------------
# Checking rows 38177 → 38178
#  A PT-PT: Achas que ela se importa uma merda para ti?
#  B PT-PT: Foda-se.
#  would_merge: False
# --------------------------------------------------
# Checking rows 11660 → 11661
#  A PT-PT: Não sei.
#  B PT-PT: Fui ver os cavalos com o Juh.
#  would_merge: False
# --------------------------------------------------
# Checking rows 15999 → 16000
#  A PT-PT: Acho que dessa vez, não.
#  B PT-PT: E, se eu não fizer isso, o mundo vai acabar.
#  would_merge: False
# --------------------------------------------------
# Checking rows 17877 → 17878
#  A PT-PT: Hoje, estávamos desesperados por ir para a Índia.
#  B PT-PT: Há vinte e cinco anos atrás, estávamos tão desesperados para chegar a Londres.
#  would_merge: False
# --------------------------------------------------
# Checking rows 52663 → 52664
#  A PT-PT: Estás com ótimo aspeto. Não percebo, tens tudo.
#  B PT-PT: Seria bom para o teu processo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 3163 → 3164
#  A PT-PT: - Sim? - Sim.
#  B PT-PT: - Qual é o tamanho do vosso apartamento?
#  would_merge: False
# --------------------------------------------------
# Checking rows 44524 → 44525
#  A PT-PT: Pensei em pedir uma opinião profissional.
#  B PT-PT: Está a cometer um erro.
#  would_merge: False
# --------------------------------------------------
# Checking rows 42038 → 42039
#  A PT-PT: Sim, está a tentar lutar contra, mas querem alocar fundos para instituições estatais de maior dimensão.
#  B PT-PT: Estes rapazes ficarão perdidos numa instituição estatal.
#  would_merge: False
# --------------------------------------------------
# Checking rows 23576 → 23577
#  A PT-PT: Estão a ouvir-me? Charlie? Estás a ouvir-me?
#  B PT-PT: Ok, Carol. Tens de ser mesmo assustadora, está bem?
#  would_merge: False
# --------------------------------------------------
# Checking rows 55114 → 55115
#  A PT-PT: A minha filha tem estado a ajudar a tomar conta de mim.
#  B PT-PT: Tenho alguns meses, acho eu.
#  would_merge: False
# --------------------------------------------------
# Checking rows 13685 → 13686
#  A PT-PT: Será rápido.
#  B PT-PT: Eficiente.
#  would_merge: False
# --------------------------------------------------
# Checking rows 10751 → 10752
#  A PT-PT: Oh, Deus, não.
#  B PT-PT: Whoo! Um, dois, três! Whoo!
#  would_merge: False
# --------------------------------------------------
# Checking rows 39435 → 39436
#  A PT-PT: Vão matá-los a eles, se lhe fizerem mal.
#  B PT-PT: E depois a vocês.
#  would_merge: False
# --------------------------------------------------
# Checking rows 45932 → 45933
#  A PT-PT: Aqui está.
#  B PT-PT: - Como é que está o paciente? - Está bem.
#  would_merge: False
# --------------------------------------------------
# Checking rows 10625 → 10626
#  A PT-PT: - Dou-te metade. - O quê?
#  B PT-PT: - É pegar ou largar. - Isso é um insulto.
#  would_merge: False
# --------------------------------------------------
# Checking rows 13501 → 13502
#  A PT-PT: Vamos ter contigo.
#  B PT-PT: Não há muito tempo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 16597 → 16598
#  A PT-PT: Maldita porta.
#  B PT-PT: Esta porta teimosa.
#  would_merge: False
# --------------------------------------------------
# Checking rows 38239 → 38240
#  A PT-PT: Muito bem, ouçam o Jude, porque ele é o demónio.
#  B PT-PT: Tinhas razão, Jude...
#  would_merge: False
# --------------------------------------------------
# Checking rows 51037 → 51038
#  A PT-PT: Eu tentei isso.
#  B PT-PT: Não.
#  would_merge: False
# --------------------------------------------------
# Checking rows 26238 → 26239
#  A PT-PT: - Olá. - Olá.
#  B PT-PT: Olá.
#  would_merge: False
# --------------------------------------------------
# Checking rows 38770 → 38771
#  A PT-PT: Obrigado.
#  B PT-PT: Vamos lá!
#  would_merge: False
# --------------------------------------------------
# Checking rows 31912 → 31913
#  A PT-PT: Mas pronto. Vocês devem estar exaustos.
#  B PT-PT: Aqui está a vossa cama.
#  would_merge: False
# --------------------------------------------------
# Checking rows 12834 → 12835
#  A PT-PT: Vamos lá, pá.
#  B PT-PT: É de cá?
#  would_merge: False
# --------------------------------------------------
# Checking rows 9653 → 9654
#  A PT-PT: Cosimo, precisamos de obter o cortadores e maquinaria de Telavive.
#  B PT-PT: A maquinaria? Eu gastei muito dinheiro nisto.
#  would_merge: False
# --------------------------------------------------
# Checking rows 3183 → 3184
#  A PT-PT: - Hmm. Deixa-me experimentar.
#  B PT-PT: - Bem, quero dizer, eu faço-o porque sou viciado, está bem?
#  would_merge: False
# --------------------------------------------------
# Checking rows 43059 → 43060
#  A PT-PT: Tu sabes disso.
#  B PT-PT: Esta é a nossa casa.
#  would_merge: False
# --------------------------------------------------
# Checking rows 31034 → 31035
#  A PT-PT: Tara!
#  B PT-PT: Sim, Mália! Sim!
#  would_merge: False
# --------------------------------------------------
# Checking rows 22831 → 22832
#  A PT-PT: Eu não acho que amanhã é um bom dia para ir espalhar estas cinzas.
#  B PT-PT: - Não, isso é, é importante que o façamos.
#  would_merge: False
# --------------------------------------------------
# Checking rows 35018 → 35019
#  A PT-PT: Vieste aqui para chorar?
#  B PT-PT: Vê, eu estive no funeral.
#  would_merge: False
# --------------------------------------------------
# Checking rows 50147 → 50148
#  A PT-PT: atrás do condutor.
#  B PT-PT: Tive de enviar um monte de formulários em dezembro passado portanto, está no meu carro desde dezembro.
#  would_merge: False
# --------------------------------------------------
# Checking rows 5231 → 5232
#  A PT-PT: Se eu puder fazer alguma coisa, basta dizer, basta pedir.
#  B PT-PT: Muito obrigada. Obrigada por tudo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 57166 → 57167
#  A PT-PT: - Eu tenho um segredo.
#  B PT-PT: Não penses que o que Estou a fazer é fácil.
#  would_merge: False
# --------------------------------------------------
# Checking rows 52572 → 52573
#  A PT-PT: É algo que surge repetidamente nas reuniões com a Sra. Henry.
#  B PT-PT: Eu nunca disse isso.
#  would_merge: False
# --------------------------------------------------
# Checking rows 43319 → 43320
#  A PT-PT: Algum problema, contacta-me ou ao Gerhard diretamente.
#  B PT-PT: Obrigado.
#  would_merge: False
# --------------------------------------------------
# Checking rows 57226 → 57227
#  A PT-PT: - Que bonito.
#  B PT-PT: Eu, eu sou o Daniele.
#  would_merge: False
# --------------------------------------------------
# Checking rows 57089 → 57090
#  A PT-PT: Preparar para contra-atacar!
#  B PT-PT: Avancem, homens. Apoio total.
#  would_merge: False
# --------------------------------------------------
# Checking rows 20390 → 20391
#  A PT-PT: - 20 anos.
#  B PT-PT: O amor vence tudo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 22785 → 22786
#  A PT-PT: - Está bem.
#  B PT-PT: - Oh, querida, está tudo bem.
#  would_merge: False
# --------------------------------------------------
# Checking rows 48818 → 48819
#  A PT-PT: Ouve, respeita sempre a equipa ou a religião dos outros. De acordo?
#  B PT-PT: Agora, vá. Senta aí.
#  would_merge: False
# --------------------------------------------------
# Checking rows 14888 → 14889
#  A PT-PT: Devem ter sofrido imenso. Estávamos preocupados.
#  B PT-PT: Senta-te, querida. Come.
#  would_merge: False
# --------------------------------------------------
# Checking rows 30193 → 30194
#  A PT-PT: I'm going down.
#  B PT-PT: You're going easy on him.
#  would_merge: False
# --------------------------------------------------
# Checking rows 28616 → 28617
#  A PT-PT: Boa noite, minhas senhoras.
#  B PT-PT: Mas depois apareceu o Davy Scherman, da revista Life.
#  would_merge: False
# --------------------------------------------------
# Checking rows 27455 → 27456
#  A PT-PT: Ainda nem são 10 horas e mal mantém os olhos abertos.
#  B PT-PT: E confiam a este degenerado o bem-estar de uma criança doente mental.
#  would_merge: False
# --------------------------------------------------
# Checking rows 43386 → 43387
#  A PT-PT: Senhor?
#  B PT-PT: Senhor?
#  would_merge: False
# --------------------------------------------------
# Checking rows 18265 → 18266
#  A PT-PT: Shakeel também concordou.
#  B PT-PT: Quem é o Shakeel agora?
#  would_merge: False
# --------------------------------------------------
# Checking rows 2991 → 2992
#  A PT-PT: - Eu não sabia que que estavas noivo.
#  B PT-PT: - Sim. - Parabéns.
#  would_merge: False
# --------------------------------------------------
# Checking rows 30135 → 30136
#  A PT-PT: Okay, word.
#  B PT-PT: See what happens.
#  would_merge: False
# --------------------------------------------------
# Checking rows 14066 → 14067
#  A PT-PT: Não, ainda não.
#  B PT-PT: Precisas de ajuda?
#  would_merge: False
# --------------------------------------------------
# Checking rows 502 → 503
#  A PT-PT: Não te via há anos!
#  B PT-PT: E continua sem ver pois eu sou Bella Baxter senhora estranha com penas.
#  would_merge: False
# --------------------------------------------------
# Checking rows 33659 → 33660
#  A PT-PT: Estou aqui. Por favor!
#  B PT-PT: Amarra-os!
#  would_merge: False
# --------------------------------------------------
# Checking rows 53071 → 53072
#  A PT-PT: São 6, já que estou a ver a dobrar.
#  B PT-PT: Tony!
#  would_merge: False
# --------------------------------------------------
# Checking rows 28216 → 28217
#  A PT-PT: Ambos sabemos que não vais usar uma...
#  B PT-PT: Mike.
#  would_merge: False
# --------------------------------------------------
# Checking rows 47118 → 47119
#  A PT-PT: Sou um homem de ação.
#  B PT-PT: Bem, isso surpreende-me muito, Wiesław.
#  would_merge: False
# --------------------------------------------------
# Checking rows 7995 → 7996
#  A PT-PT: Se o ruído do motor for demasiado forte, tente ouvir música...
#  B PT-PT: Que se lixe isto, Coco. Eu não posso fazer isso.
#  would_merge: False
# --------------------------------------------------
# Checking rows 9229 → 9230
#  A PT-PT: - Ele ficou excitado! - Bebe!
#  B PT-PT: - Desculpa... - Um brinde!
#  would_merge: False
# --------------------------------------------------
# Checking rows 37910 → 37911
#  A PT-PT: Temos de sair daqui.
#  B PT-PT: Eles vão matar-nos se não o fizermos.
#  would_merge: False
# --------------------------------------------------
# Checking rows 16292 → 16293
#  A PT-PT: Ele construiu o maior supercondutor do mundo
#  B PT-PT: para poder trazer a estrela para mais perto da Terra...
#  would_merge: True
# --------------------------------------------------
# Checking rows 24597 → 24598
#  A PT-PT: São as armas de Lukashenko. Se deixarmos agora, milhares mais os seguirão.
#  B PT-PT: Eu levo isso.
#  would_merge: False
# --------------------------------------------------
# Checking rows 22597 → 22598
#  A PT-PT: - Na verdade, o Lucas e eu vamos fazer uma viagem.
#  B PT-PT: Eu sei.
#  would_merge: False
# --------------------------------------------------
# Checking rows 52324 → 52325
#  A PT-PT: Há quanto tempo é que andam nestes...
#  B PT-PT: procedimentos?
#  would_merge: False
# --------------------------------------------------
# Checking rows 54667 → 54668
#  A PT-PT: Gate City GCO esta noite.
#  B PT-PT: Primeira vez na igreja desde...
#  would_merge: False
# --------------------------------------------------
# Checking rows 7619 → 7620
#  A PT-PT: Aqui.
#  B PT-PT: Este palazzo
#  would_merge: False
# --------------------------------------------------
# Checking rows 29670 → 29671
#  A PT-PT: Yeah, um...
#  B PT-PT: You ever tried using paprika?
#  would_merge: False
# --------------------------------------------------
# Checking rows 11677 → 11678
#  A PT-PT: Não posso ver os meus pais e estou preso aqui. O que é que eu fiz de errado?
#  B PT-PT: Cabra estúpida.
#  would_merge: False
# --------------------------------------------------
# Checking rows 5512 → 5513
#  A PT-PT: -Então, como eu disse, a empresa pediu-me para fazer esta coisa sobre a cabeça como que para promover o espetáculo.
#  B PT-PT: -Eu percebo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 20433 → 20434
#  A PT-PT: Não naquela altura.
#  B PT-PT: Ele disse que era suposto ser uma entrada e saída rápida e fácil.
#  would_merge: False
# --------------------------------------------------
# Checking rows 18027 → 18028
#  A PT-PT: Porque é que o Dumb e o Dumber estão aqui?
#  B PT-PT: Eles estão aqui para mim. Temos de ir às 2:00 p.m.
#  would_merge: False
# --------------------------------------------------
# Checking rows 18096 → 18097
#  A PT-PT: Desistiu das selecções para os Jogos Asiáticos
#  B PT-PT: para o levar para o hospital.
#  would_merge: False
# --------------------------------------------------
# Checking rows 38897 → 38898
#  A PT-PT: Escondido...
#  B PT-PT: Está a esconder-se de mim...
#  would_merge: False
# --------------------------------------------------
# Checking rows 20055 → 20056
#  A PT-PT: Diz-me apenas que estás bem.
#  B PT-PT: Está bem?
#  would_merge: False
# --------------------------------------------------
# Checking rows 51437 → 51438
#  A PT-PT: O Adam encontrou-a. - Ótimo.
#  B PT-PT: - O que é que pensa sobre fazer uma viagem?
#  would_merge: False
# --------------------------------------------------
# Checking rows 58222 → 58223
#  A PT-PT: - Pronto. - Pega.
#  B PT-PT: Obrigada.
#  would_merge: False
# --------------------------------------------------
# Checking rows 57560 → 57561
#  A PT-PT: antes do nascer do sol amanhã de manhã porque se não o fizeres, vais vais ficar preso deste lado com todas as escolhas que fizeste para sempre.
#  B PT-PT: Por isso, bebe.
#  would_merge: False
# --------------------------------------------------
# Checking rows 34070 → 34071
#  A PT-PT: O quê?
#  B PT-PT: Não!
#  would_merge: False
# --------------------------------------------------
# Checking rows 13609 → 13610
#  A PT-PT: Só quero dizer,
#  B PT-PT: adoro-vos.
#  would_merge: False
# --------------------------------------------------
# Checking rows 42133 → 42134
#  A PT-PT: Sim. Bem, significa que está a funcionar.
#  B PT-PT: Avança. Va lá.
#  would_merge: False
# --------------------------------------------------
# Checking rows 34234 → 34235
#  A PT-PT: Pode retirar esta bagagem lunática?
#  B PT-PT: Peço desculpa, Sr. Erskine. Qual parece ser o problema?
#  would_merge: False
# --------------------------------------------------
# Checking rows 6582 → 6583
#  A PT-PT: Ela disse que diria isso.
#  B PT-PT: Portanto, devo dar-lhe isto.
#  would_merge: False
# --------------------------------------------------
# Checking rows 5475 → 5476
#  A PT-PT: Tal mãe, tal filha.
#  B PT-PT: Muito bem, vamos continuar.
#  would_merge: False
# --------------------------------------------------
# Checking rows 3998 → 3999
#  A PT-PT: Eu dou-lhe o sensível... Vendeu-a ou não?
#  B PT-PT: Foi vendida num leilão online há umas 2 semanas esta e mais três lá em cima.
#  would_merge: False
# --------------------------------------------------
# Checking rows 16162 → 16163
#  A PT-PT: Aconteceu como a profecia disse. O Metalocalipse.
#  B PT-PT: Alguém viu Murderface?
#  would_merge: False
# --------------------------------------------------
# Checking rows 14377 → 14378
#  A PT-PT: Como podes dizer-me
#  B PT-PT: essas coisas horríveis?
#  would_merge: False
# --------------------------------------------------
# Checking rows 32722 → 32723
#  A PT-PT: Quem é que o matou?
#  B PT-PT: Traidor de Ho.
#  would_merge: False
# --------------------------------------------------
# Checking rows 1841 → 1842
#  A PT-PT: - Terminámos a primeira ronda
#  B PT-PT: - Vai ver o segundo, va.
#  would_merge: False
# --------------------------------------------------
# Checking rows 26609 → 26610
#  A PT-PT: Onde está o brilho dos teus olhos?
#  B PT-PT: Estou com medo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 41661 → 41662
#  A PT-PT: Molengou dois dias seguidos só para te irritar.
#  B PT-PT: Ele parece-me bastante disciplinado.
#  would_merge: False
# --------------------------------------------------
# Checking rows 114 → 115
#  A PT-PT: Bella.
#  B PT-PT: Bella, acho que não devíamos estar aqui.
#  would_merge: False
# --------------------------------------------------
# Checking rows 33143 → 33144
#  A PT-PT: Vem oferecer um tesouro.
#  B PT-PT: Que tesouro?
#  would_merge: False
# --------------------------------------------------
# Checking rows 44048 → 44049
#  A PT-PT: Depois encontrámos uma casa melhor para viver.
#  B PT-PT: Acabaram-se as aulas de canto.
#  would_merge: False
# --------------------------------------------------
# Checking rows 33741 → 33742
#  A PT-PT: Foda-se! Consegues ver o exterior?
#  B PT-PT: Sim, consigo e tudo o que vejo é água.
#  would_merge: False
# --------------------------------------------------
# Checking rows 30039 → 30040
#  A PT-PT: I've got you now.
#  B PT-PT: Are you awake?
#  would_merge: False
# --------------------------------------------------
# Checking rows 34649 → 34650
#  A PT-PT: Sr. Erskine, reservei uma sala privada para si, por aqui.
#  B PT-PT: Espero que seja do seu agrado.
#  would_merge: False
# --------------------------------------------------
# Checking rows 54297 → 54298
#  A PT-PT: E é melhor fazeres bem naquela sala de aula hoje, ou ponho-te de castigo por mais uma semana, percebeste?
#  B PT-PT: Sim, senhor.
#  would_merge: False
# --------------------------------------------------
# Checking rows 52500 → 52501
#  A PT-PT: Poderia repensar as coisas.
#  B PT-PT: Se toda a gente fizesse uma 4a feira, faríamos uma rotação. Seria mais fácil.
#  would_merge: False
# --------------------------------------------------
# Checking rows 3515 → 3516
#  A PT-PT: - Sim.
#  B PT-PT: Sim, quero dizer, o sol vai vai pôr-se em breve, por isso.
#  would_merge: False
# --------------------------------------------------
# Checking rows 20956 → 20957
#  A PT-PT: - Sabes, eu...
#  B PT-PT: Não sei.
#  would_merge: False
# --------------------------------------------------
# Checking rows 6578 → 6579
#  A PT-PT: Monsieur Poirot...
#  B PT-PT: está aqui uma senhora.
#  would_merge: False
# --------------------------------------------------
# Checking rows 33056 → 33057
#  A PT-PT: Se não tiver um cartão, não pode entrar
#  B PT-PT: Ainda precisas de chá?
#  would_merge: False
# --------------------------------------------------
# Checking rows 6965 → 6966
#  A PT-PT: Quem?
#  B PT-PT: Mostra-me. Quem?
#  would_merge: False
# --------------------------------------------------
# Checking rows 51985 → 51986
#  A PT-PT: O que aconteceu foi que arrombou a porta da minha casa de banho.
#  B PT-PT: Quer que o levemos à força? Que o algememos?
#  would_merge: False
# --------------------------------------------------
# Checking rows 8216 → 8217
#  A PT-PT: Sarah?
#  B PT-PT: Mas eu... Não, desculpa.
#  would_merge: False
# --------------------------------------------------
# Checking rows 32500 → 32501
#  A PT-PT: Senti qualquer coisa.
#  B PT-PT: Não!
#  would_merge: False
# --------------------------------------------------
# Checking rows 40438 → 40439
#  A PT-PT: Ela está aqui.
#  B PT-PT: Está viva.
#  would_merge: False
# --------------------------------------------------
# Checking rows 40955 → 40956
#  A PT-PT: Devido ao uso contínuo de drogas e à violência em casa do cliente
#  B PT-PT: Não podemos aprovar a vigilância doméstica.
#  would_merge: False
# --------------------------------------------------
# Checking rows 37338 → 37339
#  A PT-PT: Bruxaria.
#  B PT-PT: O registo oficial da cidade oficial da cidade culpa o incêndio sobre um clã profano de as bruxas do demónio.
#  would_merge: False
# --------------------------------------------------
# Checking rows 6198 → 6199
#  A PT-PT: Eu acabo por ser a tua cobaia, afinal.
#  B PT-PT: -Sim, acabei de me aperceber disso precisava de ter muito mais pormenores na cabeça.
#  would_merge: False
# --------------------------------------------------
# Checking rows 25591 → 25592
#  A PT-PT: Ei, olha! Grava isto!
#  B PT-PT: Porra!
#  would_merge: False
# --------------------------------------------------
# Checking rows 11613 → 11614
#  A PT-PT: Da próxima vez que disseres...
#  B PT-PT: Os pais do Johan continuam a telefonar-lhe também?
#  would_merge: False
# --------------------------------------------------
# Checking rows 43673 → 43674
#  A PT-PT: Bravo, excelente observação!
#  B PT-PT: - Já cá estou. - Já não era sem tempo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 23117 → 23118
#  A PT-PT: Como é que comeu?
#  B PT-PT: Eu não o fiz. Nem por isso.
#  would_merge: False
# --------------------------------------------------
# Checking rows 29588 → 29589
#  A PT-PT: Is he okay?
#  B PT-PT: He's, like, different right?
#  would_merge: False
# --------------------------------------------------
# Checking rows 38443 → 38444
#  A PT-PT: em junho, após um aguaceiro.
#  B PT-PT: - Mm-hm. - E galhos.
#  would_merge: False
# --------------------------------------------------
# Checking rows 56277 → 56278
#  A PT-PT: És apenas um bruto que não é nada sem mim.
#  B PT-PT: Sou apenas um bruto que não é nada sem ti.
#  would_merge: False
# --------------------------------------------------
# Checking rows 7181 → 7182
#  A PT-PT: É um cretino presunçoso que procura casar com a mulher mais rica que encontrar.
#  B PT-PT: Quando ficaram noivos...
#  would_merge: False
# --------------------------------------------------
# Checking rows 22074 → 22075
#  A PT-PT: - Mas levantamo-nos do sofá, certo?
#  B PT-PT: - Sim.
#  would_merge: False
# --------------------------------------------------
# Checking rows 31658 → 31659
#  A PT-PT: Bem-vinda ao Lago dos Alces.
#  B PT-PT: Bem vinda a na-na-na...
#  would_merge: False
# --------------------------------------------------
# Checking rows 40256 → 40257
#  A PT-PT: Dra. Gaul, ela ganhou.
#  B PT-PT: Quando acabar de cantar
#  would_merge: False
# --------------------------------------------------
# Checking rows 46489 → 46490
#  A PT-PT: Não tenho caneta.
#  B PT-PT: A minha estrela.
#  would_merge: False
# --------------------------------------------------
# Checking rows 19217 → 19218
#  A PT-PT: - Isso não é demasiado pessoal? - Calem-se!
#  B PT-PT: - Olá, Balli. - O que é que se passa?
#  would_merge: False
# --------------------------------------------------
# Checking rows 8775 → 8776
#  A PT-PT: -Tudo bem... -Edward?
#  B PT-PT: Edward?
#  would_merge: False
# --------------------------------------------------
# Checking rows 46038 → 46039
#  A PT-PT: O que estão a fazer, meu, é espetacular.
#  B PT-PT: Suponho que não posso incomodá-lo por uma batata frita.
#  would_merge: False
# --------------------------------------------------
# Checking rows 44368 → 44369
#  A PT-PT: Gostas de mim?
#  B PT-PT: Bem, não, mas eu...
#  would_merge: False
# --------------------------------------------------
# Checking rows 44047 → 44048
#  A PT-PT: Não sentes esta humidade? Não te faz nada bem...
#  B PT-PT: Depois encontrámos uma casa melhor para viver.
#  would_merge: False
# --------------------------------------------------
# Checking rows 607 → 608
#  A PT-PT: Ou o sentes ou não.
#  B PT-PT: Então, não é baseado em evidências, como diria o God.
#  would_merge: False
# --------------------------------------------------
# Checking rows 37993 → 37994
#  A PT-PT: Precisas de uma missão.
#  B PT-PT: O inferno está à tua espera.
#  would_merge: False
# --------------------------------------------------
# Checking rows 17498 → 17499
#  A PT-PT: Sim, eu só não podia deixar ninguém a pensar onde estava.
#  B PT-PT: Se eu tirar a mordaça, prometes que não vais entrar em pânico?
#  would_merge: False
# --------------------------------------------------
# Checking rows 56775 → 56776
#  A PT-PT: Querido bebé.
#  B PT-PT: Um dia, compreenderás o que sacrifiquei por ti.
#  would_merge: False
# --------------------------------------------------
# Checking rows 6168 → 6169
#  A PT-PT: -Oh.
#  B PT-PT: -Sabes onde estou?
#  would_merge: False
# --------------------------------------------------
# Checking rows 22990 → 22991
#  A PT-PT: Ei!
#  B PT-PT: Nathan Williams está presente?
#  would_merge: False
# --------------------------------------------------
# Checking rows 11207 → 11208
#  A PT-PT: Então, tens algum grande plano para nos tirar desta situação?
#  B PT-PT: Sim, eu tenho um plano. Eu tenho um plano.
#  would_merge: False
# --------------------------------------------------
# Checking rows 14680 → 14681
#  A PT-PT: Está bem, vou ajudar-te a movê-la.
#  B PT-PT: Está tudo bem, querida.
#  would_merge: False
# --------------------------------------------------
# Checking rows 45411 → 45412
#  A PT-PT: agora seria o momento de partir.
#  B PT-PT: Edward Wayne Brady,
#  would_merge: False
# --------------------------------------------------
# Checking rows 43842 → 43843
#  A PT-PT: É uma estação abandonada.
#  B PT-PT: É só um momento.
#  would_merge: False
# --------------------------------------------------
# Checking rows 22047 → 22048
#  A PT-PT: Recebi a tua carta.
#  B PT-PT: - Não sabia o que dizer.
#  would_merge: False
# --------------------------------------------------
# ...
#  B PT-PT: têm dedicado as suas vidas a manter o legado de Lee.
#  would_merge: True
# --------------------------------------------------
# Checking rows 56820 → 56821
#  A PT-PT: Então, vamos para São Petersburgo e ele que queime a cidade também.
#  B PT-PT: Deixámos passar demasiado tempo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 11315 → 11316
#  A PT-PT: Que comece o espetáculo.
#  B PT-PT: Oh, meu Deus! Vocês viram este sítio?
#  would_merge: False
# --------------------------------------------------
# Checking rows 40323 → 40324
#  A PT-PT: Por favor.
#  B PT-PT: Achei que podia encontrar-te aqui sentado, sozinho.
#  would_merge: False
# --------------------------------------------------
# Checking rows 2750 → 2751
#  A PT-PT: amigos, os americanos,
#  B PT-PT: o que eu não faço.
#  would_merge: False
# --------------------------------------------------
# Checking rows 19919 → 19920
#  A PT-PT: Só um minuto.
#  B PT-PT: Uma frase na sua história
#  would_merge: False
# --------------------------------------------------
# Checking rows 52788 → 52789
#  A PT-PT: - O que é que se passa contigo? - Comigo?
#  B PT-PT: - Não quero a polícia aqui. - Cala-te, raios!
#  would_merge: False
# --------------------------------------------------
# Checking rows 28038 → 28039
#  A PT-PT: Para mudar o que aconteceu.
#  B PT-PT: Para voltar atrás.
#  would_merge: False
# --------------------------------------------------
# Checking rows 26505 → 26506
#  A PT-PT: Sim, tem potencial.
#  B PT-PT: Desliga isso.
#  would_merge: False
# --------------------------------------------------
# Checking rows 48500 → 48501
#  A PT-PT: Observa a bola e mantém-te paralela à parede.
#  B PT-PT: - Não foi mau. - Não tenho jeito para isto.
#  would_merge: False
# --------------------------------------------------
# Checking rows 41195 → 41196
#  A PT-PT: É uma bicicleta.
#  B PT-PT: É um quadro. Sim.
#  would_merge: False
# --------------------------------------------------
# Checking rows 41278 → 41279
#  A PT-PT: Vamos precisar de equipamento. Vamos precisar de kits.
#  B PT-PT: Capacetes.
#  would_merge: False
# --------------------------------------------------
# Checking rows 11419 → 11420
#  A PT-PT: Vocês são tão foleiros, mas adoráveis.
#  B PT-PT: Tudo bem, ótimo. Ok, uh,
#  would_merge: False
# --------------------------------------------------
# Checking rows 36615 → 36616
#  A PT-PT: O que se passa com este Dr. Antonio Taylor?
#  B PT-PT: É procurado por espionagem e ajuda ao inimigo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 2919 → 2920
#  A PT-PT: - Bem, eu tenho estado a dizer que ela devia saltar para trás para o mercado de trabalho o mais rapidamente possível.
#  B PT-PT: Ela tem uma oferta de emprego muito interessante da Davis & Gibbon.
#  would_merge: False
# --------------------------------------------------
# Checking rows 50913 → 50914
#  A PT-PT: Porque raio é que vimos aquele filme?
#  B PT-PT: Pode acompanhar-me à casa de banho?
#  would_merge: False
# --------------------------------------------------
# Checking rows 42260 → 42261
#  A PT-PT: De qualquer forma, o nosso tempo acabou.
#  B PT-PT: Fizemos o que pudemos.
#  would_merge: False
# --------------------------------------------------
# Checking rows 56875 → 56876
#  A PT-PT: e estou pronto para regressar a casa e recuperar o que é meu.
#  B PT-PT: Tu e França.
#  would_merge: False
# --------------------------------------------------
# Checking rows 9293 → 9294
#  A PT-PT: Estes malditos chineses, alguém tem que me explicar isso.
#  B PT-PT: Seria necessário Piero Angela.
#  would_merge: False
# --------------------------------------------------
# Checking rows 22183 → 22184
#  A PT-PT: - Isso foi muito corajoso.
#  B PT-PT: - E é.
#  would_merge: False
# --------------------------------------------------
# Checking rows 15086 → 15087
#  A PT-PT: Sinto que estou a morrer.
#  B PT-PT: Vou desiludir-te.
#  would_merge: False
# --------------------------------------------------
# Checking rows 44430 → 44431
#  A PT-PT: É assim, é um facto, vai acontecer porque eu o digo.
#  B PT-PT: Não estás pelo menos curioso, James, quem é que vais matar?
#  would_merge: False
# --------------------------------------------------
# Checking rows 23858 → 23859
#  A PT-PT: E a coisa realmente importante para lembrar, Stan, é que...
#  B PT-PT: O que é realmente importante para eu me lembrar?
#  would_merge: False
# --------------------------------------------------
# Checking rows 11376 → 11377
#  A PT-PT: Mexer-se. Mexam-se, mexam-se, mexam-se! Vamos lá! Pessoal, temos de ir! Vão, vão, vão!
#  B PT-PT: Oh, merda!
#  would_merge: False
# --------------------------------------------------
# Checking rows 51189 → 51190
#  A PT-PT: Apenas... ok.
#  B PT-PT: Então, agora?
#  would_merge: False
# --------------------------------------------------
# Checking rows 30551 → 30552
#  A PT-PT: Why do you feel like you need to impress Dan so much?
#  B PT-PT: I don't know. Just kinda want him to like me.
#  would_merge: False
# --------------------------------------------------
# Checking rows 11940 → 11941
#  A PT-PT: Estou cansado.
#  B PT-PT: - Vamos deixá-lo descansar, está bem? - Mas eu acabei de chegar.
#  would_merge: False
# --------------------------------------------------
# Checking rows 47024 → 47025
#  A PT-PT: Senhoras e senhores. Caros espetadores, amigos.
#  B PT-PT: Um grande aplauso para o Kazik!
#  would_merge: False
# --------------------------------------------------
# Checking rows 4227 → 4228
#  A PT-PT: Está tudo bem? Sim?
#  B PT-PT: -uns sapatos. -Obrigada!
#  would_merge: False
# --------------------------------------------------
# Checking rows 4219 → 4220
#  A PT-PT: 2 segundos.
#  B PT-PT: Está tudo bem?
#  would_merge: False
# --------------------------------------------------
# Checking rows 30070 → 30071
#  A PT-PT: Good night.
#  B PT-PT: Big man.
#  would_merge: False
# --------------------------------------------------
# Checking rows 43665 → 43666
#  A PT-PT: Mas ela tinha de vir?
#  B PT-PT: Se calhar, podíamos vender-lhe alguma coisa, ela é rica.
#  would_merge: False
# --------------------------------------------------
# Checking rows 22113 → 22114
#  A PT-PT: - Bem, sim, há muitas de coisas que estão a começar a provavelmente, oh meu Deus.
#  B PT-PT: - Isso é horrível.
#  would_merge: False
# --------------------------------------------------
# Checking rows 13770 → 13771
#  A PT-PT: Acerta uma.
#  B PT-PT: - Entrou? - Entrou.
#  would_merge: False
# --------------------------------------------------
# Checking rows 19448 → 19449
#  A PT-PT: Os terroristas vêm para matar.
#  B PT-PT: Os afundadores vêm para viver.
#  would_merge: False
# --------------------------------------------------
# Checking rows 18531 → 18532
#  A PT-PT: O vocabulário é necessário para comunicar.
#  B PT-PT: Como é que vai comunicar a um britânico que
#  would_merge: False
# --------------------------------------------------
# Checking rows 40447 → 40448
#  A PT-PT: Disseram-me que talvez te encontrasse aqui.
#  B PT-PT: Desculpa...
#  would_merge: False
# --------------------------------------------------
# Checking rows 1534 → 1535
#  A PT-PT: Pinho [Pinho]
#  B PT-PT: Pinho [Pinho]
#  would_merge: False
# --------------------------------------------------
# Checking rows 54087 → 54088
#  A PT-PT: Ele chama-se Julien.
#  B PT-PT: Mãos no ar.
#  would_merge: False
# --------------------------------------------------
# Checking rows 25708 → 25709
#  A PT-PT: Na zdrowie!
#  B PT-PT: - Saude! - Muito estranho, pai.
#  would_merge: False
# --------------------------------------------------
# Checking rows 14449 → 14450
#  A PT-PT: Não te preocupes.
#  B PT-PT: Quero dizer, nada de polícia.
#  would_merge: False
# --------------------------------------------------
# Checking rows 35803 → 35804
#  A PT-PT: O quê?
#  B PT-PT: Achas que estás melhor aí? Que fazes na caixa?
#  would_merge: False
# --------------------------------------------------
# Checking rows 23720 → 23721
#  A PT-PT: E depois? Eu fiz asneira.
#  B PT-PT: Atacaste um aluno na escola!
#  would_merge: False
# --------------------------------------------------
# Checking rows 40160 → 40161
#  A PT-PT: Dill?
#  B PT-PT: Dill?
#  would_merge: False
# --------------------------------------------------
# Checking rows 48628 → 48629
#  A PT-PT: NOTIFICAÇÃO CHING-SHIH ENVIOU-LHE UMA MENSAGEM
#  B PT-PT: COMO NOS ENCONTRASTE?
#  would_merge: False
# --------------------------------------------------
# Checking rows 30703 → 30704
#  A PT-PT: - Adoro as cortinas. - Adoro os cisnes.
#  B PT-PT: - Taz? - Querida, estás linda!
#  would_merge: False
# --------------------------------------------------
# Checking rows 25677 → 25678
#  A PT-PT: Eu sei que parece estranho...
#  B PT-PT: Eu não acredito nele, porra, mas os papéis estão em ordem.
#  would_merge: False
# --------------------------------------------------
# Checking rows 54707 → 54708
#  A PT-PT: Ou um pregador
#  B PT-PT: O meu pai sempre me disse que nada vos pode afastar do amor de Deus.
#  would_merge: False
# --------------------------------------------------
# Checking rows 26603 → 26604
#  A PT-PT: Como foi?
#  B PT-PT: E então?
#  would_merge: False
# --------------------------------------------------
# Checking rows 14547 → 14548
#  A PT-PT: Como é que se tranca esta porta?
#  B PT-PT: Aguenta, querida.
#  would_merge: False
# --------------------------------------------------
# Checking rows 53251 → 53252
#  A PT-PT: Indo para a Europa! Duck!!
#  B PT-PT: "A situação não é boa."
#  would_merge: False
# --------------------------------------------------
# Checking rows 13964 → 13965
#  A PT-PT: Partimos esta noite.
#  B PT-PT: Chega de motéis.
#  would_merge: False
# --------------------------------------------------
# Checking rows 23197 → 23198
#  A PT-PT: -Vamos com isso. -Sim, podemos ir agora?
#  B PT-PT: A Sra. Baker sabe que gostas de fotografia?
#  would_merge: False
# --------------------------------------------------
# Checking rows 20708 → 20709
#  A PT-PT: - Oh, parece que toda a gente está morta.
#  B PT-PT: Ótimo, eram fracos.
#  would_merge: False
# --------------------------------------------------
# Checking rows 47881 → 47882
#  A PT-PT: Dedicou a sua vida a isso desde pequena.
#  B PT-PT: Tinha a garra e o talento para ir à selecção nacional.
#  would_merge: False
# --------------------------------------------------
# Checking rows 17693 → 17694
#  A PT-PT: Ainda bem.
#  B PT-PT: Estava a pensar que para o ano...
#  would_merge: False
# --------------------------------------------------
# Checking rows 49188 → 49189
#  A PT-PT: Sete anos desde que a vi pela última vez.
#  B PT-PT: Tenho cancro.
#  would_merge: False
# --------------------------------------------------
# Checking rows 21419 → 21420
#  A PT-PT: Respira fundo.
#  B PT-PT: Bertie. Olha para mim. Só uma vez. Respira fundo.
#  would_merge: False
# --------------------------------------------------
# Checking rows 17824 → 17825
#  A PT-PT: Vens para a Índia? Vou-me embora.
#  B PT-PT: Conseguiste o visto?
#  would_merge: False
# --------------------------------------------------
# Checking rows 25647 → 25648
#  A PT-PT: Mas estão seguros aqui, garanto.
#  B PT-PT: - Vou me embora, vejo-vos lá em cima. - Ok, obrigado.
#  would_merge: False
# --------------------------------------------------
# Checking rows 58888 → 58889
#  A PT-PT: Mas eu estou terminando o bolo da festa.
#  B PT-PT: Por isso. Deixe o bolo aí agora.
#  would_merge: False
# --------------------------------------------------
# Checking rows 47206 → 47207
#  A PT-PT: Qual é o plano? Vais vir aqui ver-me trabalhar?
#  B PT-PT: Se for preciso.
#  would_merge: False
# --------------------------------------------------
# Checking rows 50657 → 50658
#  A PT-PT: - Não, que se lixe o Matt Damon.
#  B PT-PT: - Isso é muito duro.
#  would_merge: False
# --------------------------------------------------
# Checking rows 53310 → 53311
#  A PT-PT: Disse que podia andar com ele e com os amigos, se quisesse.
#  B PT-PT: Isso é bom, não é?
#  would_merge: False
# --------------------------------------------------
# Checking rows 33868 → 33869
#  A PT-PT: Vai-te embora!
#  B PT-PT: Vai-te embora!
#  would_merge: False
# --------------------------------------------------
# Checking rows 44480 → 44481
#  A PT-PT: Alguns sins e alguns nãos confere direitos crescentes sobre os processos físicos e mentais da vítima processos físicos e mentais da vítima.
#  B PT-PT: Será que... Essa pista funcionou, James?
#  would_merge: False
# --------------------------------------------------
# Checking rows 11975 → 11976
#  A PT-PT: - Para quê? - Está tudo bem, deixa-a.
#  B PT-PT: - Liam, vens connosco? - Vai com aquela bruxa.
#  would_merge: False
# --------------------------------------------------
# Checking rows 16643 → 16644
#  A PT-PT: Sim, acho que o puxador está preso ou assim.
#  B PT-PT: - O beliche 9 é sempre tramado. - Pois.
#  would_merge: False
# --------------------------------------------------
# Checking rows 3818 → 3819
#  A PT-PT: Conseguiste um salto na lista de convidados?
#  B PT-PT: - Um bocadinho.
#  would_merge: False
# --------------------------------------------------
# Checking rows 52497 → 52498
#  A PT-PT: Ninguém o está a forçar.
#  B PT-PT: Claro que não. Sei que é difícil para toda a gente.
#  would_merge: False
# --------------------------------------------------
# Checking rows 10946 → 10947
#  A PT-PT: Então, uh, apenas mais uma recolha, então.
#  B PT-PT: Na verdade, é um pouco mais complicado.
#  would_merge: False
# --------------------------------------------------
# Checking rows 14875 → 14876
#  A PT-PT: - Meu Deus... - Olá, pai.
#  B PT-PT: - Olá, rapaz. - Tudo bem?
#  would_merge: False
# --------------------------------------------------
# Checking rows 4650 → 4651
#  A PT-PT: Eu só magoava todos aqueles que eram importantes e de quem gostava.
#  B PT-PT: está a cair aos bocados.
#  would_merge: False
# --------------------------------------------------
# Checking rows 31747 → 31748
#  A PT-PT: Trata-se de aventura!
#  B PT-PT: Vê bem o que mais a vida pode oferecer-nos.
#  would_merge: False
# --------------------------------------------------
# Checking rows 49644 → 49645
#  A PT-PT: Eu tinha um email impresso, e coloquei-o numa pasta.
#  B PT-PT: Ainda não tinha secretária, por isso, levei-o comigo passei a segurança e fui ao Starbucks.
#  would_merge: False
# --------------------------------------------------
# Checking rows 45594 → 45595
#  A PT-PT: Não sei se iria tão longe.
#  B PT-PT: Quero dizer, acho que tenho dificuldade para continuar a aceitar a ideia de que...
#  would_merge: False
# --------------------------------------------------
# Checking rows 35443 → 35444
#  A PT-PT: Quando andares na natureza e os animais vierem atrás de ti lembra-te de mudar de cor e de te camuflares!
#  B PT-PT: Mas eu não sou um camaleão.
#  would_merge: False
# --------------------------------------------------
# Checking rows 46637 → 46638
#  A PT-PT: Diz-lhes que a Klaudia se reformou.
#  B PT-PT: Que tal isto?
#  would_merge: False
# --------------------------------------------------
# Checking rows 21352 → 21353
#  A PT-PT: Esqueça isso. Está dormente.
#  B PT-PT: - Posso desligá-lo. - Deixe estar.
#  would_merge: False
# --------------------------------------------------
# Checking rows 28985 → 28986
#  A PT-PT: Acontecem coisas más a nós, mulheres.
#  B PT-PT: Lee...
#  would_merge: False
# --------------------------------------------------
# Checking rows 18008 → 18009
#  A PT-PT: Vitória, vitória, vitória para ti!
#  B PT-PT: Nesse dia, um estranho pôs os pés em Laltu.
#  would_merge: False
# --------------------------------------------------
# Checking rows 25219 → 25220
#  A PT-PT: Polaco, Inglês?
#  B PT-PT: Está bem?
#  would_merge: False
# --------------------------------------------------
# Checking rows 12178 → 12179
#  A PT-PT: Depois começou a bater-me e a puxar-me a pele.
#  B PT-PT: Ela continuou a bater-me até o meu nariz estar a sangrar.
#  would_merge: False
# --------------------------------------------------
# Checking rows 24790 → 24791
#  A PT-PT: Vou trazer o carro, já volto.
#  B PT-PT: - Essa é a esposa dele! Vai para o hospital! - Cale a boca, porra.
#  would_merge: False
# --------------------------------------------------
# Checking rows 54969 → 54970
#  A PT-PT: "Os que fizeram o mal virá sobre a ressurreição da condenação,
#  B PT-PT: porque o salário do pecado é a morte".
#  would_merge: False
# --------------------------------------------------

# %%
len(df_subtitle_pairs)-bad_row_count
# Out:
# 57630
